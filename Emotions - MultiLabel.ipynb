# %%
from MultiLabelEvolvingSNN import *
import arff
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
np.random.seed(0)
torch.manual_seed(0)
torch.cuda.manual_seed(0)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# device = torch.device('cpu')

# %% [markdown]
# ## Load data and convert to Spikes

# %%
train_path = '../datasets/emotions/emotions-train.arff'
test_path = '../datasets/emotions/emotions-test.arff'
num_features = 72
train_data = arff.load(open(train_path, 'rt'))
train_data = np.array(train_data['data']).astype(np.float32)
test_data = arff.load(open(test_path, 'rt'))
test_data = np.array(test_data['data']).astype(np.float32)
a = train_data[:, :num_features].max(axis=0)
b = train_data[:, :num_features].min(axis=0)

train_spikes, train_labels = encode_data_to_spikes(train_data, device, num_features, a, b)
test_spikes, test_labels = encode_data_to_spikes(test_data, device, num_features, a, b)
print("Train data shape: ", np.array(train_spikes).shape)
print("Train labels shape: ", np.array(train_labels).shape)
print("Test data shape: ", np.array(test_spikes).shape)
print("Test labels shape: ", np.array(test_labels).shape)

# print(train_labels[0:5])
# Out:
# 100%|██████████| 391/391 [00:00<00:00, 8832.82it/s]
# 100%|██████████| 202/202 [00:00<00:00, 8721.13it/s]
# Train data shape:  (391, 1, 432)
# Train labels shape:  (391, 6)
# Test data shape:  (202, 1, 432)
# Test labels shape:  (202, 6)

# %% [markdown]
# ## SNN

# %%
hparams_dict = {
    'name': 'Emotions',
    'inputs': 432,
    'outputs': 6,
    'time_constant': 300,
    'alpha_a': 0.42,
    'alpha_m': 0.07,
    'w_max': 100.0,
    'w_min': -100.0,
    'lr': 1e-3,
    'sim_time': 600,
    'n_epochs': 2500,
    'print_every': 200,
    'seed': 2,
    'ckpt_dir': './checkpoints/emotions',
    'load_from_file': None,
    'device': device
}
# train_labels = np.array([x[0] for x in train_labels]).reshape((-1, 1))
# test_labels = np.array([x[0] for x in test_labels]).reshape((-1, 1))
# train_spikes = [train_spikes[0], train_spikes[3]]
# train_labels = [train_labels[0], train_labels[3]]
net = OverallSNN(hparams_dict)
train_history, test_history = net.fit(train_spikes, train_labels, test_spikes, test_labels)
# Out:
#   0%|          | 0/2500 [00:00<?, ?it/s]
# Class 0, class 1 neurons = 5, class 0 neurons = 5
# Class 1, class 1 neurons = 5, class 0 neurons = 5
# Class 2, class 1 neurons = 3, class 0 neurons = 7
# Class 3, class 1 neurons = 3, class 0 neurons = 3
# Class 4, class 1 neurons = 5, class 0 neurons = 4
# Class 5, class 1 neurons = 6, class 0 neurons = 4
#   8%|▊         | 200/2500 [31:18<6:02:59,  9.47s/it]
# Epoch number: 200
# Train Precision: 0.8051, Test Precision: 0.7492
# Train Recall: 0.6643, Test Recall: 0.5764
# Train F1: 0.7280, Test F1: 0.6516
# Max. train classwise accuracy for is 0.9284
# Min. train classwise accuracy for is 0.7903
# Max. test classwise accuracy for is 0.8762
# Min. test classwise accuracy for is 0.7277
#  16%|█▌        | 400/2500 [1:02:47<5:29:34,  9.42s/it]
# Epoch number: 400
# Train Precision: 0.8280, Test Precision: 0.7411
# Train Recall: 0.7264, Test Recall: 0.6241
# Train F1: 0.7739, Test F1: 0.6776
# Max. train classwise accuracy for is 0.9540
# Min. train classwise accuracy for is 0.8184
# Max. test classwise accuracy for is 0.8713
# Min. test classwise accuracy for is 0.7129
#  24%|██▍       | 600/2500 [1:34:05<4:56:31,  9.36s/it]
# Epoch number: 600
# Train Precision: 0.8425, Test Precision: 0.7318
# Train Recall: 0.7546, Test Recall: 0.6291
# Train F1: 0.7961, Test F1: 0.6765
# Max. train classwise accuracy for is 0.9591
# Min. train classwise accuracy for is 0.8363
# Max. test classwise accuracy for is 0.8911
# Min. test classwise accuracy for is 0.7030
#  32%|███▏      | 800/2500 [2:05:13<4:24:06,  9.32s/it]
# Epoch number: 800
# Train Precision: 0.8559, Test Precision: 0.7211
# Train Recall: 0.8039, Test Recall: 0.6416
# Train F1: 0.8291, Test F1: 0.6790
# Max. train classwise accuracy for is 0.9642
# Min. train classwise accuracy for is 0.8593
# Max. test classwise accuracy for is 0.8960
# Min. test classwise accuracy for is 0.7079
#  40%|████      | 1000/2500 [2:36:10<3:50:59,  9.24s/it]
# Epoch number: 1000
# Train Precision: 0.8642, Test Precision: 0.7107
# Train Recall: 0.8166, Test Recall: 0.6341
# Train F1: 0.8397, Test F1: 0.6702
# Max. train classwise accuracy for is 0.9668
# Min. train classwise accuracy for is 0.8670
# Max. test classwise accuracy for is 0.9010
# Min. test classwise accuracy for is 0.7129
#  48%|████▊     | 1200/2500 [3:06:49<3:18:17,  9.15s/it]
# Epoch number: 1200
# Train Precision: 0.8864, Test Precision: 0.7070
# Train Recall: 0.8251, Test Recall: 0.6291
# Train F1: 0.8546, Test F1: 0.6658
# Max. train classwise accuracy for is 0.9693
# Min. train classwise accuracy for is 0.8721
# Max. test classwise accuracy for is 0.9059
# Min. test classwise accuracy for is 0.7030
#  56%|█████▌    | 1400/2500 [3:37:07<2:45:25,  9.02s/it]
# Epoch number: 1400
# Train Precision: 0.8992, Test Precision: 0.7047
# Train Recall: 0.8434, Test Recall: 0.6341
# Train F1: 0.8705, Test F1: 0.6675
# Max. train classwise accuracy for is 0.9693
# Min. train classwise accuracy for is 0.8772
# Max. test classwise accuracy for is 0.8861
# Min. test classwise accuracy for is 0.7228
#  64%|██████▍   | 1600/2500 [4:06:24<2:11:02,  8.74s/it]
# Epoch number: 1600
# Train Precision: 0.9074, Test Precision: 0.7135
# Train Recall: 0.8434, Test Recall: 0.6366
# Train F1: 0.8743, Test F1: 0.6728
# Max. train classwise accuracy for is 0.9668
# Min. train classwise accuracy for is 0.8824
# Max. test classwise accuracy for is 0.9010
# Min. test classwise accuracy for is 0.7178
#  72%|███████▏  | 1800/2500 [4:35:26<1:41:23,  8.69s/it]
# Epoch number: 1800
# Train Precision: 0.9094, Test Precision: 0.7209
# Train Recall: 0.8209, Test Recall: 0.6216
# Train F1: 0.8629, Test F1: 0.6676
# Max. train classwise accuracy for is 0.9770
# Min. train classwise accuracy for is 0.8696
# Max. test classwise accuracy for is 0.9158
# Min. test classwise accuracy for is 0.7228
#  80%|████████  | 2000/2500 [5:04:18<1:12:03,  8.65s/it]
# Epoch number: 2000
# Train Precision: 0.9109, Test Precision: 0.7123
# Train Recall: 0.8505, Test Recall: 0.6516
# Train F1: 0.8796, Test F1: 0.6806
# Max. train classwise accuracy for is 0.9795
# Min. train classwise accuracy for is 0.8951
# Max. test classwise accuracy for is 0.9109
# Min. test classwise accuracy for is 0.6980
#  88%|████████▊ | 2200/2500 [5:33:02<42:54,  8.58s/it]
# Epoch number: 2200
# Train Precision: 0.9060, Test Precision: 0.6984
# Train Recall: 0.8561, Test Recall: 0.6617
# Train F1: 0.8803, Test F1: 0.6795
# Max. train classwise accuracy for is 0.9770
# Min. train classwise accuracy for is 0.9028
# Max. test classwise accuracy for is 0.9010
# Min. test classwise accuracy for is 0.7079
#  96%|█████████▌| 2400/2500 [6:01:40<14:31,  8.71s/it]
# Epoch number: 2400
# Train Precision: 0.9114, Test Precision: 0.6957
# Train Recall: 0.8561, Test Recall: 0.6416
# Train F1: 0.8829, Test F1: 0.6675
# Max. train classwise accuracy for is 0.9795
# Min. train classwise accuracy for is 0.9003
# Max. test classwise accuracy for is 0.8861
# Min. test classwise accuracy for is 0.6881
# 100%|██████████| 2500/2500 [6:16:10<00:00,  9.03s/it]
# Max. Test Precision: 0.7594 at epoch 92
# Test Recall at max. test precision: 0.5063
# Test F1 at max. test precision: 0.6075
# Train Precision at max. test precision: 0.7924
# Train Recall at max. test precision: 0.5867
# Train F1 at max. test precision: 0.6742
# Max. Test Recall: 0.6742 at epoch 2223
# Test Precision at max. test recall: 0.6987
# Test F1 at max. test recall: 0.6862
# Train Recall at max. test recall: 0.8590
# Train Precision at max. test recall: 0.9076
# Train F1 at max. test recall: 0.8826
# Max. Test F1: 0.6883 at epoch 2125
# Test Recall at max. test F1: 0.6642
# Test Precision at max. test F1: 0.7143
# Train Recall at max. test F1: 0.8463
# Train Precision at max. test F1: 0.9132
# Train F1 at max. test F1: 0.8785

# %%
hparams_dict = {
    'name': 'Emotions',
    'inputs': 432,
    'outputs': 6,
    'time_constant': 300,
    'alpha_a': 0.42,
    'alpha_m': 0.07,
    'w_max': 100.0,
    'w_min': -100.0,
    'lr': 1e-3,
    'sim_time': 600,
    'n_epochs': 2500,
    'print_every': 200,
    'seed': 2,
    'ckpt_dir': './checkpoints/emotions',
    'load_from_file': './checkpoints/emotions/best_f1_model0.001_2500.pkl',
    'device': device
}
net = OverallSNN(hparams_dict)
metrics = Metrics(net, train_spikes, train_labels, test_spikes, test_labels)
metrics.evaluate()
# Out:
# Model was trained on 6 classes
# Evaluating Model on train mode
# Classwise Results
# |                     |         0 |         1 |         2 |         3 |         4 |         5 |
# |:--------------------|----------:|----------:|----------:|----------:|----------:|----------:|
# | class               | 1         | 2         | 3         | 4         | 5         | 6         |
# | accuracy            | 0.907928  | 0.923274  | 0.946292  | 0.976982  | 0.920716  | 0.900256  |
# | hamming loss        | 0.0920716 | 0.0767263 | 0.0537084 | 0.0230179 | 0.0792839 | 0.0997442 |
# | zero_one_loss       | 0.0920716 | 0.0767263 | 0.0537084 | 0.0230179 | 0.0792839 | 0.0997442 |
# | micro av. jaccard   | 0.831382  | 0.857482  | 0.898058  | 0.955     | 0.853081  | 0.818605  |
# | macro av. jaccard   | 0.805023  | 0.820546  | 0.896139  | 0.936477  | 0.795447  | 0.798442  |
# | micro av. precision | 0.907928  | 0.923274  | 0.946292  | 0.976982  | 0.920716  | 0.900256  |
# | macro av. precision | 0.894203  | 0.920076  | 0.945506  | 0.972722  | 0.929902  | 0.892413  |
# | micro av. recall    | 0.907928  | 0.923274  | 0.946292  | 0.976982  | 0.920716  | 0.900256  |
# | macro av. recall    | 0.886555  | 0.883112  | 0.94484   | 0.961325  | 0.851138  | 0.881445  |
# | micro av. f1        | 0.907928  | 0.923274  | 0.946292  | 0.976982  | 0.920716  | 0.900256  |
# | macro av. f1        | 0.89023   | 0.899227  | 0.945167  | 0.966872  | 0.881982  | 0.886528  |
# Overall Results
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.0707587 |
# | zero_one_loss       | 0.345269  |
# | one_error           | 0         |
# | micro av. jaccard   | 0.78329   |
# | macro av. jaccard   | 0.779704  |
# | micro av. precision | 0.913242  |
# | macro av. precision | 0.915916  |
# | micro av. recall    | 0.846262  |
# | macro av. recall    | 0.838942  |
# | micro av. f1        | 0.878477  |
# | macro av. f1        | 0.873911  |
# Evaluating Model on test mode
# Classwise Results
# |                     |        0 |        1 |        2 |         3 |        4 |        5 |
# |:--------------------|---------:|---------:|---------:|----------:|---------:|---------:|
# | class               | 1        | 2        | 3        | 4         | 5        | 6        |
# | accuracy            | 0.811881 | 0.777228 | 0.69802  | 0.905941  | 0.792079 | 0.826733 |
# | hamming loss        | 0.188119 | 0.222772 | 0.30198  | 0.0940594 | 0.207921 | 0.173267 |
# | zero_one_loss       | 0.188119 | 0.222772 | 0.30198  | 0.0940594 | 0.207921 | 0.173267 |
# | micro av. jaccard   | 0.683333 | 0.635628 | 0.536122 | 0.828054  | 0.655738 | 0.704641 |
# | macro av. jaccard   | 0.628785 | 0.575439 | 0.536061 | 0.801372  | 0.606904 | 0.658642 |
# | micro av. precision | 0.811881 | 0.777228 | 0.69802  | 0.905941  | 0.792079 | 0.826733 |
# | macro av. precision | 0.759785 | 0.731184 | 0.698588 | 0.882719  | 0.817025 | 0.788808 |
# | micro av. recall    | 0.811881 | 0.777228 | 0.69802  | 0.905941  | 0.792079 | 0.826733 |
# | macro av. recall    | 0.765766 | 0.708249 | 0.698998 | 0.893742  | 0.730169 | 0.7858   |
# | micro av. f1        | 0.811881 | 0.777228 | 0.69802  | 0.905941  | 0.792079 | 0.826733 |
# | macro av. f1        | 0.762647 | 0.717307 | 0.697953 | 0.887919  | 0.746049 | 0.787272 |
# Overall Results
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.19802  |
# | zero_one_loss       | 0.69802  |
# | one_error           | 0        |
# | micro av. jaccard   | 0.524752 |
# | macro av. jaccard   | 0.527183 |
# | micro av. precision | 0.714286 |
# | macro av. precision | 0.722927 |
# | micro av. recall    | 0.66416  |
# | macro av. recall    | 0.664783 |
# | micro av. f1        | 0.688312 |
# | macro av. f1        | 0.685288 |
# Evaluating Model on combined mode
# Classwise Results
# |                     |        0 |        1 |        2 |         3 |        4 |        5 |
# |:--------------------|---------:|---------:|---------:|----------:|---------:|---------:|
# | class               | 1        | 2        | 3        | 4         | 5        | 6        |
# | accuracy            | 0.875211 | 0.873524 | 0.86172  | 0.952782  | 0.876897 | 0.875211 |
# | hamming loss        | 0.124789 | 0.126476 | 0.13828  | 0.0472175 | 0.123103 | 0.124789 |
# | zero_one_loss       | 0.124789 | 0.126476 | 0.13828  | 0.0472175 | 0.123103 | 0.124789 |
# | micro av. jaccard   | 0.778111 | 0.775449 | 0.757037 | 0.909823  | 0.780781 | 0.778111 |
# | macro av. jaccard   | 0.74218  | 0.725906 | 0.755166 | 0.883079  | 0.720149 | 0.750187 |
# | micro av. precision | 0.875211 | 0.873524 | 0.86172  | 0.952782  | 0.876897 | 0.875211 |
# | macro av. precision | 0.849713 | 0.854646 | 0.859695 | 0.936972  | 0.890622 | 0.859082 |
# | micro av. recall    | 0.875211 | 0.873524 | 0.86172  | 0.952782  | 0.876897 | 0.875211 |
# | macro av. recall    | 0.847316 | 0.821965 | 0.861161 | 0.936972  | 0.800735 | 0.850693 |
# | micro av. f1        | 0.875211 | 0.873524 | 0.86172  | 0.952782  | 0.876897 | 0.875211 |
# | macro av. f1        | 0.848499 | 0.835881 | 0.860338 | 0.936972  | 0.830604 | 0.854657 |
# Overall Results
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.114109 |
# | zero_one_loss       | 0.46543  |
# | one_error           | 0        |
# | micro av. jaccard   | 0.680566 |
# | macro av. jaccard   | 0.678798 |
# | micro av. precision | 0.84144  |
# | macro av. precision | 0.846803 |
# | micro av. recall    | 0.780686 |
# | macro av. recall    | 0.775783 |
# | micro av. f1        | 0.809925 |
# | macro av. f1        | 0.80601  |
