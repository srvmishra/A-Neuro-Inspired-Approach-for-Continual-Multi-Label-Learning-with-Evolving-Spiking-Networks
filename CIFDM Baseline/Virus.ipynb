# %%
# !python3 main.py --name virus --shuffle 1 --seed 2 --device 3
# Out:
# data_name: virus.
# seed: 2.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (124, 446) (83, 446)
# torch.Size([83, 6])
# 0.19879518072289157
# task: 0, #samples: 32, #negative samples: 18, #positive samples: 0
# task: 1, #samples: 60, #negative samples: 35, #positive samples: 0
# task: 2, #samples: 32, #negative samples: 28, #positive samples: 1
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:35<00:00,  2.38s/it]
# The task 0 result is following:
# output shape =  (83, 4)
# ground truth shape =  (83, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.289157 |
# | zero_one_loss       | 0.578313 |
# | one_error           | 0        |
# | micro av. jaccard   | 0.414634 |
# | macro av. jaccard   | 0.21519  |
# | micro av. precision | 0.43038  |
# | macro av. precision | 0.21519  |
# | micro av. recall    | 0.918919 |
# | macro av. recall    | 0.5      |
# | micro av. f1        | 0.586207 |
# | macro av. f1        | 0.300885 |
# | micro av. pr.       | 0.408919 |
# | macro av. pr.       | 0.702894 |
# | micro av. auc       | 0.791745 |
# | macro av. auc       | 0.742197 |
# | coverage error      | 0.445783 |
# | ranking loss        | 0        |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:17<00:00,  3.59s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.289157 |
# | zero_one_loss       | 0.578313 |
# | one_error           | 0        |
# | micro av. jaccard   | 0.414634 |
# | macro av. jaccard   | 0.21519  |
# | micro av. precision | 0.43038  |
# | macro av. precision | 0.21519  |
# | micro av. recall    | 0.918919 |
# | macro av. recall    | 0.5      |
# | micro av. f1        | 0.586207 |
# | macro av. f1        | 0.300885 |
# | micro av. pr.       | 0.408919 |
# | macro av. pr.       | 0.702894 |
# | micro av. auc       | 0.791745 |
# | macro av. auc       | 0.742197 |
# | coverage error      | 0.445783 |
# | ranking loss        | 0        |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (83, 4)
# ground truth shape =  (83, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.289157 |
# | zero_one_loss       | 0.578313 |
# | one_error           | 0        |
# | micro av. jaccard   | 0.333333 |
# | macro av. jaccard   | 0.173913 |
# | micro av. precision | 0.40678  |
# | macro av. precision | 0.20339  |
# | micro av. recall    | 0.648649 |
# | macro av. recall    | 0.352941 |
# | micro av. f1        | 0.5      |
# | macro av. f1        | 0.258065 |
# | micro av. pr.       | 0.412408 |
# | macro av. pr.       | 0.703957 |
# | micro av. auc       | 0.795307 |
# | macro av. auc       | 0.744298 |
# | coverage error      | 0.445783 |
# | ranking loss        | 0        |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 2, e index: 4
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |         1 |
# |:--------------------|---------:|----------:|
# | hamming loss        | 0.289157 | 0.656627  |
# | zero_one_loss       | 0.578313 | 0.927711  |
# | one_error           | 0        | 0.385542  |
# | micro av. jaccard   | 0.333333 | 0.0603448 |
# | macro av. jaccard   | 0.173913 | 0.0421687 |
# | micro av. precision | 0.40678  | 0.0843373 |
# | macro av. precision | 0.20339  | 0.0421687 |
# | micro av. recall    | 0.648649 | 0.175     |
# | macro av. recall    | 0.352941 | 0.5       |
# | micro av. f1        | 0.5      | 0.113821  |
# | macro av. f1        | 0.258065 | 0.0777778 |
# | micro av. pr.       | 0.412408 | 0.174945  |
# | macro av. pr.       | 0.703957 | 0.265341  |
# | micro av. auc       | 0.795307 | 0.285714  |
# | macro av. auc       | 0.744298 | 0.516254  |
# | coverage error      | 0.445783 | 0.86747   |
# | ranking loss        | 0        | 0.385542  |
#
# Beginning compression, old model output size = 2
# Inter end shape =  4
# Old model output shape = 4
# Train single mode Epoch: 100%|██████████████████| 15/15 [00:56<00:00,  3.79s/it]
# Old model output shape =  4
# Train single mode Epoch: 100%|██████████████████| 40/40 [02:33<00:00,  3.84s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:19<00:00,  3.84s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |         1 |
# |:--------------------|---------:|----------:|
# | hamming loss        | 0.289157 | 0.656627  |
# | zero_one_loss       | 0.578313 | 0.927711  |
# | one_error           | 0        | 0.385542  |
# | micro av. jaccard   | 0.333333 | 0.0603448 |
# | macro av. jaccard   | 0.173913 | 0.0421687 |
# | micro av. precision | 0.40678  | 0.0843373 |
# | macro av. precision | 0.20339  | 0.0421687 |
# | micro av. recall    | 0.648649 | 0.175     |
# | macro av. recall    | 0.352941 | 0.5       |
# | micro av. f1        | 0.5      | 0.113821  |
# | macro av. f1        | 0.258065 | 0.0777778 |
# | micro av. pr.       | 0.412408 | 0.174945  |
# | macro av. pr.       | 0.703957 | 0.265341  |
# | micro av. auc       | 0.795307 | 0.285714  |
# | macro av. auc       | 0.744298 | 0.516254  |
# | coverage error      | 0.445783 | 0.86747   |
# | ranking loss        | 0        | 0.385542  |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (83, 6)
# ground truth shape =  (83, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.313253  |
# | zero_one_loss       | 0.590361  |
# | one_error           | 0.0361446 |
# | micro av. jaccard   | 0.395349  |
# | macro av. jaccard   | 0.204819  |
# | micro av. precision | 0.409639  |
# | macro av. precision | 0.204819  |
# | micro av. recall    | 0.918919  |
# | macro av. recall    | 0.5       |
# | micro av. f1        | 0.566667  |
# | macro av. f1        | 0.290598  |
# | micro av. pr.       | 0.450802  |
# | macro av. pr.       | 0.726607  |
# | micro av. auc       | 0.783574  |
# | macro av. auc       | 0.734094  |
# | coverage error      | 0.481928  |
# | ranking loss        | 0.0361446 |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 2, e index: 4
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |         1 |
# |:--------------------|----------:|----------:|
# | hamming loss        | 0.313253  | 0.343373  |
# | zero_one_loss       | 0.590361  | 0.614458  |
# | one_error           | 0.0361446 | 0.0722892 |
# | micro av. jaccard   | 0.395349  | 0.366667  |
# | macro av. jaccard   | 0.204819  | 0.198795  |
# | micro av. precision | 0.409639  | 0.39759   |
# | macro av. precision | 0.204819  | 0.198795  |
# | micro av. recall    | 0.918919  | 0.825     |
# | macro av. recall    | 0.5       | 0.5       |
# | micro av. f1        | 0.566667  | 0.536585  |
# | macro av. f1        | 0.290598  | 0.284483  |
# | micro av. pr.       | 0.450802  | 0.436494  |
# | macro av. pr.       | 0.726607  | 0.278964  |
# | micro av. auc       | 0.783574  | 0.722619  |
# | macro av. auc       | 0.734094  | 0.502841  |
# | coverage error      | 0.481928  | 0.554217  |
# | ranking loss        | 0.0361446 | 0.0722892 |
#
# label index list [0, 2, 4, 6]
# Task: 2, s index: 4, e index: 6
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |         1 |         2 |
# |:--------------------|----------:|----------:|----------:|
# | hamming loss        | 0.313253  | 0.343373  | 0.289157  |
# | zero_one_loss       | 0.590361  | 0.614458  | 0.542169  |
# | one_error           | 0.0361446 | 0.0722892 | 0.0361446 |
# | micro av. jaccard   | 0.395349  | 0.366667  | 0.0943396 |
# | macro av. jaccard   | 0.204819  | 0.198795  | 0.0568182 |
# | micro av. precision | 0.409639  | 0.39759   | 0.138889  |
# | macro av. precision | 0.204819  | 0.198795  | 0.0694444 |
# | micro av. recall    | 0.918919  | 0.825     | 0.227273  |
# | macro av. recall    | 0.5       | 0.5       | 0.192308  |
# | micro av. f1        | 0.566667  | 0.536585  | 0.172414  |
# | macro av. f1        | 0.290598  | 0.284483  | 0.102041  |
# | micro av. pr.       | 0.450802  | 0.436494  | 0.154084  |
# | macro av. pr.       | 0.726607  | 0.278964  | 0.213679  |
# | micro av. auc       | 0.783574  | 0.722619  | 0.576705  |
# | macro av. auc       | 0.734094  | 0.502841  | 0.544034  |
# | coverage error      | 0.481928  | 0.554217  | 0.361446  |
# | ranking loss        | 0.0361446 | 0.0722892 | 0.0963855 |
#
# Individual Task Results
# |                     |         0 |         1 |         2 |
# |:--------------------|----------:|----------:|----------:|
# | hamming loss        | 0.313253  | 0.343373  | 0.289157  |
# | zero_one_loss       | 0.590361  | 0.614458  | 0.542169  |
# | one_error           | 0.0361446 | 0.0722892 | 0.0361446 |
# | micro av. jaccard   | 0.395349  | 0.366667  | 0.0943396 |
# | macro av. jaccard   | 0.204819  | 0.198795  | 0.0568182 |
# | micro av. precision | 0.409639  | 0.39759   | 0.138889  |
# | macro av. precision | 0.204819  | 0.198795  | 0.0694444 |
# | micro av. recall    | 0.918919  | 0.825     | 0.227273  |
# | macro av. recall    | 0.5       | 0.5       | 0.192308  |
# | micro av. f1        | 0.566667  | 0.536585  | 0.172414  |
# | macro av. f1        | 0.290598  | 0.284483  | 0.102041  |
# | micro av. pr.       | 0.450802  | 0.436494  | 0.154084  |
# | macro av. pr.       | 0.726607  | 0.278964  | 0.213679  |
# | micro av. auc       | 0.783574  | 0.722619  | 0.576705  |
# | macro av. auc       | 0.734094  | 0.502841  | 0.544034  |
# | coverage error      | 0.481928  | 0.554217  | 0.361446  |
# | ranking loss        | 0.0361446 | 0.0722892 | 0.0963855 |
#
# ======================== Final Result ========================
# output shape =  (83, 6)
# ground truth shape =  (83, 6)
# Evaluation mode is incremental
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.313253  |
# | zero_one_loss       | 0.590361  |
# | one_error           | 0.0361446 |
# | micro av. jaccard   | 0.395349  |
# | macro av. jaccard   | 0.204819  |
# | micro av. precision | 0.409639  |
# | macro av. precision | 0.204819  |
# | micro av. recall    | 0.918919  |
# | macro av. recall    | 0.5       |
# | micro av. f1        | 0.566667  |
# | macro av. f1        | 0.290598  |
# | micro av. pr.       | 0.450802  |
# | macro av. pr.       | 0.726607  |
# | micro av. auc       | 0.783574  |
# | macro av. auc       | 0.734094  |
# | coverage error      | 0.481928  |
# | ranking loss        | 0.0361446 |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 0, e index: 4
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |        1 |
# |:--------------------|----------:|---------:|
# | hamming loss        | 0.313253  | 0.328313 |
# | zero_one_loss       | 0.590361  | 0.879518 |
# | one_error           | 0.0361446 | 0        |
# | micro av. jaccard   | 0.395349  | 0.380682 |
# | macro av. jaccard   | 0.204819  | 0.201807 |
# | micro av. precision | 0.409639  | 0.403614 |
# | macro av. precision | 0.204819  | 0.201807 |
# | micro av. recall    | 0.918919  | 0.87013  |
# | macro av. recall    | 0.5       | 0.5      |
# | micro av. f1        | 0.566667  | 0.55144  |
# | macro av. f1        | 0.290598  | 0.287541 |
# | micro av. pr.       | 0.450802  | 0.425559 |
# | macro av. pr.       | 0.726607  | 0.502785 |
# | micro av. auc       | 0.783574  | 0.76221  |
# | macro av. auc       | 0.734094  | 0.618467 |
# | coverage error      | 0.481928  | 1.45783  |
# | ranking loss        | 0.0361446 | 0.178715 |
#
# label index list [0, 2, 4, 6]
# Task: 2, s index: 0, e index: 6
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |        1 |        2 |
# |:--------------------|----------:|---------:|---------:|
# | hamming loss        | 0.313253  | 0.328313 | 0.315261 |
# | zero_one_loss       | 0.590361  | 0.879518 | 0.939759 |
# | one_error           | 0.0361446 | 0        | 0        |
# | micro av. jaccard   | 0.395349  | 0.380682 | 0.31441  |
# | macro av. jaccard   | 0.204819  | 0.201807 | 0.153478 |
# | micro av. precision | 0.409639  | 0.403614 | 0.356436 |
# | macro av. precision | 0.204819  | 0.201807 | 0.157686 |
# | micro av. recall    | 0.918919  | 0.87013  | 0.727273 |
# | macro av. recall    | 0.5       | 0.5      | 0.397436 |
# | micro av. f1        | 0.566667  | 0.55144  | 0.478405 |
# | macro av. f1        | 0.290598  | 0.287541 | 0.225707 |
# | micro av. pr.       | 0.450802  | 0.425559 | 0.396457 |
# | macro av. pr.       | 0.726607  | 0.502785 | 0.406417 |
# | micro av. auc       | 0.783574  | 0.76221  | 0.756791 |
# | macro av. auc       | 0.734094  | 0.618467 | 0.593656 |
# | coverage error      | 0.481928  | 1.45783  | 2.42169  |
# | ranking loss        | 0.0361446 | 0.178715 | 0.24411  |
#
# Overall Task Results
# |                     |         0 |        1 |        2 |
# |:--------------------|----------:|---------:|---------:|
# | hamming loss        | 0.313253  | 0.328313 | 0.315261 |
# | zero_one_loss       | 0.590361  | 0.879518 | 0.939759 |
# | one_error           | 0.0361446 | 0        | 0        |
# | micro av. jaccard   | 0.395349  | 0.380682 | 0.31441  |
# | macro av. jaccard   | 0.204819  | 0.201807 | 0.153478 |
# | micro av. precision | 0.409639  | 0.403614 | 0.356436 |
# | macro av. precision | 0.204819  | 0.201807 | 0.157686 |
# | micro av. recall    | 0.918919  | 0.87013  | 0.727273 |
# | macro av. recall    | 0.5       | 0.5      | 0.397436 |
# | micro av. f1        | 0.566667  | 0.55144  | 0.478405 |
# | macro av. f1        | 0.290598  | 0.287541 | 0.225707 |
# | micro av. pr.       | 0.450802  | 0.425559 | 0.396457 |
# | macro av. pr.       | 0.726607  | 0.502785 | 0.406417 |
# | micro av. auc       | 0.783574  | 0.76221  | 0.756791 |
# | macro av. auc       | 0.734094  | 0.618467 | 0.593656 |
# | coverage error      | 0.481928  | 1.45783  | 2.42169  |
# | ranking loss        | 0.0361446 | 0.178715 | 0.24411  |
# 820.6649649143219 s.

# %%
# !python3 main.py --name virus --shuffle 1 --seed 63 --device 3
# Out:
# data_name: virus.
# seed: 63.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (124, 446) (83, 446)
# torch.Size([83, 6])
# 0.19879518072289157
# task: 0, #samples: 32, #negative samples: 18, #positive samples: 0
# task: 1, #samples: 60, #negative samples: 49, #positive samples: 0
# task: 2, #samples: 32, #negative samples: 14, #positive samples: 0
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:36<00:00,  2.41s/it]
# The task 0 result is following:
# output shape =  (83, 4)
# ground truth shape =  (83, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.23494   |
# | zero_one_loss       | 0.445783  |
# | one_error           | 0.0240964 |
# | micro av. jaccard   | 0.25      |
# | macro av. jaccard   | 0.151163  |
# | micro av. precision | 0.565217  |
# | macro av. precision | 0.282609  |
# | micro av. recall    | 0.309524  |
# | macro av. recall    | 0.19697   |
# | micro av. f1        | 0.4       |
# | macro av. f1        | 0.232143  |
# | micro av. pr.       | 0.50297   |
# | macro av. pr.       | 0.406596  |
# | micro av. auc       | 0.769969  |
# | macro av. auc       | 0.681275  |
# | coverage error      | 0.60241   |
# | ranking loss        | 0.0963855 |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:17<00:00,  3.46s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.23494   |
# | zero_one_loss       | 0.445783  |
# | one_error           | 0.0240964 |
# | micro av. jaccard   | 0.25      |
# | macro av. jaccard   | 0.151163  |
# | micro av. precision | 0.565217  |
# | macro av. precision | 0.282609  |
# | micro av. recall    | 0.309524  |
# | macro av. recall    | 0.19697   |
# | micro av. f1        | 0.4       |
# | macro av. f1        | 0.232143  |
# | micro av. pr.       | 0.50297   |
# | macro av. pr.       | 0.406596  |
# | micro av. auc       | 0.769969  |
# | macro av. auc       | 0.681275  |
# | coverage error      | 0.60241   |
# | ranking loss        | 0.0963855 |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (83, 4)
# ground truth shape =  (83, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.259036  |
# | zero_one_loss       | 0.506024  |
# | one_error           | 0.0120482 |
# | micro av. jaccard   | 0.0444444 |
# | macro av. jaccard   | 0.0277778 |
# | micro av. precision | 0.4       |
# | macro av. precision | 0.2       |
# | micro av. recall    | 0.047619  |
# | macro av. recall    | 0.030303  |
# | micro av. f1        | 0.0851064 |
# | macro av. f1        | 0.0526316 |
# | micro av. pr.       | 0.447844  |
# | macro av. pr.       | 0.401902  |
# | micro av. auc       | 0.727919  |
# | macro av. auc       | 0.675531  |
# | coverage error      | 0.626506  |
# | ranking loss        | 0.120482  |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 2, e index: 4
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |         1 |
# |:--------------------|----------:|----------:|
# | hamming loss        | 0.259036  | 0.439759  |
# | zero_one_loss       | 0.506024  | 0.843373  |
# | one_error           | 0.0120482 | 0.0361446 |
# | micro av. jaccard   | 0.0444444 | 0.151163  |
# | macro av. jaccard   | 0.0277778 | 0.0783133 |
# | micro av. precision | 0.4       | 0.156627  |
# | macro av. precision | 0.2       | 0.0783133 |
# | micro av. recall    | 0.047619  | 0.8125    |
# | macro av. recall    | 0.030303  | 0.5       |
# | micro av. f1        | 0.0851064 | 0.262626  |
# | macro av. f1        | 0.0526316 | 0.135417  |
# | micro av. pr.       | 0.447844  | 0.261316  |
# | macro av. pr.       | 0.401902  | 0.332817  |
# | micro av. auc       | 0.727919  | 0.786667  |
# | macro av. auc       | 0.675531  | 0.820261  |
# | coverage error      | 0.626506  | 0.228916  |
# | ranking loss        | 0.120482  | 0.0361446 |
#
# Beginning compression, old model output size = 2
# Inter end shape =  4
# Old model output shape = 4
# Train single mode Epoch: 100%|██████████████████| 15/15 [01:01<00:00,  4.13s/it]
# Old model output shape =  4
# Train single mode Epoch: 100%|██████████████████| 40/40 [02:50<00:00,  4.26s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:19<00:00,  3.96s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |         0 |         1 |
# |:--------------------|----------:|----------:|
# | hamming loss        | 0.259036  | 0.439759  |
# | zero_one_loss       | 0.506024  | 0.843373  |
# | one_error           | 0.0120482 | 0.0361446 |
# | micro av. jaccard   | 0.0444444 | 0.151163  |
# | macro av. jaccard   | 0.0277778 | 0.0783133 |
# | micro av. precision | 0.4       | 0.156627  |
# | macro av. precision | 0.2       | 0.0783133 |
# | micro av. recall    | 0.047619  | 0.8125    |
# | macro av. recall    | 0.030303  | 0.5       |
# | micro av. f1        | 0.0851064 | 0.262626  |
# | macro av. f1        | 0.0526316 | 0.135417  |
# | micro av. pr.       | 0.447844  | 0.261316  |
# | macro av. pr.       | 0.401902  | 0.332817  |
# | micro av. auc       | 0.727919  | 0.786667  |
# | macro av. auc       | 0.675531  | 0.820261  |
# | coverage error      | 0.626506  | 0.228916  |
# | ranking loss        | 0.120482  | 0.0361446 |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (83, 6)
# ground truth shape =  (83, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.355422  |
# | zero_one_loss       | 0.614458  |
# | one_error           | 0.0963855 |
# | micro av. jaccard   | 0.358696  |
# | macro av. jaccard   | 0.198795  |
# | micro av. precision | 0.39759   |
# | macro av. precision | 0.198795  |
# | micro av. recall    | 0.785714  |
# | macro av. recall    | 0.5       |
# | micro av. f1        | 0.528     |
# | macro av. f1        | 0.284483  |
# | micro av. pr.       | 0.50171   |
# | macro av. pr.       | 0.40657   |
# | micro av. auc       | 0.767665  |
# | macro av. auc       | 0.677467  |
# | coverage error      | 0.60241   |
# | ranking loss        | 0.0963855 |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 2, e index: 4
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |         1 |
# |:--------------------|----------:|----------:|
# | hamming loss        | 0.355422  | 0.439759  |
# | zero_one_loss       | 0.614458  | 0.843373  |
# | one_error           | 0.0963855 | 0.0361446 |
# | micro av. jaccard   | 0.358696  | 0.151163  |
# | macro av. jaccard   | 0.198795  | 0.0783133 |
# | micro av. precision | 0.39759   | 0.156627  |
# | macro av. precision | 0.198795  | 0.0783133 |
# | micro av. recall    | 0.785714  | 0.8125    |
# | macro av. recall    | 0.5       | 0.5       |
# | micro av. f1        | 0.528     | 0.262626  |
# | macro av. f1        | 0.284483  | 0.135417  |
# | micro av. pr.       | 0.50171   | 0.169091  |
# | macro av. pr.       | 0.40657   | 0.105716  |
# | micro av. auc       | 0.767665  | 0.63625   |
# | macro av. auc       | 0.677467  | 0.267582  |
# | coverage error      | 0.60241   | 0.228916  |
# | ranking loss        | 0.0963855 | 0.0361446 |
#
# label index list [0, 2, 4, 6]
# Task: 2, s index: 4, e index: 6
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |         1 |        2 |
# |:--------------------|----------:|----------:|---------:|
# | hamming loss        | 0.355422  | 0.439759  | 0.246988 |
# | zero_one_loss       | 0.614458  | 0.843373  | 0.493976 |
# | one_error           | 0.0963855 | 0.0361446 | 0        |
# | micro av. jaccard   | 0.358696  | 0.151163  | 0        |
# | macro av. jaccard   | 0.198795  | 0.0783133 | 0        |
# | micro av. precision | 0.39759   | 0.156627  | 0        |
# | macro av. precision | 0.198795  | 0.0783133 | 0        |
# | micro av. recall    | 0.785714  | 0.8125    | 0        |
# | macro av. recall    | 0.5       | 0.5       | 0        |
# | micro av. f1        | 0.528     | 0.262626  | 0        |
# | macro av. f1        | 0.284483  | 0.135417  | 0        |
# | micro av. pr.       | 0.50171   | 0.169091  | 0.200313 |
# | macro av. pr.       | 0.40657   | 0.105716  | 0.363977 |
# | micro av. auc       | 0.767665  | 0.63625   | 0.369756 |
# | macro av. auc       | 0.677467  | 0.267582  | 0.65423  |
# | coverage error      | 0.60241   | 0.228916  | 0.903614 |
# | ranking loss        | 0.0963855 | 0.0361446 | 0.409639 |
#
# Individual Task Results
# |                     |         0 |         1 |        2 |
# |:--------------------|----------:|----------:|---------:|
# | hamming loss        | 0.355422  | 0.439759  | 0.246988 |
# | zero_one_loss       | 0.614458  | 0.843373  | 0.493976 |
# | one_error           | 0.0963855 | 0.0361446 | 0        |
# | micro av. jaccard   | 0.358696  | 0.151163  | 0        |
# | macro av. jaccard   | 0.198795  | 0.0783133 | 0        |
# | micro av. precision | 0.39759   | 0.156627  | 0        |
# | macro av. precision | 0.198795  | 0.0783133 | 0        |
# | micro av. recall    | 0.785714  | 0.8125    | 0        |
# | macro av. recall    | 0.5       | 0.5       | 0        |
# | micro av. f1        | 0.528     | 0.262626  | 0        |
# | macro av. f1        | 0.284483  | 0.135417  | 0        |
# | micro av. pr.       | 0.50171   | 0.169091  | 0.200313 |
# | macro av. pr.       | 0.40657   | 0.105716  | 0.363977 |
# | micro av. auc       | 0.767665  | 0.63625   | 0.369756 |
# | macro av. auc       | 0.677467  | 0.267582  | 0.65423  |
# | coverage error      | 0.60241   | 0.228916  | 0.903614 |
# | ranking loss        | 0.0963855 | 0.0361446 | 0.409639 |
#
# ======================== Final Result ========================
# output shape =  (83, 6)
# ground truth shape =  (83, 6)
# Evaluation mode is incremental
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.355422  |
# | zero_one_loss       | 0.614458  |
# | one_error           | 0.0963855 |
# | micro av. jaccard   | 0.358696  |
# | macro av. jaccard   | 0.198795  |
# | micro av. precision | 0.39759   |
# | macro av. precision | 0.198795  |
# | micro av. recall    | 0.785714  |
# | macro av. recall    | 0.5       |
# | micro av. f1        | 0.528     |
# | macro av. f1        | 0.284483  |
# | micro av. pr.       | 0.50171   |
# | macro av. pr.       | 0.40657   |
# | micro av. auc       | 0.767665  |
# | macro av. auc       | 0.677467  |
# | coverage error      | 0.60241   |
# | ranking loss        | 0.0963855 |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 0, e index: 4
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |        1 |
# |:--------------------|----------:|---------:|
# | hamming loss        | 0.355422  | 0.39759  |
# | zero_one_loss       | 0.614458  | 1        |
# | one_error           | 0.0963855 | 0        |
# | micro av. jaccard   | 0.358696  | 0.258427 |
# | macro av. jaccard   | 0.198795  | 0.138554 |
# | micro av. precision | 0.39759   | 0.277108 |
# | macro av. precision | 0.198795  | 0.138554 |
# | micro av. recall    | 0.785714  | 0.793103 |
# | macro av. recall    | 0.5       | 0.5      |
# | micro av. f1        | 0.528     | 0.410714 |
# | macro av. f1        | 0.284483  | 0.20995  |
# | micro av. pr.       | 0.50171   | 0.433299 |
# | macro av. pr.       | 0.40657   | 0.256143 |
# | micro av. auc       | 0.767665  | 0.764599 |
# | macro av. auc       | 0.677467  | 0.472524 |
# | coverage error      | 0.60241   | 1.14458  |
# | ranking loss        | 0.0963855 | 0.149598 |
#
# label index list [0, 2, 4, 6]
# Task: 2, s index: 0, e index: 6
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |        1 |         2 |
# |:--------------------|----------:|---------:|----------:|
# | hamming loss        | 0.355422  | 0.39759  | 0.34739   |
# | zero_one_loss       | 0.614458  | 1        | 1         |
# | one_error           | 0.0963855 | 0        | 0         |
# | micro av. jaccard   | 0.358696  | 0.258427 | 0.210046  |
# | macro av. jaccard   | 0.198795  | 0.138554 | 0.0923695 |
# | micro av. precision | 0.39759   | 0.277108 | 0.277108  |
# | macro av. precision | 0.198795  | 0.138554 | 0.0923695 |
# | micro av. recall    | 0.785714  | 0.793103 | 0.464646  |
# | macro av. recall    | 0.5       | 0.5      | 0.333333  |
# | micro av. f1        | 0.528     | 0.410714 | 0.34717   |
# | macro av. f1        | 0.284483  | 0.20995  | 0.139966  |
# | micro av. pr.       | 0.50171   | 0.433299 | 0.330674  |
# | macro av. pr.       | 0.40657   | 0.256143 | 0.292088  |
# | micro av. auc       | 0.767665  | 0.764599 | 0.544113  |
# | macro av. auc       | 0.677467  | 0.472524 | 0.533093  |
# | coverage error      | 0.60241   | 1.14458  | 3.73494   |
# | ranking loss        | 0.0963855 | 0.149598 | 0.470415  |
#
# Overall Task Results
# |                     |         0 |        1 |         2 |
# |:--------------------|----------:|---------:|----------:|
# | hamming loss        | 0.355422  | 0.39759  | 0.34739   |
# | zero_one_loss       | 0.614458  | 1        | 1         |
# | one_error           | 0.0963855 | 0        | 0         |
# | micro av. jaccard   | 0.358696  | 0.258427 | 0.210046  |
# | macro av. jaccard   | 0.198795  | 0.138554 | 0.0923695 |
# | micro av. precision | 0.39759   | 0.277108 | 0.277108  |
# | macro av. precision | 0.198795  | 0.138554 | 0.0923695 |
# | micro av. recall    | 0.785714  | 0.793103 | 0.464646  |
# | macro av. recall    | 0.5       | 0.5      | 0.333333  |
# | micro av. f1        | 0.528     | 0.410714 | 0.34717   |
# | macro av. f1        | 0.284483  | 0.20995  | 0.139966  |
# | micro av. pr.       | 0.50171   | 0.433299 | 0.330674  |
# | macro av. pr.       | 0.40657   | 0.256143 | 0.292088  |
# | micro av. auc       | 0.767665  | 0.764599 | 0.544113  |
# | macro av. auc       | 0.677467  | 0.472524 | 0.533093  |
# | coverage error      | 0.60241   | 1.14458  | 3.73494   |
# | ranking loss        | 0.0963855 | 0.149598 | 0.470415  |
# 866.3593170642853 s.

# %%
# !python3 main.py --name virus --shuffle 1 --seed 66 --device 3
# Out:
# data_name: virus.
# seed: 66.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (124, 446) (83, 446)
# torch.Size([83, 6])
# 0.19879518072289157
# task: 0, #samples: 32, #negative samples: 26, #positive samples: 0
# task: 1, #samples: 60, #negative samples: 30, #positive samples: 0
# task: 2, #samples: 32, #negative samples: 17, #positive samples: 0
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:42<00:00,  2.57s/it]
# The task 0 result is following:
# output shape =  (83, 4)
# ground truth shape =  (83, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.060241 |
# | zero_one_loss       | 0.120482 |
# | one_error           | 0        |
# | micro av. jaccard   | 0        |
# | macro av. jaccard   | 0        |
# | micro av. precision | 0        |
# | macro av. precision | 0        |
# | micro av. recall    | 0        |
# | macro av. recall    | 0        |
# | micro av. f1        | 0        |
# | macro av. f1        | 0        |
# | micro av. pr.       | 0.239965 |
# | macro av. pr.       | 0.642947 |
# | micro av. auc       | 0.807692 |
# | macro av. auc       | 0.883459 |
# | coverage error      | 0.120482 |
# | ranking loss        | 0        |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:18<00:00,  3.77s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.060241 |
# | zero_one_loss       | 0.120482 |
# | one_error           | 0        |
# | micro av. jaccard   | 0        |
# | macro av. jaccard   | 0        |
# | micro av. precision | 0        |
# | macro av. precision | 0        |
# | micro av. recall    | 0        |
# | macro av. recall    | 0        |
# | micro av. f1        | 0        |
# | macro av. f1        | 0        |
# | micro av. pr.       | 0.239965 |
# | macro av. pr.       | 0.642947 |
# | micro av. auc       | 0.807692 |
# | macro av. auc       | 0.883459 |
# | coverage error      | 0.120482 |
# | ranking loss        | 0        |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (83, 4)
# ground truth shape =  (83, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.060241 |
# | zero_one_loss       | 0.120482 |
# | one_error           | 0        |
# | micro av. jaccard   | 0        |
# | macro av. jaccard   | 0        |
# | micro av. precision | 0        |
# | macro av. precision | 0        |
# | micro av. recall    | 0        |
# | macro av. recall    | 0        |
# | micro av. f1        | 0        |
# | macro av. f1        | 0        |
# | micro av. pr.       | 0.271416 |
# | macro av. pr.       | 0.646022 |
# | micro av. auc       | 0.866667 |
# | macro av. auc       | 0.889098 |
# | coverage error      | 0.120482 |
# | ranking loss        | 0        |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 2, e index: 4
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |         1 |
# |:--------------------|---------:|----------:|
# | hamming loss        | 0.060241 | 0.259036  |
# | zero_one_loss       | 0.120482 | 0.493976  |
# | one_error           | 0        | 0.0240964 |
# | micro av. jaccard   | 0        | 0         |
# | macro av. jaccard   | 0        | 0         |
# | micro av. precision | 0        | 0         |
# | macro av. precision | 0        | 0         |
# | micro av. recall    | 0        | 0         |
# | macro av. recall    | 0        | 0         |
# | micro av. f1        | 0        | 0         |
# | macro av. f1        | 0        | 0         |
# | micro av. pr.       | 0.271416 | 0.201873  |
# | macro av. pr.       | 0.646022 | 0.240128  |
# | micro av. auc       | 0.866667 | 0.356778  |
# | macro av. auc       | 0.889098 | 0.418339  |
# | coverage error      | 0.120482 | 0.843373  |
# | ranking loss        | 0        | 0.325301  |
#
# Beginning compression, old model output size = 2
# Inter end shape =  4
# Old model output shape = 4
# Train single mode Epoch: 100%|██████████████████| 15/15 [00:55<00:00,  3.72s/it]
# Old model output shape =  4
# Train single mode Epoch: 100%|██████████████████| 40/40 [02:30<00:00,  3.76s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:18<00:00,  3.79s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |         1 |
# |:--------------------|---------:|----------:|
# | hamming loss        | 0.060241 | 0.259036  |
# | zero_one_loss       | 0.120482 | 0.493976  |
# | one_error           | 0        | 0.0240964 |
# | micro av. jaccard   | 0        | 0         |
# | macro av. jaccard   | 0        | 0         |
# | micro av. precision | 0        | 0         |
# | macro av. precision | 0        | 0         |
# | micro av. recall    | 0        | 0         |
# | macro av. recall    | 0        | 0         |
# | micro av. f1        | 0        | 0         |
# | macro av. f1        | 0        | 0         |
# | micro av. pr.       | 0.271416 | 0.201873  |
# | macro av. pr.       | 0.646022 | 0.240128  |
# | micro av. auc       | 0.866667 | 0.356778  |
# | macro av. auc       | 0.889098 | 0.418339  |
# | coverage error      | 0.120482 | 0.843373  |
# | ranking loss        | 0        | 0.325301  |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (83, 6)
# ground truth shape =  (83, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.475904  |
# | zero_one_loss       | 0.915663  |
# | one_error           | 0.0361446 |
# | micro av. jaccard   | 0.0813953 |
# | macro av. jaccard   | 0.0421687 |
# | micro av. precision | 0.0843373 |
# | macro av. precision | 0.0421687 |
# | micro av. recall    | 0.7       |
# | macro av. recall    | 0.5       |
# | micro av. f1        | 0.150538  |
# | macro av. f1        | 0.0777778 |
# | micro av. pr.       | 0.0584997 |
# | macro av. pr.       | 0.0427718 |
# | micro av. auc       | 0.449359  |
# | macro av. auc       | 0.157675  |
# | coverage error      | 0.156627  |
# | ranking loss        | 0.0361446 |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 2, e index: 4
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |         1 |
# |:--------------------|----------:|----------:|
# | hamming loss        | 0.475904  | 0.349398  |
# | zero_one_loss       | 0.915663  | 0.614458  |
# | one_error           | 0.0361446 | 0.0843373 |
# | micro av. jaccard   | 0.0813953 | 0.369565  |
# | macro av. jaccard   | 0.0421687 | 0.204819  |
# | micro av. precision | 0.0843373 | 0.409639  |
# | macro av. precision | 0.0421687 | 0.204819  |
# | micro av. recall    | 0.7       | 0.790698  |
# | macro av. recall    | 0.5       | 0.5       |
# | micro av. f1        | 0.150538  | 0.539683  |
# | macro av. f1        | 0.0777778 | 0.290598  |
# | micro av. pr.       | 0.0584997 | 0.433797  |
# | macro av. pr.       | 0.0427718 | 0.323358  |
# | micro av. auc       | 0.449359  | 0.721308  |
# | macro av. auc       | 0.157675  | 0.584979  |
# | coverage error      | 0.156627  | 0.60241   |
# | ranking loss        | 0.0361446 | 0.0843373 |
#
# label index list [0, 2, 4, 6]
# Task: 2, s index: 4, e index: 6
# The test shape is (83, 6).
# |                     |         0 |         1 |        2 |
# |:--------------------|----------:|----------:|---------:|
# | hamming loss        | 0.475904  | 0.349398  | 0.548193 |
# | zero_one_loss       | 0.915663  | 0.614458  | 0.831325 |
# | one_error           | 0.0361446 | 0.0843373 | 0.26506  |
# | micro av. jaccard   | 0.0813953 | 0.369565  | 0.272    |
# | macro av. jaccard   | 0.0421687 | 0.204819  | 0.303166 |
# | micro av. precision | 0.0843373 | 0.409639  | 0.300885 |
# | macro av. precision | 0.0421687 | 0.204819  | 0.376082 |
# | micro av. recall    | 0.7       | 0.790698  | 0.73913  |
# | macro av. recall    | 0.5       | 0.5       | 0.818182 |
# | micro av. f1        | 0.150538  | 0.539683  | 0.427673 |
# | macro av. f1        | 0.0777778 | 0.290598  | 0.448792 |
# | micro av. pr.       | 0.0584997 | 0.433797  | 0.310461 |
# | macro av. pr.       | 0.0427718 | 0.323358  | 0.457479 |
# | micro av. auc       | 0.449359  | 0.721308  | 0.519565 |
# | macro av. auc       | 0.157675  | 0.584979  | 0.692168 |
# | coverage error      | 0.156627  | 0.60241   | 0.855422 |
# | ranking loss        | 0.0361446 | 0.0843373 | 0.301205 |
#
# Individual Task Results
# |                     |         0 |         1 |        2 |
# |:--------------------|----------:|----------:|---------:|
# | hamming loss        | 0.475904  | 0.349398  | 0.548193 |
# | zero_one_loss       | 0.915663  | 0.614458  | 0.831325 |
# | one_error           | 0.0361446 | 0.0843373 | 0.26506  |
# | micro av. jaccard   | 0.0813953 | 0.369565  | 0.272    |
# | macro av. jaccard   | 0.0421687 | 0.204819  | 0.303166 |
# | micro av. precision | 0.0843373 | 0.409639  | 0.300885 |
# | macro av. precision | 0.0421687 | 0.204819  | 0.376082 |
# | micro av. recall    | 0.7       | 0.790698  | 0.73913  |
# | macro av. recall    | 0.5       | 0.5       | 0.818182 |
# | micro av. f1        | 0.150538  | 0.539683  | 0.427673 |
# | macro av. f1        | 0.0777778 | 0.290598  | 0.448792 |
# | micro av. pr.       | 0.0584997 | 0.433797  | 0.310461 |
# | macro av. pr.       | 0.0427718 | 0.323358  | 0.457479 |
# | micro av. auc       | 0.449359  | 0.721308  | 0.519565 |
# | macro av. auc       | 0.157675  | 0.584979  | 0.692168 |
# | coverage error      | 0.156627  | 0.60241   | 0.855422 |
# | ranking loss        | 0.0361446 | 0.0843373 | 0.301205 |
#
# ======================== Final Result ========================
# output shape =  (83, 6)
# ground truth shape =  (83, 6)
# Evaluation mode is incremental
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.475904  |
# | zero_one_loss       | 0.915663  |
# | one_error           | 0.0361446 |
# | micro av. jaccard   | 0.0813953 |
# | macro av. jaccard   | 0.0421687 |
# | micro av. precision | 0.0843373 |
# | macro av. precision | 0.0421687 |
# | micro av. recall    | 0.7       |
# | macro av. recall    | 0.5       |
# | micro av. f1        | 0.150538  |
# | macro av. f1        | 0.0777778 |
# | micro av. pr.       | 0.0584997 |
# | macro av. pr.       | 0.0427718 |
# | micro av. auc       | 0.449359  |
# | macro av. auc       | 0.157675  |
# | coverage error      | 0.156627  |
# | ranking loss        | 0.0361446 |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 0, e index: 4
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |        1 |
# |:--------------------|----------:|---------:|
# | hamming loss        | 0.475904  | 0.412651 |
# | zero_one_loss       | 0.915663  | 1        |
# | one_error           | 0.0361446 | 0        |
# | micro av. jaccard   | 0.0813953 | 0.230337 |
# | macro av. jaccard   | 0.0421687 | 0.123494 |
# | micro av. precision | 0.0843373 | 0.246988 |
# | macro av. precision | 0.0421687 | 0.123494 |
# | micro av. recall    | 0.7       | 0.773585 |
# | macro av. recall    | 0.5       | 0.5      |
# | micro av. f1        | 0.150538  | 0.374429 |
# | macro av. f1        | 0.0777778 | 0.184188 |
# | micro av. pr.       | 0.0584997 | 0.36747  |
# | macro av. pr.       | 0.0427718 | 0.183065 |
# | micro av. auc       | 0.449359  | 0.715696 |
# | macro av. auc       | 0.157675  | 0.371327 |
# | coverage error      | 0.156627  | 1.07229  |
# | ranking loss        | 0.0361446 | 0.141566 |
#
# label index list [0, 2, 4, 6]
# Task: 2, s index: 0, e index: 6
# The test shape is (83, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |        1 |        2 |
# |:--------------------|----------:|---------:|---------:|
# | hamming loss        | 0.475904  | 0.412651 | 0.457831 |
# | zero_one_loss       | 0.915663  | 1        | 1        |
# | one_error           | 0.0361446 | 0        | 0        |
# | micro av. jaccard   | 0.0813953 | 0.230337 | 0.247525 |
# | macro av. jaccard   | 0.0421687 | 0.123494 | 0.183385 |
# | micro av. precision | 0.0843373 | 0.246988 | 0.268817 |
# | macro av. precision | 0.0421687 | 0.123494 | 0.20769  |
# | micro av. recall    | 0.7       | 0.773585 | 0.757576 |
# | macro av. recall    | 0.5       | 0.5      | 0.606061 |
# | micro av. f1        | 0.150538  | 0.374429 | 0.396825 |
# | macro av. f1        | 0.0777778 | 0.184188 | 0.272389 |
# | micro av. pr.       | 0.0584997 | 0.36747  | 0.315775 |
# | macro av. pr.       | 0.0427718 | 0.183065 | 0.274536 |
# | micro av. auc       | 0.449359  | 0.715696 | 0.657958 |
# | macro av. auc       | 0.157675  | 0.371327 | 0.478274 |
# | coverage error      | 0.156627  | 1.07229  | 3.01205  |
# | ranking loss        | 0.0361446 | 0.141566 | 0.34585  |
#
# Overall Task Results
# |                     |         0 |        1 |        2 |
# |:--------------------|----------:|---------:|---------:|
# | hamming loss        | 0.475904  | 0.412651 | 0.457831 |
# | zero_one_loss       | 0.915663  | 1        | 1        |
# | one_error           | 0.0361446 | 0        | 0        |
# | micro av. jaccard   | 0.0813953 | 0.230337 | 0.247525 |
# | macro av. jaccard   | 0.0421687 | 0.123494 | 0.183385 |
# | micro av. precision | 0.0843373 | 0.246988 | 0.268817 |
# | macro av. precision | 0.0421687 | 0.123494 | 0.20769  |
# | micro av. recall    | 0.7       | 0.773585 | 0.757576 |
# | macro av. recall    | 0.5       | 0.5      | 0.606061 |
# | micro av. f1        | 0.150538  | 0.374429 | 0.396825 |
# | macro av. f1        | 0.0777778 | 0.184188 | 0.272389 |
# | micro av. pr.       | 0.0584997 | 0.36747  | 0.315775 |
# | macro av. pr.       | 0.0427718 | 0.183065 | 0.274536 |
# | micro av. auc       | 0.449359  | 0.715696 | 0.657958 |
# | macro av. auc       | 0.157675  | 0.371327 | 0.478274 |
# | coverage error      | 0.156627  | 1.07229  | 3.01205  |
# | ranking loss        | 0.0361446 | 0.141566 | 0.34585  |
# 805.4114396572113 s.
