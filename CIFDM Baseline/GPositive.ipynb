# %%
# !python3 main.py --name gpositive --shuffle 1 --seed 2 --device 0
# Out:
# data_name: gpositive.
# seed: 2.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (311, 444) (208, 444)
# torch.Size([208, 4])
# 0.2512019230769231
# task: 0, #samples: 105, #negative samples: 48, #positive samples: 0
# task: 1, #samples: 103, #negative samples: 64, #positive samples: 39
# task: 2, #samples: 103, #negative samples: 103, #positive samples: 0
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [00:50<00:00,  1.25s/it]
# The task 0 result is following:
# output shape =  (208, 3)
# ground truth shape =  (208, 4)
# Evaluation mode is single
# label index list [0, 2, 3, 4]
# Task: 0, s index: 0, e index: 2
# The test shape is (208, 4).
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.398844 |
# | micro av. precision | 0.560976 |
# | micro av. recall    | 0.579832 |
# | micro av. f1        | 0.570248 |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:08<00:00,  1.76s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.398844 |
# | micro av. precision | 0.560976 |
# | micro av. recall    | 0.579832 |
# | micro av. f1        | 0.570248 |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (208, 3)
# ground truth shape =  (208, 4)
# Evaluation mode is single
# label index list [0, 2, 3, 4]
# Task: 0, s index: 0, e index: 2
# The test shape is (208, 4).
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.377246 |
# | micro av. precision | 0.567568 |
# | micro av. recall    | 0.529412 |
# | micro av. f1        | 0.547826 |
#
# label index list [0, 2, 3, 4]
# Task: 1, s index: 2, e index: 3
# The test shape is (208, 4).
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | micro av. jaccard   | 0.377246 | 0.429553 |
# | micro av. precision | 0.567568 | 0.600962 |
# | micro av. recall    | 0.529412 | 0.600962 |
# | micro av. f1        | 0.547826 | 0.600962 |
#
# Beginning compression, old model output size = 2
# Inter end shape =  3
# Old model output shape = 3
# Train single mode Epoch: 100%|██████████████████| 15/15 [00:26<00:00,  1.75s/it]
# Old model output shape =  3
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:09<00:00,  1.74s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:08<00:00,  1.77s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | micro av. jaccard   | 0.377246 | 0.429553 |
# | micro av. precision | 0.567568 | 0.600962 |
# | micro av. recall    | 0.529412 | 0.600962 |
# | micro av. f1        | 0.547826 | 0.600962 |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (208, 4)
# ground truth shape =  (208, 4)
# Evaluation mode is single
# label index list [0, 2, 3, 4]
# Task: 0, s index: 0, e index: 2
# The test shape is (208, 4).
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.272374 |
# | micro av. precision | 0.336538 |
# | micro av. recall    | 0.588235 |
# | micro av. f1        | 0.428135 |
#
# label index list [0, 2, 3, 4]
# Task: 1, s index: 2, e index: 3
# The test shape is (208, 4).
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | micro av. jaccard   | 0.272374 | 0.249249 |
# | micro av. precision | 0.336538 | 0.399038 |
# | micro av. recall    | 0.588235 | 0.399038 |
# | micro av. f1        | 0.428135 | 0.399038 |
#
# label index list [0, 2, 3, 4]
# Task: 2, s index: 3, e index: 4
# The test shape is (208, 4).
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | micro av. jaccard   | 0.272374 | 0.249249 | 0.934884 |
# | micro av. precision | 0.336538 | 0.399038 | 0.966346 |
# | micro av. recall    | 0.588235 | 0.399038 | 0.966346 |
# | micro av. f1        | 0.428135 | 0.399038 | 0.966346 |
#
# Individual Task Results
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | micro av. jaccard   | 0.272374 | 0.249249 | 0.934884 |
# | micro av. precision | 0.336538 | 0.399038 | 0.966346 |
# | micro av. recall    | 0.588235 | 0.399038 | 0.966346 |
# | micro av. f1        | 0.428135 | 0.399038 | 0.966346 |
#
# ======================== Final Result ========================
# output shape =  (208, 4)
# ground truth shape =  (208, 4)
# Evaluation mode is incremental
# label index list [0, 2, 3, 4]
# Task: 0, s index: 0, e index: 2
# The test shape is (208, 4).
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.272374 |
# | micro av. precision | 0.336538 |
# | micro av. recall    | 0.588235 |
# | micro av. f1        | 0.428135 |
#
# label index list [0, 2, 3, 4]
# Task: 1, s index: 0, e index: 3
# The test shape is (208, 4).
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | micro av. jaccard   | 0.272374 | 0.329032 |
# | micro av. precision | 0.336538 | 0.367788 |
# | micro av. recall    | 0.588235 | 0.757426 |
# | micro av. f1        | 0.428135 | 0.495146 |
#
# label index list [0, 2, 3, 4]
# Task: 2, s index: 0, e index: 4
# The test shape is (208, 4).
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | micro av. jaccard   | 0.272374 | 0.329032 | 0.324153 |
# | micro av. precision | 0.336538 | 0.367788 | 0.367788 |
# | micro av. recall    | 0.588235 | 0.757426 | 0.732057 |
# | micro av. f1        | 0.428135 | 0.495146 | 0.4896   |
#
# Overall Task Results
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | micro av. jaccard   | 0.272374 | 0.329032 | 0.324153 |
# | micro av. precision | 0.336538 | 0.367788 | 0.367788 |
# | micro av. recall    | 0.588235 | 0.757426 | 0.732057 |
# | micro av. f1        | 0.428135 | 0.495146 | 0.4896   |
# 398.3803057670593 s.

# %%
# !python3 main.py --name gpositive --shuffle 1 --seed 4 --device 0
# Out:
# data_name: gpositive.
# seed: 4.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (311, 444) (208, 444)
# torch.Size([208, 4])
# 0.2512019230769231
# task: 0, #samples: 105, #negative samples: 65, #positive samples: 0
# task: 1, #samples: 103, #negative samples: 81, #positive samples: 22
# task: 2, #samples: 103, #negative samples: 65, #positive samples: 38
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [00:49<00:00,  1.25s/it]
# The task 0 result is following:
# output shape =  (208, 3)
# ground truth shape =  (208, 4)
# Evaluation mode is single
# label index list [0, 2, 3, 4]
# Task: 0, s index: 0, e index: 2
# The test shape is (208, 4).
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.660714 |
# | micro av. precision | 0.770833 |
# | micro av. recall    | 0.822222 |
# | micro av. f1        | 0.795699 |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:09<00:00,  1.90s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.660714 |
# | micro av. precision | 0.770833 |
# | micro av. recall    | 0.822222 |
# | micro av. f1        | 0.795699 |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (208, 3)
# ground truth shape =  (208, 4)
# Evaluation mode is single
# label index list [0, 2, 3, 4]
# Task: 0, s index: 0, e index: 2
# The test shape is (208, 4).
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.152174 |
# | micro av. precision | 0.875    |
# | micro av. recall    | 0.155556 |
# | micro av. f1        | 0.264151 |
#
# label index list [0, 2, 3, 4]
# Task: 1, s index: 2, e index: 3
# The test shape is (208, 4).
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | micro av. jaccard   | 0.152174 | 0.175141 |
# | micro av. precision | 0.875    | 0.298077 |
# | micro av. recall    | 0.155556 | 0.298077 |
# | micro av. f1        | 0.264151 | 0.298077 |
#
# Beginning compression, old model output size = 2
# Inter end shape =  3
# Old model output shape = 3
# Train single mode Epoch: 100%|██████████████████| 15/15 [00:27<00:00,  1.84s/it]
# Old model output shape =  3
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:13<00:00,  1.84s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:09<00:00,  1.89s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | micro av. jaccard   | 0.152174 | 0.175141 |
# | micro av. precision | 0.875    | 0.298077 |
# | micro av. recall    | 0.155556 | 0.298077 |
# | micro av. f1        | 0.264151 | 0.298077 |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (208, 4)
# ground truth shape =  (208, 4)
# Evaluation mode is single
# label index list [0, 2, 3, 4]
# Task: 0, s index: 0, e index: 2
# The test shape is (208, 4).
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.386047 |
# | micro av. precision | 0.399038 |
# | micro av. recall    | 0.922222 |
# | micro av. f1        | 0.557047 |
#
# label index list [0, 2, 3, 4]
# Task: 1, s index: 2, e index: 3
# The test shape is (208, 4).
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | micro av. jaccard   | 0.386047 | 0.133515 |
# | micro av. precision | 0.399038 | 0.235577 |
# | micro av. recall    | 0.922222 | 0.235577 |
# | micro av. f1        | 0.557047 | 0.235577 |
#
# label index list [0, 2, 3, 4]
# Task: 2, s index: 3, e index: 4
# The test shape is (208, 4).
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | micro av. jaccard   | 0.386047 | 0.133515 | 0.202312 |
# | micro av. precision | 0.399038 | 0.235577 | 0.336538 |
# | micro av. recall    | 0.922222 | 0.235577 | 0.336538 |
# | micro av. f1        | 0.557047 | 0.235577 | 0.336538 |
#
# Individual Task Results
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | micro av. jaccard   | 0.386047 | 0.133515 | 0.202312 |
# | micro av. precision | 0.399038 | 0.235577 | 0.336538 |
# | micro av. recall    | 0.922222 | 0.235577 | 0.336538 |
# | micro av. f1        | 0.557047 | 0.235577 | 0.336538 |
#
# ======================== Final Result ========================
# output shape =  (208, 4)
# ground truth shape =  (208, 4)
# Evaluation mode is incremental
# label index list [0, 2, 3, 4]
# Task: 0, s index: 0, e index: 2
# The test shape is (208, 4).
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.386047 |
# | micro av. precision | 0.399038 |
# | micro av. recall    | 0.922222 |
# | micro av. f1        | 0.557047 |
#
# label index list [0, 2, 3, 4]
# Task: 1, s index: 0, e index: 3
# The test shape is (208, 4).
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | micro av. jaccard   | 0.386047 | 0.312057 |
# | micro av. precision | 0.399038 | 0.317308 |
# | micro av. recall    | 0.922222 | 0.94964  |
# | micro av. f1        | 0.557047 | 0.475676 |
#
# label index list [0, 2, 3, 4]
# Task: 2, s index: 0, e index: 4
# The test shape is (208, 4).
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | micro av. jaccard   | 0.386047 | 0.312057 | 0.320127 |
# | micro av. precision | 0.399038 | 0.317308 | 0.323718 |
# | micro av. recall    | 0.922222 | 0.94964  | 0.966507 |
# | micro av. f1        | 0.557047 | 0.475676 | 0.484994 |
#
# Overall Task Results
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | micro av. jaccard   | 0.386047 | 0.312057 | 0.320127 |
# | micro av. precision | 0.399038 | 0.317308 | 0.323718 |
# | micro av. recall    | 0.922222 | 0.94964  | 0.966507 |
# | micro av. f1        | 0.557047 | 0.475676 | 0.484994 |
# 410.8948018550873 s.

# %%
# !python3 main.py --name gpositive --shuffle 1 --seed 5 --device 0
# Out:
# data_name: gpositive.
# seed: 5.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (311, 444) (208, 444)
# torch.Size([208, 4])
# 0.2512019230769231
# task: 0, #samples: 105, #negative samples: 66, #positive samples: 0
# task: 1, #samples: 103, #negative samples: 80, #positive samples: 23
# task: 2, #samples: 103, #negative samples: 57, #positive samples: 46
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [00:54<00:00,  1.37s/it]
# The task 0 result is following:
# output shape =  (208, 3)
# ground truth shape =  (208, 4)
# Evaluation mode is single
# label index list [0, 2, 3, 4]
# Task: 0, s index: 0, e index: 2
# The test shape is (208, 4).
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.413462 |
# | micro av. precision | 0.614286 |
# | micro av. recall    | 0.558442 |
# | micro av. f1        | 0.585034 |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:10<00:00,  2.04s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.413462 |
# | micro av. precision | 0.614286 |
# | micro av. recall    | 0.558442 |
# | micro av. f1        | 0.585034 |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (208, 3)
# ground truth shape =  (208, 4)
# Evaluation mode is single
# label index list [0, 2, 3, 4]
# Task: 0, s index: 0, e index: 2
# The test shape is (208, 4).
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.43038  |
# | micro av. precision | 0.944444 |
# | micro av. recall    | 0.441558 |
# | micro av. f1        | 0.60177  |
#
# label index list [0, 2, 3, 4]
# Task: 1, s index: 2, e index: 3
# The test shape is (208, 4).
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | micro av. jaccard   | 0.43038  | 0.618677 |
# | micro av. precision | 0.944444 | 0.764423 |
# | micro av. recall    | 0.441558 | 0.764423 |
# | micro av. f1        | 0.60177  | 0.764423 |
#
# Beginning compression, old model output size = 2
# Inter end shape =  3
# Old model output shape = 3
# Train single mode Epoch: 100%|██████████████████| 15/15 [00:28<00:00,  1.88s/it]
# Old model output shape =  3
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:16<00:00,  1.91s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:09<00:00,  1.97s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | micro av. jaccard   | 0.43038  | 0.618677 |
# | micro av. precision | 0.944444 | 0.764423 |
# | micro av. recall    | 0.441558 | 0.764423 |
# | micro av. f1        | 0.60177  | 0.764423 |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (208, 4)
# ground truth shape =  (208, 4)
# Evaluation mode is single
# label index list [0, 2, 3, 4]
# Task: 0, s index: 0, e index: 2
# The test shape is (208, 4).
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.325581 |
# | micro av. precision | 0.336538 |
# | micro av. recall    | 0.909091 |
# | micro av. f1        | 0.491228 |
#
# label index list [0, 2, 3, 4]
# Task: 1, s index: 2, e index: 3
# The test shape is (208, 4).
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | micro av. jaccard   | 0.325581 | 0.133515 |
# | micro av. precision | 0.336538 | 0.235577 |
# | micro av. recall    | 0.909091 | 0.235577 |
# | micro av. f1        | 0.491228 | 0.235577 |
#
# label index list [0, 2, 3, 4]
# Task: 2, s index: 3, e index: 4
# The test shape is (208, 4).
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | micro av. jaccard   | 0.325581 | 0.133515 | 0.249249 |
# | micro av. precision | 0.336538 | 0.235577 | 0.399038 |
# | micro av. recall    | 0.909091 | 0.235577 | 0.399038 |
# | micro av. f1        | 0.491228 | 0.235577 | 0.399038 |
#
# Individual Task Results
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | micro av. jaccard   | 0.325581 | 0.133515 | 0.249249 |
# | micro av. precision | 0.336538 | 0.235577 | 0.399038 |
# | micro av. recall    | 0.909091 | 0.235577 | 0.399038 |
# | micro av. f1        | 0.491228 | 0.235577 | 0.399038 |
#
# ======================== Final Result ========================
# output shape =  (208, 4)
# ground truth shape =  (208, 4)
# Evaluation mode is incremental
# label index list [0, 2, 3, 4]
# Task: 0, s index: 0, e index: 2
# The test shape is (208, 4).
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.325581 |
# | micro av. precision | 0.336538 |
# | micro av. recall    | 0.909091 |
# | micro av. f1        | 0.491228 |
#
# label index list [0, 2, 3, 4]
# Task: 1, s index: 0, e index: 3
# The test shape is (208, 4).
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | micro av. jaccard   | 0.325581 | 0.281324 |
# | micro av. precision | 0.336538 | 0.286058 |
# | micro av. recall    | 0.909091 | 0.944444 |
# | micro av. f1        | 0.491228 | 0.439114 |
#
# label index list [0, 2, 3, 4]
# Task: 2, s index: 0, e index: 4
# The test shape is (208, 4).
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | micro av. jaccard   | 0.325581 | 0.281324 | 0.320127 |
# | micro av. precision | 0.336538 | 0.286058 | 0.323718 |
# | micro av. recall    | 0.909091 | 0.944444 | 0.966507 |
# | micro av. f1        | 0.491228 | 0.439114 | 0.484994 |
#
# Overall Task Results
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | micro av. jaccard   | 0.325581 | 0.281324 | 0.320127 |
# | micro av. precision | 0.336538 | 0.286058 | 0.323718 |
# | micro av. recall    | 0.909091 | 0.944444 | 0.966507 |
# | micro av. f1        | 0.491228 | 0.439114 | 0.484994 |
# 431.6629559993744 s.
