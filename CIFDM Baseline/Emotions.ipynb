# %%
# !python3 main.py --name emotions --shuffle 1 --seed 2 --device 1
# Out:
# data_name: emotions.
# seed: 2.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (391, 78) (202, 78)
# torch.Size([202, 6])
# 0.3292079207920792
# task: 0, #samples: 130, #negative samples: 53, #positive samples: 2
# task: 1, #samples: 130, #negative samples: 65, #positive samples: 26
# task: 2, #samples: 131, #negative samples: 66, #positive samples: 0
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:29<00:00,  2.24s/it]
# The task 0 result is following:
# output shape =  (202, 4)
# ground truth shape =  (202, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.289604 |
# | zero_one_loss       | 0.549505 |
# | one_error           | 0.029703 |
# | micro av. jaccard   | 0        |
# | macro av. jaccard   | 0        |
# | micro av. precision | 0        |
# | macro av. precision | 0        |
# | micro av. recall    | 0        |
# | macro av. recall    | 0        |
# | micro av. f1        | 0        |
# | macro av. f1        | 0        |
# | micro av. pr.       | 0.423227 |
# | macro av. pr.       | 0.440451 |
# | micro av. auc       | 0.577206 |
# | macro av. auc       | 0.6487   |
# | coverage error      | 0.841584 |
# | ranking loss        | 0.262376 |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:18<00:00,  3.70s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.289604 |
# | zero_one_loss       | 0.549505 |
# | one_error           | 0.029703 |
# | micro av. jaccard   | 0        |
# | macro av. jaccard   | 0        |
# | micro av. precision | 0        |
# | macro av. precision | 0        |
# | micro av. recall    | 0        |
# | macro av. recall    | 0        |
# | micro av. f1        | 0        |
# | macro av. f1        | 0        |
# | micro av. pr.       | 0.423227 |
# | macro av. pr.       | 0.440451 |
# | micro av. auc       | 0.577206 |
# | macro av. auc       | 0.6487   |
# | coverage error      | 0.841584 |
# | ranking loss        | 0.262376 |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (202, 4)
# ground truth shape =  (202, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.289604 |
# | zero_one_loss       | 0.549505 |
# | one_error           | 0.029703 |
# | micro av. jaccard   | 0        |
# | macro av. jaccard   | 0        |
# | micro av. precision | 0        |
# | macro av. precision | 0        |
# | micro av. recall    | 0        |
# | macro av. recall    | 0        |
# | micro av. f1        | 0        |
# | macro av. f1        | 0        |
# | micro av. pr.       | 0.423227 |
# | macro av. pr.       | 0.440451 |
# | micro av. auc       | 0.577206 |
# | macro av. auc       | 0.6487   |
# | coverage error      | 0.841584 |
# | ranking loss        | 0.262376 |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 2, e index: 4
# The test shape is (202, 6).
# |                     |        0 |         1 |
# |:--------------------|---------:|----------:|
# | hamming loss        | 0.289604 | 0.393564  |
# | zero_one_loss       | 0.549505 | 0.707921  |
# | one_error           | 0.029703 | 0.0792079 |
# | micro av. jaccard   | 0        | 0.430108  |
# | macro av. jaccard   | 0        | 0.403646  |
# | micro av. precision | 0        | 0.491803  |
# | macro av. precision | 0        | 0.497701  |
# | micro av. recall    | 0        | 0.774194  |
# | macro av. recall    | 0        | 0.719721  |
# | micro av. f1        | 0        | 0.601504  |
# | macro av. f1        | 0        | 0.571555  |
# | micro av. pr.       | 0.423227 | 0.579428  |
# | macro av. pr.       | 0.440451 | 0.533775  |
# | micro av. auc       | 0.577206 | 0.697033  |
# | macro av. auc       | 0.6487   | 0.698135  |
# | coverage error      | 0.841584 | 0.881188  |
# | ranking loss        | 0.262376 | 0.113861  |
#
# Beginning compression, old model output size = 2
# Inter end shape =  4
# Old model output shape = 4
# Train single mode Epoch: 100%|██████████████████| 15/15 [01:01<00:00,  4.10s/it]
# Old model output shape =  4
# Train single mode Epoch: 100%|██████████████████| 40/40 [02:41<00:00,  4.04s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:19<00:00,  4.00s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |         1 |
# |:--------------------|---------:|----------:|
# | hamming loss        | 0.289604 | 0.393564  |
# | zero_one_loss       | 0.549505 | 0.707921  |
# | one_error           | 0.029703 | 0.0792079 |
# | micro av. jaccard   | 0        | 0.430108  |
# | macro av. jaccard   | 0        | 0.403646  |
# | micro av. precision | 0        | 0.491803  |
# | macro av. precision | 0        | 0.497701  |
# | micro av. recall    | 0        | 0.774194  |
# | macro av. recall    | 0        | 0.719721  |
# | micro av. f1        | 0        | 0.601504  |
# | macro av. f1        | 0        | 0.571555  |
# | micro av. pr.       | 0.423227 | 0.579428  |
# | macro av. pr.       | 0.440451 | 0.533775  |
# | micro av. auc       | 0.577206 | 0.697033  |
# | macro av. auc       | 0.6487   | 0.698135  |
# | coverage error      | 0.841584 | 0.881188  |
# | ranking loss        | 0.262376 | 0.113861  |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (202, 6)
# ground truth shape =  (202, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.502475 |
# | zero_one_loss       | 0.742574 |
# | one_error           | 0.262376 |
# | micro av. jaccard   | 0.222222 |
# | macro av. jaccard   | 0.143564 |
# | micro av. precision | 0.287129 |
# | macro av. precision | 0.143564 |
# | micro av. recall    | 0.495726 |
# | macro av. recall    | 0.5      |
# | micro av. f1        | 0.363636 |
# | macro av. f1        | 0.223077 |
# | micro av. pr.       | 0.236669 |
# | macro av. pr.       | 0.246211 |
# | micro av. auc       | 0.421409 |
# | macro av. auc       | 0.347994 |
# | coverage error      | 0.841584 |
# | ranking loss        | 0.262376 |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 2, e index: 4
# The test shape is (202, 6).
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | hamming loss        | 0.502475 | 0.517327 |
# | zero_one_loss       | 0.742574 | 0.757426 |
# | one_error           | 0.262376 | 0.277228 |
# | micro av. jaccard   | 0.222222 | 0.336508 |
# | macro av. jaccard   | 0.143564 | 0.281872 |
# | micro av. precision | 0.287129 | 0.398496 |
# | macro av. precision | 0.143564 | 0.315749 |
# | micro av. recall    | 0.495726 | 0.683871 |
# | macro av. recall    | 0.5      | 0.584746 |
# | micro av. f1        | 0.363636 | 0.503563 |
# | macro av. f1        | 0.223077 | 0.403448 |
# | micro av. pr.       | 0.236669 | 0.591809 |
# | macro av. pr.       | 0.246211 | 0.468284 |
# | micro av. auc       | 0.421409 | 0.634538 |
# | macro av. auc       | 0.347994 | 0.558133 |
# | coverage error      | 0.841584 | 0.871287 |
# | ranking loss        | 0.262376 | 0.10396  |
#
# label index list [0, 2, 4, 6]
# Task: 2, s index: 4, e index: 6
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | hamming loss        | 0.502475 | 0.517327 | 0.54703  |
# | zero_one_loss       | 0.742574 | 0.757426 | 0.762376 |
# | one_error           | 0.262376 | 0.277228 | 0.331683 |
# | micro av. jaccard   | 0.222222 | 0.336508 | 0.196364 |
# | macro av. jaccard   | 0.143564 | 0.281872 | 0.133663 |
# | micro av. precision | 0.287129 | 0.398496 | 0.267327 |
# | macro av. precision | 0.143564 | 0.315749 | 0.133663 |
# | micro av. recall    | 0.495726 | 0.683871 | 0.425197 |
# | macro av. recall    | 0.5      | 0.584746 | 0.5      |
# | micro av. f1        | 0.363636 | 0.503563 | 0.328267 |
# | macro av. f1        | 0.223077 | 0.403448 | 0.210938 |
# | micro av. pr.       | 0.236669 | 0.591809 | 0.308263 |
# | macro av. pr.       | 0.246211 | 0.468284 | 0.363093 |
# | micro av. auc       | 0.421409 | 0.634538 | 0.474004 |
# | macro av. auc       | 0.347994 | 0.558133 | 0.552558 |
# | coverage error      | 0.841584 | 0.871287 | 0.960396 |
# | ranking loss        | 0.262376 | 0.10396  | 0.331683 |
#
# Individual Task Results
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | hamming loss        | 0.502475 | 0.517327 | 0.54703  |
# | zero_one_loss       | 0.742574 | 0.757426 | 0.762376 |
# | one_error           | 0.262376 | 0.277228 | 0.331683 |
# | micro av. jaccard   | 0.222222 | 0.336508 | 0.196364 |
# | macro av. jaccard   | 0.143564 | 0.281872 | 0.133663 |
# | micro av. precision | 0.287129 | 0.398496 | 0.267327 |
# | macro av. precision | 0.143564 | 0.315749 | 0.133663 |
# | micro av. recall    | 0.495726 | 0.683871 | 0.425197 |
# | macro av. recall    | 0.5      | 0.584746 | 0.5      |
# | micro av. f1        | 0.363636 | 0.503563 | 0.328267 |
# | macro av. f1        | 0.223077 | 0.403448 | 0.210938 |
# | micro av. pr.       | 0.236669 | 0.591809 | 0.308263 |
# | macro av. pr.       | 0.246211 | 0.468284 | 0.363093 |
# | micro av. auc       | 0.421409 | 0.634538 | 0.474004 |
# | macro av. auc       | 0.347994 | 0.558133 | 0.552558 |
# | coverage error      | 0.841584 | 0.871287 | 0.960396 |
# | ranking loss        | 0.262376 | 0.10396  | 0.331683 |
#
# ======================== Final Result ========================
# output shape =  (202, 6)
# ground truth shape =  (202, 6)
# Evaluation mode is incremental
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.502475 |
# | zero_one_loss       | 0.742574 |
# | one_error           | 0.262376 |
# | micro av. jaccard   | 0.222222 |
# | macro av. jaccard   | 0.143564 |
# | micro av. precision | 0.287129 |
# | macro av. precision | 0.143564 |
# | micro av. recall    | 0.495726 |
# | macro av. recall    | 0.5      |
# | micro av. f1        | 0.363636 |
# | macro av. f1        | 0.223077 |
# | micro av. pr.       | 0.236669 |
# | macro av. pr.       | 0.246211 |
# | micro av. auc       | 0.421409 |
# | macro av. auc       | 0.347994 |
# | coverage error      | 0.841584 |
# | ranking loss        | 0.262376 |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 0, e index: 4
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |         1 |
# |:--------------------|---------:|----------:|
# | hamming loss        | 0.502475 | 0.509901  |
# | zero_one_loss       | 0.742574 | 1         |
# | one_error           | 0.262376 | 0.0445545 |
# | micro av. jaccard   | 0.222222 | 0.284722  |
# | macro av. jaccard   | 0.143564 | 0.212718  |
# | micro av. precision | 0.287129 | 0.350427  |
# | macro av. precision | 0.143564 | 0.229657  |
# | micro av. recall    | 0.495726 | 0.602941  |
# | macro av. recall    | 0.5      | 0.542373  |
# | micro av. f1        | 0.363636 | 0.443243  |
# | macro av. f1        | 0.223077 | 0.313263  |
# | micro av. pr.       | 0.236669 | 0.346443  |
# | macro av. pr.       | 0.246211 | 0.357248  |
# | micro av. auc       | 0.421409 | 0.534395  |
# | macro av. auc       | 0.347994 | 0.453064  |
# | coverage error      | 0.841584 | 2.53465   |
# | ranking loss        | 0.262376 | 0.438119  |
#
# label index list [0, 2, 4, 6]
# Task: 2, s index: 0, e index: 6
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |         1 |        2 |
# |:--------------------|---------:|----------:|---------:|
# | hamming loss        | 0.502475 | 0.509901  | 0.522277 |
# | zero_one_loss       | 0.742574 | 1         | 1        |
# | one_error           | 0.262376 | 0.0445545 | 0        |
# | micro av. jaccard   | 0.222222 | 0.284722  | 0.256169 |
# | macro av. jaccard   | 0.143564 | 0.212718  | 0.186366 |
# | micro av. precision | 0.287129 | 0.350427  | 0.325373 |
# | macro av. precision | 0.143564 | 0.229657  | 0.197659 |
# | micro av. recall    | 0.495726 | 0.602941  | 0.546366 |
# | macro av. recall    | 0.5      | 0.542373  | 0.528249 |
# | micro av. f1        | 0.363636 | 0.443243  | 0.407858 |
# | macro av. f1        | 0.223077 | 0.313263  | 0.279154 |
# | micro av. pr.       | 0.236669 | 0.346443  | 0.318383 |
# | macro av. pr.       | 0.246211 | 0.357248  | 0.359196 |
# | micro av. auc       | 0.421409 | 0.534395  | 0.488847 |
# | macro av. auc       | 0.347994 | 0.453064  | 0.486228 |
# | coverage error      | 0.841584 | 2.53465   | 4.5      |
# | ranking loss        | 0.262376 | 0.438119  | 0.508952 |
#
# Overall Task Results
# |                     |        0 |         1 |        2 |
# |:--------------------|---------:|----------:|---------:|
# | hamming loss        | 0.502475 | 0.509901  | 0.522277 |
# | zero_one_loss       | 0.742574 | 1         | 1        |
# | one_error           | 0.262376 | 0.0445545 | 0        |
# | micro av. jaccard   | 0.222222 | 0.284722  | 0.256169 |
# | macro av. jaccard   | 0.143564 | 0.212718  | 0.186366 |
# | micro av. precision | 0.287129 | 0.350427  | 0.325373 |
# | macro av. precision | 0.143564 | 0.229657  | 0.197659 |
# | micro av. recall    | 0.495726 | 0.602941  | 0.546366 |
# | macro av. recall    | 0.5      | 0.542373  | 0.528249 |
# | micro av. f1        | 0.363636 | 0.443243  | 0.407858 |
# | macro av. f1        | 0.223077 | 0.313263  | 0.279154 |
# | micro av. pr.       | 0.236669 | 0.346443  | 0.318383 |
# | macro av. pr.       | 0.246211 | 0.357248  | 0.359196 |
# | micro av. auc       | 0.421409 | 0.534395  | 0.488847 |
# | macro av. auc       | 0.347994 | 0.453064  | 0.486228 |
# | coverage error      | 0.841584 | 2.53465   | 4.5      |
# | ranking loss        | 0.262376 | 0.438119  | 0.508952 |
# 873.7167842388153 s.

# %%
# !python3 main.py --name emotions --shuffle 1 --seed 3 --device 1
# Out:
# data_name: emotions.
# seed: 3.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (391, 78) (202, 78)
# torch.Size([202, 6])
# 0.3292079207920792
# task: 0, #samples: 130, #negative samples: 62, #positive samples: 25
# task: 1, #samples: 130, #negative samples: 62, #positive samples: 1
# task: 2, #samples: 131, #negative samples: 56, #positive samples: 2
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:35<00:00,  2.40s/it]
# The task 0 result is following:
# output shape =  (202, 4)
# ground truth shape =  (202, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.408416 |
# | zero_one_loss       | 0.712871 |
# | one_error           | 0.10396  |
# | micro av. jaccard   | 0.367816 |
# | macro av. jaccard   | 0.237624 |
# | micro av. precision | 0.475248 |
# | macro av. precision | 0.237624 |
# | micro av. recall    | 0.619355 |
# | macro av. recall    | 0.5      |
# | micro av. f1        | 0.537815 |
# | macro av. f1        | 0.322148 |
# | micro av. pr.       | 0.401866 |
# | macro av. pr.       | 0.340792 |
# | micro av. auc       | 0.551548 |
# | macro av. auc       | 0.410222 |
# | coverage error      | 0.871287 |
# | ranking loss        | 0.10396  |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:17<00:00,  3.48s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.408416 |
# | zero_one_loss       | 0.712871 |
# | one_error           | 0.10396  |
# | micro av. jaccard   | 0.367816 |
# | macro av. jaccard   | 0.237624 |
# | micro av. precision | 0.475248 |
# | macro av. precision | 0.237624 |
# | micro av. recall    | 0.619355 |
# | macro av. recall    | 0.5      |
# | micro av. f1        | 0.537815 |
# | macro av. f1        | 0.322148 |
# | micro av. pr.       | 0.401866 |
# | macro av. pr.       | 0.340792 |
# | micro av. auc       | 0.551548 |
# | macro av. auc       | 0.410222 |
# | coverage error      | 0.871287 |
# | ranking loss        | 0.10396  |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (202, 4)
# ground truth shape =  (202, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.383663 |
# | zero_one_loss       | 0.579208 |
# | one_error           | 0.188119 |
# | micro av. jaccard   | 0        |
# | macro av. jaccard   | 0        |
# | micro av. precision | 0        |
# | macro av. precision | 0        |
# | micro av. recall    | 0        |
# | macro av. recall    | 0        |
# | micro av. f1        | 0        |
# | macro av. f1        | 0        |
# | micro av. pr.       | 0.420996 |
# | macro av. pr.       | 0.354393 |
# | micro av. auc       | 0.568804 |
# | macro av. auc       | 0.4425   |
# | coverage error      | 0.871287 |
# | ranking loss        | 0.10396  |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 2, e index: 4
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | hamming loss        | 0.383663 | 0.54703  |
# | zero_one_loss       | 0.579208 | 0.762376 |
# | one_error           | 0.188119 | 0.331683 |
# | micro av. jaccard   | 0        | 0.196364 |
# | macro av. jaccard   | 0        | 0.133663 |
# | micro av. precision | 0        | 0.267327 |
# | macro av. precision | 0        | 0.133663 |
# | micro av. recall    | 0        | 0.425197 |
# | macro av. recall    | 0        | 0.5      |
# | micro av. f1        | 0        | 0.328267 |
# | macro av. f1        | 0        | 0.210938 |
# | micro av. pr.       | 0.420996 | 0.303823 |
# | macro av. pr.       | 0.354393 | 0.371255 |
# | micro av. auc       | 0.568804 | 0.474743 |
# | macro av. auc       | 0.4425   | 0.558795 |
# | coverage error      | 0.871287 | 0.960396 |
# | ranking loss        | 0.10396  | 0.331683 |
#
# Beginning compression, old model output size = 2
# Inter end shape =  4
# Old model output shape = 4
# Train single mode Epoch: 100%|██████████████████| 15/15 [00:51<00:00,  3.46s/it]
# Old model output shape =  4
# Train single mode Epoch: 100%|██████████████████| 40/40 [02:15<00:00,  3.39s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:16<00:00,  3.30s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | hamming loss        | 0.383663 | 0.54703  |
# | zero_one_loss       | 0.579208 | 0.762376 |
# | one_error           | 0.188119 | 0.331683 |
# | micro av. jaccard   | 0        | 0.196364 |
# | macro av. jaccard   | 0        | 0.133663 |
# | micro av. precision | 0        | 0.267327 |
# | macro av. precision | 0        | 0.133663 |
# | micro av. recall    | 0        | 0.425197 |
# | macro av. recall    | 0        | 0.5      |
# | micro av. f1        | 0        | 0.328267 |
# | macro av. f1        | 0        | 0.210938 |
# | micro av. pr.       | 0.420996 | 0.303823 |
# | macro av. pr.       | 0.354393 | 0.371255 |
# | micro av. auc       | 0.568804 | 0.474743 |
# | macro av. auc       | 0.4425   | 0.558795 |
# | coverage error      | 0.871287 | 0.960396 |
# | ranking loss        | 0.10396  | 0.331683 |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (202, 6)
# ground truth shape =  (202, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.408416 |
# | zero_one_loss       | 0.712871 |
# | one_error           | 0.10396  |
# | micro av. jaccard   | 0.367816 |
# | macro av. jaccard   | 0.237624 |
# | micro av. precision | 0.475248 |
# | macro av. precision | 0.237624 |
# | micro av. recall    | 0.619355 |
# | macro av. recall    | 0.5      |
# | micro av. f1        | 0.537815 |
# | macro av. f1        | 0.322148 |
# | micro av. pr.       | 0.427109 |
# | macro av. pr.       | 0.409101 |
# | micro av. auc       | 0.587123 |
# | macro av. auc       | 0.486647 |
# | coverage error      | 0.871287 |
# | ranking loss        | 0.10396  |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 2, e index: 4
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | hamming loss        | 0.408416 | 0.314356 |
# | zero_one_loss       | 0.712871 | 0.59901  |
# | one_error           | 0.10396  | 0.029703 |
# | micro av. jaccard   | 0.367816 | 0        |
# | macro av. jaccard   | 0.237624 | 0        |
# | micro av. precision | 0.475248 | 0        |
# | macro av. precision | 0.237624 | 0        |
# | micro av. recall    | 0.619355 | 0        |
# | macro av. recall    | 0.5      | 0        |
# | micro av. f1        | 0.537815 | 0        |
# | macro av. f1        | 0.322148 | 0        |
# | micro av. pr.       | 0.427109 | 0.274393 |
# | macro av. pr.       | 0.409101 | 0.321164 |
# | micro av. auc       | 0.587123 | 0.435601 |
# | macro av. auc       | 0.486647 | 0.473915 |
# | coverage error      | 0.871287 | 0.960396 |
# | ranking loss        | 0.10396  | 0.331683 |
#
# label index list [0, 2, 4, 6]
# Task: 2, s index: 4, e index: 6
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | hamming loss        | 0.408416 | 0.314356 | 0.50495  |
# | zero_one_loss       | 0.712871 | 0.59901  | 0.742574 |
# | one_error           | 0.10396  | 0.029703 | 0.267327 |
# | micro av. jaccard   | 0.367816 | 0        | 0.218391 |
# | macro av. jaccard   | 0.237624 | 0        | 0.141089 |
# | micro av. precision | 0.475248 | 0        | 0.283582 |
# | macro av. precision | 0.237624 | 0        | 0.141791 |
# | micro av. recall    | 0.619355 | 0        | 0.487179 |
# | macro av. recall    | 0.5      | 0        | 0.491379 |
# | micro av. f1        | 0.537815 | 0        | 0.358491 |
# | macro av. f1        | 0.322148 | 0        | 0.220077 |
# | micro av. pr.       | 0.427109 | 0.274393 | 0.283234 |
# | macro av. pr.       | 0.409101 | 0.321164 | 0.292463 |
# | micro av. auc       | 0.587123 | 0.435601 | 0.490515 |
# | macro av. auc       | 0.486647 | 0.473915 | 0.487286 |
# | coverage error      | 0.871287 | 0.960396 | 0.841584 |
# | ranking loss        | 0.10396  | 0.331683 | 0.262376 |
#
# Individual Task Results
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | hamming loss        | 0.408416 | 0.314356 | 0.50495  |
# | zero_one_loss       | 0.712871 | 0.59901  | 0.742574 |
# | one_error           | 0.10396  | 0.029703 | 0.267327 |
# | micro av. jaccard   | 0.367816 | 0        | 0.218391 |
# | macro av. jaccard   | 0.237624 | 0        | 0.141089 |
# | micro av. precision | 0.475248 | 0        | 0.283582 |
# | macro av. precision | 0.237624 | 0        | 0.141791 |
# | micro av. recall    | 0.619355 | 0        | 0.487179 |
# | macro av. recall    | 0.5      | 0        | 0.491379 |
# | micro av. f1        | 0.537815 | 0        | 0.358491 |
# | macro av. f1        | 0.322148 | 0        | 0.220077 |
# | micro av. pr.       | 0.427109 | 0.274393 | 0.283234 |
# | macro av. pr.       | 0.409101 | 0.321164 | 0.292463 |
# | micro av. auc       | 0.587123 | 0.435601 | 0.490515 |
# | macro av. auc       | 0.486647 | 0.473915 | 0.487286 |
# | coverage error      | 0.871287 | 0.960396 | 0.841584 |
# | ranking loss        | 0.10396  | 0.331683 | 0.262376 |
#
# ======================== Final Result ========================
# output shape =  (202, 6)
# ground truth shape =  (202, 6)
# Evaluation mode is incremental
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.408416 |
# | zero_one_loss       | 0.712871 |
# | one_error           | 0.10396  |
# | micro av. jaccard   | 0.367816 |
# | macro av. jaccard   | 0.237624 |
# | micro av. precision | 0.475248 |
# | macro av. precision | 0.237624 |
# | micro av. recall    | 0.619355 |
# | macro av. recall    | 0.5      |
# | micro av. f1        | 0.537815 |
# | macro av. f1        | 0.322148 |
# | micro av. pr.       | 0.427109 |
# | macro av. pr.       | 0.409101 |
# | micro av. auc       | 0.587123 |
# | macro av. auc       | 0.486647 |
# | coverage error      | 0.871287 |
# | ranking loss        | 0.10396  |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 0, e index: 4
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | hamming loss        | 0.408416 | 0.361386 |
# | zero_one_loss       | 0.712871 | 0.767327 |
# | one_error           | 0.10396  | 0        |
# | micro av. jaccard   | 0.367816 | 0.247423 |
# | macro av. jaccard   | 0.237624 | 0.118812 |
# | micro av. precision | 0.475248 | 0.475248 |
# | macro av. precision | 0.237624 | 0.118812 |
# | micro av. recall    | 0.619355 | 0.340426 |
# | macro av. recall    | 0.5      | 0.25     |
# | micro av. f1        | 0.537815 | 0.396694 |
# | macro av. f1        | 0.322148 | 0.161074 |
# | micro av. pr.       | 0.427109 | 0.392754 |
# | macro av. pr.       | 0.409101 | 0.365133 |
# | micro av. auc       | 0.587123 | 0.558099 |
# | macro av. auc       | 0.486647 | 0.480281 |
# | coverage error      | 0.871287 | 2.23267  |
# | ranking loss        | 0.10396  | 0.353548 |
#
# label index list [0, 2, 4, 6]
# Task: 2, s index: 0, e index: 6
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | hamming loss        | 0.408416 | 0.361386 | 0.409241 |
# | zero_one_loss       | 0.712871 | 0.767327 | 0.99505  |
# | one_error           | 0.10396  | 0        | 0        |
# | micro av. jaccard   | 0.367816 | 0.247423 | 0.235747 |
# | macro av. jaccard   | 0.237624 | 0.118812 | 0.126238 |
# | micro av. precision | 0.475248 | 0.475248 | 0.379653 |
# | macro av. precision | 0.237624 | 0.118812 | 0.126472 |
# | micro av. recall    | 0.619355 | 0.340426 | 0.383459 |
# | macro av. recall    | 0.5      | 0.25     | 0.33046  |
# | micro av. f1        | 0.537815 | 0.396694 | 0.381546 |
# | macro av. f1        | 0.322148 | 0.161074 | 0.180742 |
# | micro av. pr.       | 0.427109 | 0.392754 | 0.372115 |
# | macro av. pr.       | 0.409101 | 0.365133 | 0.340909 |
# | micro av. auc       | 0.587123 | 0.558099 | 0.544285 |
# | macro av. auc       | 0.486647 | 0.480281 | 0.482616 |
# | coverage error      | 0.871287 | 2.23267  | 4.22277  |
# | ranking loss        | 0.10396  | 0.353548 | 0.421411 |
#
# Overall Task Results
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | hamming loss        | 0.408416 | 0.361386 | 0.409241 |
# | zero_one_loss       | 0.712871 | 0.767327 | 0.99505  |
# | one_error           | 0.10396  | 0        | 0        |
# | micro av. jaccard   | 0.367816 | 0.247423 | 0.235747 |
# | macro av. jaccard   | 0.237624 | 0.118812 | 0.126238 |
# | micro av. precision | 0.475248 | 0.475248 | 0.379653 |
# | macro av. precision | 0.237624 | 0.118812 | 0.126472 |
# | micro av. recall    | 0.619355 | 0.340426 | 0.383459 |
# | macro av. recall    | 0.5      | 0.25     | 0.33046  |
# | micro av. f1        | 0.537815 | 0.396694 | 0.381546 |
# | macro av. f1        | 0.322148 | 0.161074 | 0.180742 |
# | micro av. pr.       | 0.427109 | 0.392754 | 0.372115 |
# | macro av. pr.       | 0.409101 | 0.365133 | 0.340909 |
# | micro av. auc       | 0.587123 | 0.558099 | 0.544285 |
# | macro av. auc       | 0.486647 | 0.480281 | 0.482616 |
# | coverage error      | 0.871287 | 2.23267  | 4.22277  |
# | ranking loss        | 0.10396  | 0.353548 | 0.421411 |
# 772.052426815033 s.

# %%
# !python3 main.py --name emotions --shuffle 1 --seed 4 --device 1
# Out:
# data_name: emotions.
# seed: 4.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (391, 78) (202, 78)
# torch.Size([202, 6])
# 0.3292079207920792
# task: 0, #samples: 130, #negative samples: 54, #positive samples: 21
# task: 1, #samples: 130, #negative samples: 57, #positive samples: 0
# task: 2, #samples: 131, #negative samples: 48, #positive samples: 2
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:26<00:00,  2.15s/it]
# The task 0 result is following:
# output shape =  (202, 4)
# ground truth shape =  (202, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.443069 |
# | zero_one_loss       | 0.69802  |
# | one_error           | 0.188119 |
# | micro av. jaccard   | 0.349091 |
# | macro av. jaccard   | 0.237624 |
# | micro av. precision | 0.475248 |
# | macro av. precision | 0.237624 |
# | micro av. recall    | 0.568047 |
# | macro av. recall    | 0.5      |
# | micro av. f1        | 0.51752  |
# | macro av. f1        | 0.322148 |
# | micro av. pr.       | 0.448554 |
# | macro av. pr.       | 0.419915 |
# | micro av. auc       | 0.546292 |
# | macro av. auc       | 0.476984 |
# | coverage error      | 1.02475  |
# | ranking loss        | 0.188119 |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:16<00:00,  3.35s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.443069 |
# | zero_one_loss       | 0.69802  |
# | one_error           | 0.188119 |
# | micro av. jaccard   | 0.349091 |
# | macro av. jaccard   | 0.237624 |
# | micro av. precision | 0.475248 |
# | macro av. precision | 0.237624 |
# | micro av. recall    | 0.568047 |
# | macro av. recall    | 0.5      |
# | micro av. f1        | 0.51752  |
# | macro av. f1        | 0.322148 |
# | micro av. pr.       | 0.448554 |
# | macro av. pr.       | 0.419915 |
# | micro av. auc       | 0.546292 |
# | macro av. auc       | 0.476984 |
# | coverage error      | 1.02475  |
# | ranking loss        | 0.188119 |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (202, 4)
# ground truth shape =  (202, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.443069 |
# | zero_one_loss       | 0.69802  |
# | one_error           | 0.188119 |
# | micro av. jaccard   | 0.349091 |
# | macro av. jaccard   | 0.237624 |
# | micro av. precision | 0.475248 |
# | macro av. precision | 0.237624 |
# | micro av. recall    | 0.568047 |
# | macro av. recall    | 0.5      |
# | micro av. f1        | 0.51752  |
# | macro av. f1        | 0.322148 |
# | micro av. pr.       | 0.448554 |
# | macro av. pr.       | 0.419915 |
# | micro av. auc       | 0.546292 |
# | macro av. auc       | 0.476984 |
# | coverage error      | 1.02475  |
# | ranking loss        | 0.188119 |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 2, e index: 4
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | hamming loss        | 0.443069 | 0.512376 |
# | zero_one_loss       | 0.69802  | 0.732673 |
# | one_error           | 0.188119 | 0.292079 |
# | micro av. jaccard   | 0.349091 | 0.206897 |
# | macro av. jaccard   | 0.237624 | 0.133663 |
# | micro av. precision | 0.475248 | 0.267327 |
# | macro av. precision | 0.237624 | 0.133663 |
# | micro av. recall    | 0.568047 | 0.477876 |
# | macro av. recall    | 0.5      | 0.5      |
# | micro av. f1        | 0.51752  | 0.342857 |
# | macro av. f1        | 0.322148 | 0.210938 |
# | micro av. pr.       | 0.448554 | 0.327448 |
# | macro av. pr.       | 0.419915 | 0.383521 |
# | micro av. auc       | 0.546292 | 0.533741 |
# | macro av. auc       | 0.476984 | 0.5993   |
# | coverage error      | 1.02475  | 0.851485 |
# | ranking loss        | 0.188119 | 0.292079 |
#
# Beginning compression, old model output size = 2
# Inter end shape =  4
# Old model output shape = 4
# Train single mode Epoch: 100%|██████████████████| 15/15 [00:51<00:00,  3.42s/it]
# Old model output shape =  4
# Train single mode Epoch: 100%|██████████████████| 40/40 [02:11<00:00,  3.30s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:16<00:00,  3.34s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | hamming loss        | 0.443069 | 0.512376 |
# | zero_one_loss       | 0.69802  | 0.732673 |
# | one_error           | 0.188119 | 0.292079 |
# | micro av. jaccard   | 0.349091 | 0.206897 |
# | macro av. jaccard   | 0.237624 | 0.133663 |
# | micro av. precision | 0.475248 | 0.267327 |
# | macro av. precision | 0.237624 | 0.133663 |
# | micro av. recall    | 0.568047 | 0.477876 |
# | macro av. recall    | 0.5      | 0.5      |
# | micro av. f1        | 0.51752  | 0.342857 |
# | macro av. f1        | 0.322148 | 0.210938 |
# | micro av. pr.       | 0.448554 | 0.327448 |
# | macro av. pr.       | 0.419915 | 0.383521 |
# | micro av. auc       | 0.546292 | 0.533741 |
# | macro av. auc       | 0.476984 | 0.5993   |
# | coverage error      | 1.02475  | 0.851485 |
# | ranking loss        | 0.188119 | 0.292079 |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (202, 6)
# ground truth shape =  (202, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.443069 |
# | zero_one_loss       | 0.69802  |
# | one_error           | 0.188119 |
# | micro av. jaccard   | 0.349091 |
# | macro av. jaccard   | 0.237624 |
# | micro av. precision | 0.475248 |
# | macro av. precision | 0.237624 |
# | micro av. recall    | 0.568047 |
# | macro av. recall    | 0.5      |
# | micro av. f1        | 0.51752  |
# | macro av. f1        | 0.322148 |
# | micro av. pr.       | 0.454874 |
# | macro av. pr.       | 0.471372 |
# | micro av. auc       | 0.581317 |
# | macro av. auc       | 0.549085 |
# | coverage error      | 1.02475  |
# | ranking loss        | 0.188119 |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 2, e index: 4
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | hamming loss        | 0.443069 | 0.279703 |
# | zero_one_loss       | 0.69802  | 0.559406 |
# | one_error           | 0.188119 | 0        |
# | micro av. jaccard   | 0.349091 | 0        |
# | macro av. jaccard   | 0.237624 | 0        |
# | micro av. precision | 0.475248 | 0        |
# | macro av. precision | 0.237624 | 0        |
# | micro av. recall    | 0.568047 | 0        |
# | macro av. recall    | 0.5      | 0        |
# | micro av. f1        | 0.51752  | 0        |
# | macro av. f1        | 0.322148 | 0        |
# | micro av. pr.       | 0.454874 | 0.348399 |
# | macro av. pr.       | 0.471372 | 0.412735 |
# | micro av. auc       | 0.581317 | 0.537056 |
# | macro av. auc       | 0.549085 | 0.585758 |
# | coverage error      | 1.02475  | 0.851485 |
# | ranking loss        | 0.188119 | 0.292079 |
#
# label index list [0, 2, 4, 6]
# Task: 2, s index: 4, e index: 6
# The test shape is (202, 6).
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | hamming loss        | 0.443069 | 0.279703 | 0.475248 |
# | zero_one_loss       | 0.69802  | 0.559406 | 0.732673 |
# | one_error           | 0.188119 | 0        | 0.217822 |
# | micro av. jaccard   | 0.349091 | 0        | 0.29927  |
# | macro av. jaccard   | 0.237624 | 0        | 0.2931   |
# | micro av. precision | 0.475248 | 0        | 0.343096 |
# | macro av. precision | 0.237624 | 0        | 0.375892 |
# | micro av. recall    | 0.568047 | 0        | 0.700855 |
# | macro av. recall    | 0.5      | 0        | 0.703244 |
# | micro av. f1        | 0.51752  | 0        | 0.460674 |
# | macro av. f1        | 0.322148 | 0        | 0.453017 |
# | micro av. pr.       | 0.454874 | 0.348399 | 0.418628 |
# | macro av. pr.       | 0.471372 | 0.412735 | 0.435718 |
# | micro av. auc       | 0.581317 | 0.537056 | 0.622234 |
# | macro av. auc       | 0.549085 | 0.585758 | 0.63557  |
# | coverage error      | 1.02475  | 0.851485 | 0.777228 |
# | ranking loss        | 0.188119 | 0.292079 | 0.19802  |
#
# Individual Task Results
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | hamming loss        | 0.443069 | 0.279703 | 0.475248 |
# | zero_one_loss       | 0.69802  | 0.559406 | 0.732673 |
# | one_error           | 0.188119 | 0        | 0.217822 |
# | micro av. jaccard   | 0.349091 | 0        | 0.29927  |
# | macro av. jaccard   | 0.237624 | 0        | 0.2931   |
# | micro av. precision | 0.475248 | 0        | 0.343096 |
# | macro av. precision | 0.237624 | 0        | 0.375892 |
# | micro av. recall    | 0.568047 | 0        | 0.700855 |
# | macro av. recall    | 0.5      | 0        | 0.703244 |
# | micro av. f1        | 0.51752  | 0        | 0.460674 |
# | macro av. f1        | 0.322148 | 0        | 0.453017 |
# | micro av. pr.       | 0.454874 | 0.348399 | 0.418628 |
# | macro av. pr.       | 0.471372 | 0.412735 | 0.435718 |
# | micro av. auc       | 0.581317 | 0.537056 | 0.622234 |
# | macro av. auc       | 0.549085 | 0.585758 | 0.63557  |
# | coverage error      | 1.02475  | 0.851485 | 0.777228 |
# | ranking loss        | 0.188119 | 0.292079 | 0.19802  |
#
# ======================== Final Result ========================
# output shape =  (202, 6)
# ground truth shape =  (202, 6)
# Evaluation mode is incremental
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.443069 |
# | zero_one_loss       | 0.69802  |
# | one_error           | 0.188119 |
# | micro av. jaccard   | 0.349091 |
# | macro av. jaccard   | 0.237624 |
# | micro av. precision | 0.475248 |
# | macro av. precision | 0.237624 |
# | micro av. recall    | 0.568047 |
# | macro av. recall    | 0.5      |
# | micro av. f1        | 0.51752  |
# | macro av. f1        | 0.322148 |
# | micro av. pr.       | 0.454874 |
# | macro av. pr.       | 0.471372 |
# | micro av. auc       | 0.581317 |
# | macro av. auc       | 0.549085 |
# | coverage error      | 1.02475  |
# | ranking loss        | 0.188119 |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 0, e index: 4
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | hamming loss        | 0.443069 | 0.361386 |
# | zero_one_loss       | 0.69802  | 0.767327 |
# | one_error           | 0.188119 | 0        |
# | micro av. jaccard   | 0.349091 | 0.247423 |
# | macro av. jaccard   | 0.237624 | 0.118812 |
# | micro av. precision | 0.475248 | 0.475248 |
# | macro av. precision | 0.237624 | 0.118812 |
# | micro av. recall    | 0.568047 | 0.340426 |
# | macro av. recall    | 0.5      | 0.25     |
# | micro av. f1        | 0.51752  | 0.396694 |
# | macro av. f1        | 0.322148 | 0.161074 |
# | micro av. pr.       | 0.454874 | 0.404303 |
# | macro av. pr.       | 0.471372 | 0.442054 |
# | micro av. auc       | 0.581317 | 0.561733 |
# | macro av. auc       | 0.549085 | 0.567422 |
# | coverage error      | 1.02475  | 2.30198  |
# | ranking loss        | 0.188119 | 0.375413 |
#
# label index list [0, 2, 4, 6]
# Task: 2, s index: 0, e index: 6
# The test shape is (202, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | hamming loss        | 0.443069 | 0.361386 | 0.39934  |
# | zero_one_loss       | 0.69802  | 0.767327 | 0.980198 |
# | one_error           | 0.188119 | 0        | 0        |
# | micro av. jaccard   | 0.349091 | 0.247423 | 0.268882 |
# | macro av. jaccard   | 0.237624 | 0.118812 | 0.176908 |
# | micro av. precision | 0.475248 | 0.475248 | 0.403628 |
# | macro av. precision | 0.237624 | 0.118812 | 0.204505 |
# | micro av. recall    | 0.568047 | 0.340426 | 0.446115 |
# | macro av. recall    | 0.5      | 0.25     | 0.401081 |
# | micro av. f1        | 0.51752  | 0.396694 | 0.42381  |
# | macro av. f1        | 0.322148 | 0.161074 | 0.258388 |
# | micro av. pr.       | 0.454874 | 0.404303 | 0.392742 |
# | macro av. pr.       | 0.471372 | 0.442054 | 0.439942 |
# | micro av. auc       | 0.581317 | 0.561733 | 0.561388 |
# | macro av. auc       | 0.549085 | 0.567422 | 0.590138 |
# | coverage error      | 1.02475  | 2.30198  | 4.10396  |
# | ranking loss        | 0.188119 | 0.375413 | 0.429345 |
#
# Overall Task Results
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | hamming loss        | 0.443069 | 0.361386 | 0.39934  |
# | zero_one_loss       | 0.69802  | 0.767327 | 0.980198 |
# | one_error           | 0.188119 | 0        | 0        |
# | micro av. jaccard   | 0.349091 | 0.247423 | 0.268882 |
# | macro av. jaccard   | 0.237624 | 0.118812 | 0.176908 |
# | micro av. precision | 0.475248 | 0.475248 | 0.403628 |
# | macro av. precision | 0.237624 | 0.118812 | 0.204505 |
# | micro av. recall    | 0.568047 | 0.340426 | 0.446115 |
# | macro av. recall    | 0.5      | 0.25     | 0.401081 |
# | micro av. f1        | 0.51752  | 0.396694 | 0.42381  |
# | macro av. f1        | 0.322148 | 0.161074 | 0.258388 |
# | micro av. pr.       | 0.454874 | 0.404303 | 0.392742 |
# | macro av. pr.       | 0.471372 | 0.442054 | 0.439942 |
# | micro av. auc       | 0.581317 | 0.561733 | 0.561388 |
# | macro av. auc       | 0.549085 | 0.567422 | 0.590138 |
# | coverage error      | 1.02475  | 2.30198  | 4.10396  |
# | ranking loss        | 0.188119 | 0.375413 | 0.429345 |
# 740.9009778499603 s.
