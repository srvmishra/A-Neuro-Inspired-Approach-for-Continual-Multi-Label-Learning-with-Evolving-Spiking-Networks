# %%
# !python3 main.py --name flags --shuffle 1 --seed 2 --device 1
# Out:
# data_name: flags.
# seed: 2.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (129, 26) (65, 26)
# torch.Size([65, 7])
# 0.47692307692307695
# task: 0, #samples: 43, #negative samples: 20, #positive samples: 1
# task: 1, #samples: 43, #negative samples: 10, #positive samples: 16
# task: 2, #samples: 43, #negative samples: 7, #positive samples: 15
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [00:46<00:00,  1.17s/it]
# The task 0 result is following:
# output shape =  (65, 5)
# ground truth shape =  (65, 7)
# Evaluation mode is single
# label index list [0, 3, 5, 7]
# Task: 0, s index: 0, e index: 3
# The test shape is (65, 7).
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.188406 |
# | micro av. precision | 0.52     |
# | micro av. recall    | 0.22807  |
# | micro av. f1        | 0.317073 |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:08<00:00,  1.65s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.188406 |
# | micro av. precision | 0.52     |
# | micro av. recall    | 0.22807  |
# | micro av. f1        | 0.317073 |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (65, 5)
# ground truth shape =  (65, 7)
# Evaluation mode is single
# label index list [0, 3, 5, 7]
# Task: 0, s index: 0, e index: 3
# The test shape is (65, 7).
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.181818 |
# | micro av. precision | 0.571429 |
# | micro av. recall    | 0.210526 |
# | micro av. f1        | 0.307692 |
#
# label index list [0, 3, 5, 7]
# Task: 1, s index: 3, e index: 5
# The test shape is (65, 7).
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | micro av. jaccard   | 0.181818 | 0.62963  |
# | micro av. precision | 0.571429 | 0.73913  |
# | micro av. recall    | 0.210526 | 0.809524 |
# | micro av. f1        | 0.307692 | 0.772727 |
#
# Beginning compression, old model output size = 3
# Inter end shape =  5
# Old model output shape = 5
# Train single mode Epoch: 100%|██████████████████| 15/15 [00:26<00:00,  1.75s/it]
# Old model output shape =  5
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:09<00:00,  1.74s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:08<00:00,  1.75s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | micro av. jaccard   | 0.181818 | 0.62963  |
# | micro av. precision | 0.571429 | 0.73913  |
# | micro av. recall    | 0.210526 | 0.809524 |
# | micro av. f1        | 0.307692 | 0.772727 |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (65, 7)
# ground truth shape =  (65, 7)
# Evaluation mode is single
# label index list [0, 3, 5, 7]
# Task: 0, s index: 0, e index: 3
# The test shape is (65, 7).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |   0 |
# |:--------------------|----:|
# | micro av. jaccard   |   0 |
# | micro av. precision |   0 |
# | micro av. recall    |   0 |
# | micro av. f1        |   0 |
#
# label index list [0, 3, 5, 7]
# Task: 1, s index: 3, e index: 5
# The test shape is (65, 7).
# |                     |   0 |   1 |
# |:--------------------|----:|----:|
# | micro av. jaccard   |   0 |   0 |
# | micro av. precision |   0 |   0 |
# | micro av. recall    |   0 |   0 |
# | micro av. f1        |   0 |   0 |
#
# label index list [0, 3, 5, 7]
# Task: 2, s index: 5, e index: 7
# The test shape is (65, 7).
# |                     |   0 |   1 |   2 |
# |:--------------------|----:|----:|----:|
# | micro av. jaccard   |   0 |   0 |   0 |
# | micro av. precision |   0 |   0 |   0 |
# | micro av. recall    |   0 |   0 |   0 |
# | micro av. f1        |   0 |   0 |   0 |
#
# Individual Task Results
# |                     |   0 |   1 |   2 |
# |:--------------------|----:|----:|----:|
# | micro av. jaccard   |   0 |   0 |   0 |
# | micro av. precision |   0 |   0 |   0 |
# | micro av. recall    |   0 |   0 |   0 |
# | micro av. f1        |   0 |   0 |   0 |
#
# ======================== Final Result ========================
# output shape =  (65, 7)
# ground truth shape =  (65, 7)
# Evaluation mode is incremental
# label index list [0, 3, 5, 7]
# Task: 0, s index: 0, e index: 3
# The test shape is (65, 7).
# |                     |   0 |
# |:--------------------|----:|
# | micro av. jaccard   |   0 |
# | micro av. precision |   0 |
# | micro av. recall    |   0 |
# | micro av. f1        |   0 |
#
# label index list [0, 3, 5, 7]
# Task: 1, s index: 0, e index: 5
# The test shape is (65, 7).
# |                     |   0 |   1 |
# |:--------------------|----:|----:|
# | micro av. jaccard   |   0 |   0 |
# | micro av. precision |   0 |   0 |
# | micro av. recall    |   0 |   0 |
# | micro av. f1        |   0 |   0 |
#
# label index list [0, 3, 5, 7]
# Task: 2, s index: 0, e index: 7
# The test shape is (65, 7).
# |                     |   0 |   1 |   2 |
# |:--------------------|----:|----:|----:|
# | micro av. jaccard   |   0 |   0 |   0 |
# | micro av. precision |   0 |   0 |   0 |
# | micro av. recall    |   0 |   0 |   0 |
# | micro av. f1        |   0 |   0 |   0 |
#
# Overall Task Results
# |                     |   0 |   1 |   2 |
# |:--------------------|----:|----:|----:|
# | micro av. jaccard   |   0 |   0 |   0 |
# | micro av. precision |   0 |   0 |   0 |
# | micro av. recall    |   0 |   0 |   0 |
# | micro av. f1        |   0 |   0 |   0 |
# 387.60351061820984 s.

# %%
# !python3 main.py --name flags --shuffle 1 --seed 3 --device 1
# Out:
# data_name: flags.
# seed: 3.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (129, 26) (65, 26)
# torch.Size([65, 7])
# 0.47692307692307695
# task: 0, #samples: 43, #negative samples: 7, #positive samples: 5
# task: 1, #samples: 43, #negative samples: 3, #positive samples: 20
# task: 2, #samples: 43, #negative samples: 21, #positive samples: 7
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [00:50<00:00,  1.26s/it]
# The task 0 result is following:
# output shape =  (65, 5)
# ground truth shape =  (65, 7)
# Evaluation mode is single
# label index list [0, 3, 5, 7]
# Task: 0, s index: 0, e index: 3
# The test shape is (65, 7).
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.441176 |
# | micro av. precision | 0.461538 |
# | micro av. recall    | 0.909091 |
# | micro av. f1        | 0.612245 |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:09<00:00,  1.90s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.441176 |
# | micro av. precision | 0.461538 |
# | micro av. recall    | 0.909091 |
# | micro av. f1        | 0.612245 |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (65, 5)
# ground truth shape =  (65, 7)
# Evaluation mode is single
# label index list [0, 3, 5, 7]
# Task: 0, s index: 0, e index: 3
# The test shape is (65, 7).
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.441176 |
# | micro av. precision | 0.461538 |
# | micro av. recall    | 0.909091 |
# | micro av. f1        | 0.612245 |
#
# label index list [0, 3, 5, 7]
# Task: 1, s index: 3, e index: 5
# The test shape is (65, 7).
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | micro av. jaccard   | 0.441176 | 0.769231 |
# | micro av. precision | 0.461538 | 0.769231 |
# | micro av. recall    | 0.909091 | 1        |
# | micro av. f1        | 0.612245 | 0.869565 |
#
# Beginning compression, old model output size = 3
# Inter end shape =  5
# Old model output shape = 5
# Train single mode Epoch: 100%|██████████████████| 15/15 [00:28<00:00,  1.91s/it]
# Old model output shape =  5
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:17<00:00,  1.94s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:09<00:00,  1.99s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | micro av. jaccard   | 0.441176 | 0.769231 |
# | micro av. precision | 0.461538 | 0.769231 |
# | micro av. recall    | 0.909091 | 1        |
# | micro av. f1        | 0.612245 | 0.869565 |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (65, 7)
# ground truth shape =  (65, 7)
# Evaluation mode is single
# label index list [0, 3, 5, 7]
# Task: 0, s index: 0, e index: 3
# The test shape is (65, 7).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |   0 |
# |:--------------------|----:|
# | micro av. jaccard   |   0 |
# | micro av. precision |   0 |
# | micro av. recall    |   0 |
# | micro av. f1        |   0 |
#
# label index list [0, 3, 5, 7]
# Task: 1, s index: 3, e index: 5
# The test shape is (65, 7).
# |                     |   0 |   1 |
# |:--------------------|----:|----:|
# | micro av. jaccard   |   0 |   0 |
# | micro av. precision |   0 |   0 |
# | micro av. recall    |   0 |   0 |
# | micro av. f1        |   0 |   0 |
#
# label index list [0, 3, 5, 7]
# Task: 2, s index: 5, e index: 7
# The test shape is (65, 7).
# |                     |   0 |   1 |   2 |
# |:--------------------|----:|----:|----:|
# | micro av. jaccard   |   0 |   0 |   0 |
# | micro av. precision |   0 |   0 |   0 |
# | micro av. recall    |   0 |   0 |   0 |
# | micro av. f1        |   0 |   0 |   0 |
#
# Individual Task Results
# |                     |   0 |   1 |   2 |
# |:--------------------|----:|----:|----:|
# | micro av. jaccard   |   0 |   0 |   0 |
# | micro av. precision |   0 |   0 |   0 |
# | micro av. recall    |   0 |   0 |   0 |
# | micro av. f1        |   0 |   0 |   0 |
#
# ======================== Final Result ========================
# output shape =  (65, 7)
# ground truth shape =  (65, 7)
# Evaluation mode is incremental
# label index list [0, 3, 5, 7]
# Task: 0, s index: 0, e index: 3
# The test shape is (65, 7).
# |                     |   0 |
# |:--------------------|----:|
# | micro av. jaccard   |   0 |
# | micro av. precision |   0 |
# | micro av. recall    |   0 |
# | micro av. f1        |   0 |
#
# label index list [0, 3, 5, 7]
# Task: 1, s index: 0, e index: 5
# The test shape is (65, 7).
# |                     |   0 |   1 |
# |:--------------------|----:|----:|
# | micro av. jaccard   |   0 |   0 |
# | micro av. precision |   0 |   0 |
# | micro av. recall    |   0 |   0 |
# | micro av. f1        |   0 |   0 |
#
# label index list [0, 3, 5, 7]
# Task: 2, s index: 0, e index: 7
# The test shape is (65, 7).
# |                     |   0 |   1 |   2 |
# |:--------------------|----:|----:|----:|
# | micro av. jaccard   |   0 |   0 |   0 |
# | micro av. precision |   0 |   0 |   0 |
# | micro av. recall    |   0 |   0 |   0 |
# | micro av. f1        |   0 |   0 |   0 |
#
# Overall Task Results
# |                     |   0 |   1 |   2 |
# |:--------------------|----:|----:|----:|
# | micro av. jaccard   |   0 |   0 |   0 |
# | micro av. precision |   0 |   0 |   0 |
# | micro av. recall    |   0 |   0 |   0 |
# | micro av. f1        |   0 |   0 |   0 |
# 430.1273503303528 s.

# %%
# !python3 main.py --name flags --shuffle 1 --seed 4 --device 1
# Out:
# data_name: flags.
# seed: 4.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (129, 26) (65, 26)
# torch.Size([65, 7])
# 0.47692307692307695
# task: 0, #samples: 43, #negative samples: 1, #positive samples: 10
# task: 1, #samples: 43, #negative samples: 9, #positive samples: 13
# task: 2, #samples: 43, #negative samples: 22, #positive samples: 7
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [00:53<00:00,  1.34s/it]
# The task 0 result is following:
# output shape =  (65, 5)
# ground truth shape =  (65, 7)
# Evaluation mode is single
# label index list [0, 3, 5, 7]
# Task: 0, s index: 0, e index: 3
# The test shape is (65, 7).
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.662252 |
# | micro av. precision | 0.769231 |
# | micro av. recall    | 0.826446 |
# | micro av. f1        | 0.796813 |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:09<00:00,  1.92s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.662252 |
# | micro av. precision | 0.769231 |
# | micro av. recall    | 0.826446 |
# | micro av. f1        | 0.796813 |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (65, 5)
# ground truth shape =  (65, 7)
# Evaluation mode is single
# label index list [0, 3, 5, 7]
# Task: 0, s index: 0, e index: 3
# The test shape is (65, 7).
# |                     |        0 |
# |:--------------------|---------:|
# | micro av. jaccard   | 0.662252 |
# | micro av. precision | 0.769231 |
# | micro av. recall    | 0.826446 |
# | micro av. f1        | 0.796813 |
#
# label index list [0, 3, 5, 7]
# Task: 1, s index: 3, e index: 5
# The test shape is (65, 7).
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | micro av. jaccard   | 0.662252 | 0.401961 |
# | micro av. precision | 0.769231 | 0.5125   |
# | micro av. recall    | 0.826446 | 0.650794 |
# | micro av. f1        | 0.796813 | 0.573427 |
#
# Beginning compression, old model output size = 3
# Inter end shape =  5
# Old model output shape = 5
# Train single mode Epoch: 100%|██████████████████| 15/15 [00:27<00:00,  1.83s/it]
# Old model output shape =  5
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:14<00:00,  1.87s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:09<00:00,  1.88s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | micro av. jaccard   | 0.662252 | 0.401961 |
# | micro av. precision | 0.769231 | 0.5125   |
# | micro av. recall    | 0.826446 | 0.650794 |
# | micro av. f1        | 0.796813 | 0.573427 |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (65, 7)
# ground truth shape =  (65, 7)
# Evaluation mode is single
# label index list [0, 3, 5, 7]
# Task: 0, s index: 0, e index: 3
# The test shape is (65, 7).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |   0 |
# |:--------------------|----:|
# | micro av. jaccard   |   0 |
# | micro av. precision |   0 |
# | micro av. recall    |   0 |
# | micro av. f1        |   0 |
#
# label index list [0, 3, 5, 7]
# Task: 1, s index: 3, e index: 5
# The test shape is (65, 7).
# |                     |   0 |   1 |
# |:--------------------|----:|----:|
# | micro av. jaccard   |   0 |   0 |
# | micro av. precision |   0 |   0 |
# | micro av. recall    |   0 |   0 |
# | micro av. f1        |   0 |   0 |
#
# label index list [0, 3, 5, 7]
# Task: 2, s index: 5, e index: 7
# The test shape is (65, 7).
# |                     |   0 |   1 |   2 |
# |:--------------------|----:|----:|----:|
# | micro av. jaccard   |   0 |   0 |   0 |
# | micro av. precision |   0 |   0 |   0 |
# | micro av. recall    |   0 |   0 |   0 |
# | micro av. f1        |   0 |   0 |   0 |
#
# Individual Task Results
# |                     |   0 |   1 |   2 |
# |:--------------------|----:|----:|----:|
# | micro av. jaccard   |   0 |   0 |   0 |
# | micro av. precision |   0 |   0 |   0 |
# | micro av. recall    |   0 |   0 |   0 |
# | micro av. f1        |   0 |   0 |   0 |
#
# ======================== Final Result ========================
# output shape =  (65, 7)
# ground truth shape =  (65, 7)
# Evaluation mode is incremental
# label index list [0, 3, 5, 7]
# Task: 0, s index: 0, e index: 3
# The test shape is (65, 7).
# |                     |   0 |
# |:--------------------|----:|
# | micro av. jaccard   |   0 |
# | micro av. precision |   0 |
# | micro av. recall    |   0 |
# | micro av. f1        |   0 |
#
# label index list [0, 3, 5, 7]
# Task: 1, s index: 0, e index: 5
# The test shape is (65, 7).
# |                     |   0 |   1 |
# |:--------------------|----:|----:|
# | micro av. jaccard   |   0 |   0 |
# | micro av. precision |   0 |   0 |
# | micro av. recall    |   0 |   0 |
# | micro av. f1        |   0 |   0 |
#
# label index list [0, 3, 5, 7]
# Task: 2, s index: 0, e index: 7
# The test shape is (65, 7).
# |                     |   0 |   1 |   2 |
# |:--------------------|----:|----:|----:|
# | micro av. jaccard   |   0 |   0 |   0 |
# | micro av. precision |   0 |   0 |   0 |
# | micro av. recall    |   0 |   0 |   0 |
# | micro av. f1        |   0 |   0 |   0 |
#
# Overall Task Results
# |                     |   0 |   1 |   2 |
# |:--------------------|----:|----:|----:|
# | micro av. jaccard   |   0 |   0 |   0 |
# | micro av. precision |   0 |   0 |   0 |
# | micro av. recall    |   0 |   0 |   0 |
# | micro av. f1        |   0 |   0 |   0 |
# 420.2656366825104 s.
