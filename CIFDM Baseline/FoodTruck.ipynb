# %%
# !python3 main.py --name foodtruck --shuffle 1 --seed 2 --device 1
# Out:
# data_name: foodtruck.
# seed: 2.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (250, 33) (250, 33)
# torch.Size([250, 12])
# 0.188
# task: 0, #samples: 90, #negative samples: 21, #positive samples: 0
# task: 1, #samples: 80, #negative samples: 32, #positive samples: 1
# task: 2, #samples: 80, #negative samples: 47, #positive samples: 0
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:42<00:00,  2.57s/it]
# The task 0 result is following:
# output shape =  (250, 8)
# ground truth shape =  (250, 12)
# Evaluation mode is single
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.117     |
# | zero_one_loss       | 0.356     |
# | one_error           | 0         |
# | micro av. jaccard   | 0.607383  |
# | macro av. jaccard   | 0.181     |
# | micro av. precision | 0.724     |
# | macro av. precision | 0.181     |
# | micro av. recall    | 0.790393  |
# | macro av. recall    | 0.25      |
# | micro av. f1        | 0.755741  |
# | macro av. f1        | 0.209977  |
# | micro av. pr.       | 0.621196  |
# | macro av. pr.       | 0.247195  |
# | micro av. auc       | 0.85572   |
# | macro av. auc       | 0.516846  |
# | coverage error      | 1.092     |
# | ranking loss        | 0.0576667 |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:19<00:00,  3.92s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.117     |
# | zero_one_loss       | 0.356     |
# | one_error           | 0         |
# | micro av. jaccard   | 0.607383  |
# | macro av. jaccard   | 0.181     |
# | micro av. precision | 0.724     |
# | macro av. precision | 0.181     |
# | micro av. recall    | 0.790393  |
# | macro av. recall    | 0.25      |
# | micro av. f1        | 0.755741  |
# | macro av. f1        | 0.209977  |
# | micro av. pr.       | 0.621196  |
# | macro av. pr.       | 0.247195  |
# | micro av. auc       | 0.85572   |
# | macro av. auc       | 0.516846  |
# | coverage error      | 1.092     |
# | ranking loss        | 0.0576667 |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (250, 8)
# ground truth shape =  (250, 12)
# Evaluation mode is single
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.117     |
# | zero_one_loss       | 0.356     |
# | one_error           | 0         |
# | micro av. jaccard   | 0.607383  |
# | macro av. jaccard   | 0.181     |
# | micro av. precision | 0.724     |
# | macro av. precision | 0.181     |
# | micro av. recall    | 0.790393  |
# | macro av. recall    | 0.25      |
# | micro av. f1        | 0.755741  |
# | macro av. f1        | 0.209977  |
# | micro av. pr.       | 0.62098   |
# | macro av. pr.       | 0.243832  |
# | micro av. auc       | 0.855419  |
# | macro av. auc       | 0.516101  |
# | coverage error      | 1.092     |
# | ranking loss        | 0.0576667 |
#
# label index list [0, 4, 8, 12]
# Task: 1, s index: 4, e index: 8
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |         1 |
# |:--------------------|----------:|----------:|
# | hamming loss        | 0.117     | 0.359     |
# | zero_one_loss       | 0.356     | 0.932     |
# | one_error           | 0         | 0         |
# | micro av. jaccard   | 0.607383  | 0.111386  |
# | macro av. jaccard   | 0.181     | 0.045     |
# | micro av. precision | 0.724     | 0.18      |
# | macro av. precision | 0.181     | 0.045     |
# | micro av. recall    | 0.790393  | 0.226131  |
# | macro av. recall    | 0.25      | 0.25      |
# | micro av. f1        | 0.755741  | 0.200445  |
# | macro av. f1        | 0.209977  | 0.0762712 |
# | micro av. pr.       | 0.62098   | 0.23533   |
# | macro av. pr.       | 0.243832  | 0.220416  |
# | micro av. auc       | 0.855419  | 0.585273  |
# | macro av. auc       | 0.516101  | 0.502514  |
# | coverage error      | 1.092     | 1.432     |
# | ranking loss        | 0.0576667 | 0.219     |
#
# Beginning compression, old model output size = 4
# Inter end shape =  8
# Old model output shape = 8
# Train single mode Epoch: 100%|██████████████████| 15/15 [00:58<00:00,  3.90s/it]
# Old model output shape =  8
# Train single mode Epoch: 100%|██████████████████| 40/40 [02:40<00:00,  4.02s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:19<00:00,  3.89s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |         0 |         1 |
# |:--------------------|----------:|----------:|
# | hamming loss        | 0.117     | 0.359     |
# | zero_one_loss       | 0.356     | 0.932     |
# | one_error           | 0         | 0         |
# | micro av. jaccard   | 0.607383  | 0.111386  |
# | macro av. jaccard   | 0.181     | 0.045     |
# | micro av. precision | 0.724     | 0.18      |
# | macro av. precision | 0.181     | 0.045     |
# | micro av. recall    | 0.790393  | 0.226131  |
# | macro av. recall    | 0.25      | 0.25      |
# | micro av. f1        | 0.755741  | 0.200445  |
# | macro av. f1        | 0.209977  | 0.0762712 |
# | micro av. pr.       | 0.62098   | 0.23533   |
# | macro av. pr.       | 0.243832  | 0.220416  |
# | micro av. auc       | 0.855419  | 0.585273  |
# | macro av. auc       | 0.516101  | 0.502514  |
# | coverage error      | 1.092     | 1.432     |
# | ranking loss        | 0.0576667 | 0.219     |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (250, 12)
# ground truth shape =  (250, 12)
# Evaluation mode is single
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.117     |
# | zero_one_loss       | 0.356     |
# | one_error           | 0         |
# | micro av. jaccard   | 0.607383  |
# | macro av. jaccard   | 0.181     |
# | micro av. precision | 0.724     |
# | macro av. precision | 0.181     |
# | micro av. recall    | 0.790393  |
# | macro av. recall    | 0.25      |
# | micro av. f1        | 0.755741  |
# | macro av. f1        | 0.209977  |
# | micro av. pr.       | 0.619401  |
# | macro av. pr.       | 0.248657  |
# | micro av. auc       | 0.857153  |
# | macro av. auc       | 0.508404  |
# | coverage error      | 1.084     |
# | ranking loss        | 0.0583333 |
#
# label index list [0, 4, 8, 12]
# Task: 1, s index: 4, e index: 8
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |        1 |
# |:--------------------|----------:|---------:|
# | hamming loss        | 0.117     | 0.265    |
# | zero_one_loss       | 0.356     | 0.804    |
# | one_error           | 0         | 0        |
# | micro av. jaccard   | 0.607383  | 0.257703 |
# | macro av. jaccard   | 0.181     | 0.092    |
# | micro av. precision | 0.724     | 0.368    |
# | macro av. precision | 0.181     | 0.092    |
# | micro av. recall    | 0.790393  | 0.462312 |
# | macro av. recall    | 0.25      | 0.25     |
# | micro av. f1        | 0.755741  | 0.4098   |
# | macro av. f1        | 0.209977  | 0.134503 |
# | micro av. pr.       | 0.619401  | 0.307751 |
# | macro av. pr.       | 0.248657  | 0.237572 |
# | micro av. auc       | 0.857153  | 0.679502 |
# | macro av. auc       | 0.508404  | 0.514968 |
# | coverage error      | 1.084     | 1.248    |
# | ranking loss        | 0.0583333 | 0.144667 |
#
# label index list [0, 4, 8, 12]
# Task: 2, s index: 8, e index: 12
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |        1 |         2 |
# |:--------------------|----------:|---------:|----------:|
# | hamming loss        | 0.117     | 0.265    | 0.387     |
# | zero_one_loss       | 0.356     | 0.804    | 0.98      |
# | one_error           | 0         | 0        | 0.016     |
# | micro av. jaccard   | 0.607383  | 0.257703 | 0.122449  |
# | macro av. jaccard   | 0.181     | 0.092    | 0.0794351 |
# | micro av. precision | 0.724     | 0.368    | 0.150418  |
# | macro av. precision | 0.181     | 0.092    | 0.11242   |
# | micro av. recall    | 0.790393  | 0.462312 | 0.397059  |
# | macro av. recall    | 0.25      | 0.25     | 0.339744  |
# | micro av. f1        | 0.755741  | 0.4098   | 0.218182  |
# | macro av. f1        | 0.209977  | 0.134503 | 0.135152  |
# | micro av. pr.       | 0.619401  | 0.307751 | 0.133788  |
# | macro av. pr.       | 0.248657  | 0.237572 | 0.136896  |
# | micro av. auc       | 0.857153  | 0.679502 | 0.511229  |
# | macro av. auc       | 0.508404  | 0.514968 | 0.446888  |
# | coverage error      | 1.084     | 1.248    | 1.056     |
# | ranking loss        | 0.0583333 | 0.144667 | 0.187     |
#
# Individual Task Results
# |                     |         0 |        1 |         2 |
# |:--------------------|----------:|---------:|----------:|
# | hamming loss        | 0.117     | 0.265    | 0.387     |
# | zero_one_loss       | 0.356     | 0.804    | 0.98      |
# | one_error           | 0         | 0        | 0.016     |
# | micro av. jaccard   | 0.607383  | 0.257703 | 0.122449  |
# | macro av. jaccard   | 0.181     | 0.092    | 0.0794351 |
# | micro av. precision | 0.724     | 0.368    | 0.150418  |
# | macro av. precision | 0.181     | 0.092    | 0.11242   |
# | micro av. recall    | 0.790393  | 0.462312 | 0.397059  |
# | macro av. recall    | 0.25      | 0.25     | 0.339744  |
# | micro av. f1        | 0.755741  | 0.4098   | 0.218182  |
# | macro av. f1        | 0.209977  | 0.134503 | 0.135152  |
# | micro av. pr.       | 0.619401  | 0.307751 | 0.133788  |
# | macro av. pr.       | 0.248657  | 0.237572 | 0.136896  |
# | micro av. auc       | 0.857153  | 0.679502 | 0.511229  |
# | macro av. auc       | 0.508404  | 0.514968 | 0.446888  |
# | coverage error      | 1.084     | 1.248    | 1.056     |
# | ranking loss        | 0.0583333 | 0.144667 | 0.187     |
#
# ======================== Final Result ========================
# output shape =  (250, 12)
# ground truth shape =  (250, 12)
# Evaluation mode is incremental
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.117     |
# | zero_one_loss       | 0.356     |
# | one_error           | 0         |
# | micro av. jaccard   | 0.607383  |
# | macro av. jaccard   | 0.181     |
# | micro av. precision | 0.724     |
# | macro av. precision | 0.181     |
# | micro av. recall    | 0.790393  |
# | macro av. recall    | 0.25      |
# | micro av. f1        | 0.755741  |
# | macro av. f1        | 0.209977  |
# | micro av. pr.       | 0.619401  |
# | macro av. pr.       | 0.248657  |
# | micro av. auc       | 0.857153  |
# | macro av. auc       | 0.508404  |
# | coverage error      | 1.084     |
# | ranking loss        | 0.0583333 |
#
# label index list [0, 4, 8, 12]
# Task: 1, s index: 0, e index: 8
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |        1 |
# |:--------------------|----------:|---------:|
# | hamming loss        | 0.117     | 0.191    |
# | zero_one_loss       | 0.356     | 0.88     |
# | one_error           | 0         | 0        |
# | micro av. jaccard   | 0.607383  | 0.416794 |
# | macro av. jaccard   | 0.181     | 0.1365   |
# | micro av. precision | 0.724     | 0.546    |
# | macro av. precision | 0.181     | 0.1365   |
# | micro av. recall    | 0.790393  | 0.63785  |
# | macro av. recall    | 0.25      | 0.25     |
# | micro av. f1        | 0.755741  | 0.588362 |
# | macro av. f1        | 0.209977  | 0.17224  |
# | micro av. pr.       | 0.619401  | 0.549436 |
# | macro av. pr.       | 0.248657  | 0.243114 |
# | micro av. auc       | 0.857153  | 0.807508 |
# | macro av. auc       | 0.508404  | 0.511686 |
# | coverage error      | 1.084     | 2.788    |
# | ranking loss        | 0.0583333 | 0.125529 |
#
# label index list [0, 4, 8, 12]
# Task: 2, s index: 0, e index: 12
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |        1 |        2 |
# |:--------------------|----------:|---------:|---------:|
# | hamming loss        | 0.117     | 0.191    | 0.256333 |
# | zero_one_loss       | 0.356     | 0.88     | 1        |
# | one_error           | 0         | 0        | 0        |
# | micro av. jaccard   | 0.607383  | 0.416794 | 0.298358 |
# | macro av. jaccard   | 0.181     | 0.1365   | 0.117478 |
# | micro av. precision | 0.724     | 0.546    | 0.380675 |
# | macro av. precision | 0.181     | 0.1365   | 0.128473 |
# | micro av. recall    | 0.790393  | 0.63785  | 0.579787 |
# | macro av. recall    | 0.25      | 0.25     | 0.279915 |
# | micro av. f1        | 0.755741  | 0.588362 | 0.459592 |
# | macro av. f1        | 0.209977  | 0.17224  | 0.159877 |
# | micro av. pr.       | 0.619401  | 0.549436 | 0.29564  |
# | macro av. pr.       | 0.248657  | 0.243114 | 0.207708 |
# | micro av. auc       | 0.857153  | 0.807508 | 0.702569 |
# | macro av. auc       | 0.508404  | 0.511686 | 0.490087 |
# | coverage error      | 1.084     | 2.788    | 5.504    |
# | ranking loss        | 0.0583333 | 0.125529 | 0.246551 |
#
# Overall Task Results
# |                     |         0 |        1 |        2 |
# |:--------------------|----------:|---------:|---------:|
# | hamming loss        | 0.117     | 0.191    | 0.256333 |
# | zero_one_loss       | 0.356     | 0.88     | 1        |
# | one_error           | 0         | 0        | 0        |
# | micro av. jaccard   | 0.607383  | 0.416794 | 0.298358 |
# | macro av. jaccard   | 0.181     | 0.1365   | 0.117478 |
# | micro av. precision | 0.724     | 0.546    | 0.380675 |
# | macro av. precision | 0.181     | 0.1365   | 0.128473 |
# | micro av. recall    | 0.790393  | 0.63785  | 0.579787 |
# | macro av. recall    | 0.25      | 0.25     | 0.279915 |
# | micro av. f1        | 0.755741  | 0.588362 | 0.459592 |
# | macro av. f1        | 0.209977  | 0.17224  | 0.159877 |
# | micro av. pr.       | 0.619401  | 0.549436 | 0.29564  |
# | macro av. pr.       | 0.248657  | 0.243114 | 0.207708 |
# | micro av. auc       | 0.857153  | 0.807508 | 0.702569 |
# | macro av. auc       | 0.508404  | 0.511686 | 0.490087 |
# | coverage error      | 1.084     | 2.788    | 5.504    |
# | ranking loss        | 0.0583333 | 0.125529 | 0.246551 |
# 895.1712908744812 s.

# %%
# !python3 main.py --name foodtruck --shuffle 1 --seed 3 --device 1
# Out:
# data_name: foodtruck.
# seed: 3.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (250, 33) (250, 33)
# torch.Size([250, 12])
# 0.188
# task: 0, #samples: 90, #negative samples: 46, #positive samples: 0
# task: 1, #samples: 80, #negative samples: 18, #positive samples: 0
# task: 2, #samples: 80, #negative samples: 40, #positive samples: 0
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:47<00:00,  2.68s/it]
# The task 0 result is following:
# output shape =  (250, 8)
# ground truth shape =  (250, 12)
# Evaluation mode is single
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.151    |
# | zero_one_loss       | 0.516    |
# | one_error           | 0        |
# | micro av. jaccard   | 0        |
# | macro av. jaccard   | 0        |
# | micro av. precision | 0        |
# | macro av. precision | 0        |
# | micro av. recall    | 0        |
# | macro av. recall    | 0        |
# | micro av. f1        | 0        |
# | macro av. f1        | 0        |
# | micro av. pr.       | 0.261904 |
# | macro av. pr.       | 0.208283 |
# | micro av. auc       | 0.713531 |
# | macro av. auc       | 0.554383 |
# | coverage error      | 0.912    |
# | ranking loss        | 0.109    |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:19<00:00,  3.88s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.151    |
# | zero_one_loss       | 0.516    |
# | one_error           | 0        |
# | micro av. jaccard   | 0        |
# | macro av. jaccard   | 0        |
# | micro av. precision | 0        |
# | macro av. precision | 0        |
# | micro av. recall    | 0        |
# | macro av. recall    | 0        |
# | micro av. f1        | 0        |
# | macro av. f1        | 0        |
# | micro av. pr.       | 0.261904 |
# | macro av. pr.       | 0.208283 |
# | micro av. auc       | 0.713531 |
# | macro av. auc       | 0.554383 |
# | coverage error      | 0.912    |
# | ranking loss        | 0.109    |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (250, 8)
# ground truth shape =  (250, 12)
# Evaluation mode is single
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.151    |
# | zero_one_loss       | 0.516    |
# | one_error           | 0        |
# | micro av. jaccard   | 0        |
# | macro av. jaccard   | 0        |
# | micro av. precision | 0        |
# | macro av. precision | 0        |
# | micro av. recall    | 0        |
# | macro av. recall    | 0        |
# | micro av. f1        | 0        |
# | macro av. f1        | 0        |
# | micro av. pr.       | 0.25554  |
# | macro av. pr.       | 0.206396 |
# | micro av. auc       | 0.711987 |
# | macro av. auc       | 0.554947 |
# | coverage error      | 0.924    |
# | ranking loss        | 0.112    |
#
# label index list [0, 4, 8, 12]
# Task: 1, s index: 4, e index: 8
# The test shape is (250, 12).
# |                     |        0 |         1 |
# |:--------------------|---------:|----------:|
# | hamming loss        | 0.151    | 0.41      |
# | zero_one_loss       | 0.516    | 0.872     |
# | one_error           | 0        | 0.016     |
# | micro av. jaccard   | 0        | 0.0909091 |
# | macro av. jaccard   | 0        | 0.0631815 |
# | micro av. precision | 0        | 0.175214  |
# | macro av. precision | 0        | 0.220707  |
# | micro av. recall    | 0        | 0.158915  |
# | macro av. recall    | 0        | 0.184247  |
# | micro av. f1        | 0        | 0.166667  |
# | macro av. f1        | 0        | 0.11502   |
# | micro av. pr.       | 0.25554  | 0.242069  |
# | macro av. pr.       | 0.206396 | 0.285671  |
# | micro av. auc       | 0.711987 | 0.329656  |
# | macro av. auc       | 0.554947 | 0.462001  |
# | coverage error      | 0.924    | 2.664     |
# | ranking loss        | 0.112    | 0.558333  |
#
# Beginning compression, old model output size = 4
# Inter end shape =  8
# Old model output shape = 8
# Train single mode Epoch: 100%|██████████████████| 15/15 [00:59<00:00,  3.95s/it]
# Old model output shape =  8
# Train single mode Epoch: 100%|██████████████████| 40/40 [02:33<00:00,  3.84s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:17<00:00,  3.57s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |         1 |
# |:--------------------|---------:|----------:|
# | hamming loss        | 0.151    | 0.41      |
# | zero_one_loss       | 0.516    | 0.872     |
# | one_error           | 0        | 0.016     |
# | micro av. jaccard   | 0        | 0.0909091 |
# | macro av. jaccard   | 0        | 0.0631815 |
# | micro av. precision | 0        | 0.175214  |
# | macro av. precision | 0        | 0.220707  |
# | micro av. recall    | 0        | 0.158915  |
# | macro av. recall    | 0        | 0.184247  |
# | micro av. f1        | 0        | 0.166667  |
# | macro av. f1        | 0        | 0.11502   |
# | micro av. pr.       | 0.25554  | 0.242069  |
# | macro av. pr.       | 0.206396 | 0.285671  |
# | micro av. auc       | 0.711987 | 0.329656  |
# | macro av. auc       | 0.554947 | 0.462001  |
# | coverage error      | 0.924    | 2.664     |
# | ranking loss        | 0.112    | 0.558333  |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (250, 12)
# ground truth shape =  (250, 12)
# Evaluation mode is single
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.411    |
# | zero_one_loss       | 0.984    |
# | one_error           | 0.016    |
# | micro av. jaccard   | 0.225989 |
# | macro av. jaccard   | 0.12     |
# | micro av. precision | 0.24     |
# | macro av. precision | 0.12     |
# | micro av. recall    | 0.794702 |
# | macro av. recall    | 0.5      |
# | micro av. f1        | 0.368664 |
# | macro av. f1        | 0.19082  |
# | micro av. pr.       | 0.203463 |
# | macro av. pr.       | 0.187249 |
# | micro av. auc       | 0.655976 |
# | macro av. auc       | 0.522441 |
# | coverage error      | 1.076    |
# | ranking loss        | 0.164667 |
#
# label index list [0, 4, 8, 12]
# Task: 1, s index: 4, e index: 8
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |         1 |
# |:--------------------|---------:|----------:|
# | hamming loss        | 0.411    | 0.146     |
# | zero_one_loss       | 0.984    | 0.44      |
# | one_error           | 0.016    | 0.004     |
# | micro av. jaccard   | 0.225989 | 0.553517  |
# | macro av. jaccard   | 0.12     | 0.181     |
# | micro av. precision | 0.24     | 0.724     |
# | macro av. precision | 0.12     | 0.181     |
# | micro av. recall    | 0.794702 | 0.70155   |
# | macro av. recall    | 0.5      | 0.25      |
# | micro av. f1        | 0.368664 | 0.712598  |
# | macro av. f1        | 0.19082  | 0.209977  |
# | micro av. pr.       | 0.203463 | 0.605419  |
# | macro av. pr.       | 0.187249 | 0.247227  |
# | micro av. auc       | 0.655976 | 0.82532   |
# | macro av. auc       | 0.522441 | 0.420251  |
# | coverage error      | 1.076    | 1.268     |
# | ranking loss        | 0.164667 | 0.0756667 |
#
# label index list [0, 4, 8, 12]
# Task: 2, s index: 8, e index: 12
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |         1 |         2 |
# |:--------------------|---------:|----------:|----------:|
# | hamming loss        | 0.411    | 0.146     | 0.34      |
# | zero_one_loss       | 0.984    | 0.44      | 0.876     |
# | one_error           | 0.016    | 0.004     | 0.008     |
# | micro av. jaccard   | 0.225989 | 0.553517  | 0.230769  |
# | macro av. jaccard   | 0.12     | 0.181     | 0.108129  |
# | micro av. precision | 0.24     | 0.724     | 0.262211  |
# | macro av. precision | 0.12     | 0.181     | 0.109986  |
# | micro av. recall    | 0.794702 | 0.70155   | 0.658065  |
# | macro av. recall    | 0.5      | 0.25      | 0.346154  |
# | micro av. f1        | 0.368664 | 0.712598  | 0.375     |
# | macro av. f1        | 0.19082  | 0.209977  | 0.164806  |
# | micro av. pr.       | 0.203463 | 0.605419  | 0.281724  |
# | macro av. pr.       | 0.187249 | 0.247227  | 0.14985   |
# | micro av. auc       | 0.655976 | 0.82532   | 0.685581  |
# | macro av. auc       | 0.522441 | 0.420251  | 0.44374   |
# | coverage error      | 1.076    | 1.268     | 0.916     |
# | ranking loss        | 0.164667 | 0.0756667 | 0.0983333 |
#
# Individual Task Results
# |                     |        0 |         1 |         2 |
# |:--------------------|---------:|----------:|----------:|
# | hamming loss        | 0.411    | 0.146     | 0.34      |
# | zero_one_loss       | 0.984    | 0.44      | 0.876     |
# | one_error           | 0.016    | 0.004     | 0.008     |
# | micro av. jaccard   | 0.225989 | 0.553517  | 0.230769  |
# | macro av. jaccard   | 0.12     | 0.181     | 0.108129  |
# | micro av. precision | 0.24     | 0.724     | 0.262211  |
# | macro av. precision | 0.12     | 0.181     | 0.109986  |
# | micro av. recall    | 0.794702 | 0.70155   | 0.658065  |
# | macro av. recall    | 0.5      | 0.25      | 0.346154  |
# | micro av. f1        | 0.368664 | 0.712598  | 0.375     |
# | macro av. f1        | 0.19082  | 0.209977  | 0.164806  |
# | micro av. pr.       | 0.203463 | 0.605419  | 0.281724  |
# | macro av. pr.       | 0.187249 | 0.247227  | 0.14985   |
# | micro av. auc       | 0.655976 | 0.82532   | 0.685581  |
# | macro av. auc       | 0.522441 | 0.420251  | 0.44374   |
# | coverage error      | 1.076    | 1.268     | 0.916     |
# | ranking loss        | 0.164667 | 0.0756667 | 0.0983333 |
#
# ======================== Final Result ========================
# output shape =  (250, 12)
# ground truth shape =  (250, 12)
# Evaluation mode is incremental
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.411    |
# | zero_one_loss       | 0.984    |
# | one_error           | 0.016    |
# | micro av. jaccard   | 0.225989 |
# | macro av. jaccard   | 0.12     |
# | micro av. precision | 0.24     |
# | macro av. precision | 0.12     |
# | micro av. recall    | 0.794702 |
# | macro av. recall    | 0.5      |
# | micro av. f1        | 0.368664 |
# | macro av. f1        | 0.19082  |
# | micro av. pr.       | 0.203463 |
# | macro av. pr.       | 0.187249 |
# | micro av. auc       | 0.655976 |
# | macro av. auc       | 0.522441 |
# | coverage error      | 1.076    |
# | ranking loss        | 0.164667 |
#
# label index list [0, 4, 8, 12]
# Task: 1, s index: 0, e index: 8
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | hamming loss        | 0.411    | 0.2785   |
# | zero_one_loss       | 0.984    | 0.992    |
# | one_error           | 0.016    | 0        |
# | micro av. jaccard   | 0.225989 | 0.350816 |
# | macro av. jaccard   | 0.12     | 0.1505   |
# | micro av. precision | 0.24     | 0.401333 |
# | macro av. precision | 0.12     | 0.1505   |
# | micro av. recall    | 0.794702 | 0.735941 |
# | macro av. recall    | 0.5      | 0.375    |
# | micro av. f1        | 0.368664 | 0.519413 |
# | macro av. f1        | 0.19082  | 0.200399 |
# | micro av. pr.       | 0.203463 | 0.309027 |
# | macro av. pr.       | 0.187249 | 0.217238 |
# | micro av. auc       | 0.655976 | 0.713711 |
# | macro av. auc       | 0.522441 | 0.471346 |
# | coverage error      | 1.076    | 3.616    |
# | ranking loss        | 0.164667 | 0.267886 |
#
# label index list [0, 4, 8, 12]
# Task: 2, s index: 0, e index: 12
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | hamming loss        | 0.411    | 0.2785   | 0.299    |
# | zero_one_loss       | 0.984    | 0.992    | 0.996    |
# | one_error           | 0.016    | 0        | 0        |
# | micro av. jaccard   | 0.225989 | 0.350816 | 0.31     |
# | macro av. jaccard   | 0.12     | 0.1505   | 0.136376 |
# | micro av. precision | 0.24     | 0.401333 | 0.353819 |
# | macro av. precision | 0.12     | 0.1505   | 0.136995 |
# | micro av. recall    | 0.794702 | 0.735941 | 0.714539 |
# | macro av. recall    | 0.5      | 0.375    | 0.365385 |
# | micro av. f1        | 0.368664 | 0.519413 | 0.473282 |
# | macro av. f1        | 0.19082  | 0.200399 | 0.188534 |
# | micro av. pr.       | 0.203463 | 0.309027 | 0.301085 |
# | macro av. pr.       | 0.187249 | 0.217238 | 0.194775 |
# | micro av. auc       | 0.655976 | 0.713711 | 0.697515 |
# | macro av. auc       | 0.522441 | 0.471346 | 0.462144 |
# | coverage error      | 1.076    | 3.616    | 5.924    |
# | ranking loss        | 0.164667 | 0.267886 | 0.287683 |
#
# Overall Task Results
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | hamming loss        | 0.411    | 0.2785   | 0.299    |
# | zero_one_loss       | 0.984    | 0.992    | 0.996    |
# | one_error           | 0.016    | 0        | 0        |
# | micro av. jaccard   | 0.225989 | 0.350816 | 0.31     |
# | macro av. jaccard   | 0.12     | 0.1505   | 0.136376 |
# | micro av. precision | 0.24     | 0.401333 | 0.353819 |
# | macro av. precision | 0.12     | 0.1505   | 0.136995 |
# | micro av. recall    | 0.794702 | 0.735941 | 0.714539 |
# | macro av. recall    | 0.5      | 0.375    | 0.365385 |
# | micro av. f1        | 0.368664 | 0.519413 | 0.473282 |
# | macro av. f1        | 0.19082  | 0.200399 | 0.188534 |
# | micro av. pr.       | 0.203463 | 0.309027 | 0.301085 |
# | macro av. pr.       | 0.187249 | 0.217238 | 0.194775 |
# | micro av. auc       | 0.655976 | 0.713711 | 0.697515 |
# | macro av. auc       | 0.522441 | 0.471346 | 0.462144 |
# | coverage error      | 1.076    | 3.616    | 5.924    |
# | ranking loss        | 0.164667 | 0.267886 | 0.287683 |
# 871.1428773403168 s.

# %%
# !python3 main.py --name foodtruck --shuffle 1 --seed 4 --device 1
# Out:
# data_name: foodtruck.
# seed: 4.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (250, 33) (250, 33)
# torch.Size([250, 12])
# 0.188
# task: 0, #samples: 90, #negative samples: 52, #positive samples: 1
# task: 1, #samples: 80, #negative samples: 33, #positive samples: 0
# task: 2, #samples: 80, #negative samples: 14, #positive samples: 0
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:50<00:00,  2.77s/it]
# The task 0 result is following:
# output shape =  (250, 8)
# ground truth shape =  (250, 12)
# Evaluation mode is single
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.22      |
# | zero_one_loss       | 0.76      |
# | one_error           | 0         |
# | micro av. jaccard   | 0.294872  |
# | macro av. jaccard   | 0.0931174 |
# | micro av. precision | 0.37247   |
# | macro av. precision | 0.0931174 |
# | micro av. recall    | 0.585987  |
# | macro av. recall    | 0.25      |
# | micro av. f1        | 0.455446  |
# | macro av. f1        | 0.135693  |
# | micro av. pr.       | 0.316602  |
# | macro av. pr.       | 0.153461  |
# | micro av. auc       | 0.698015  |
# | macro av. auc       | 0.445202  |
# | coverage error      | 0.892     |
# | ranking loss        | 0.081     |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:19<00:00,  3.98s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.22      |
# | zero_one_loss       | 0.76      |
# | one_error           | 0         |
# | micro av. jaccard   | 0.294872  |
# | macro av. jaccard   | 0.0931174 |
# | micro av. precision | 0.37247   |
# | macro av. precision | 0.0931174 |
# | micro av. recall    | 0.585987  |
# | macro av. recall    | 0.25      |
# | micro av. f1        | 0.455446  |
# | macro av. f1        | 0.135693  |
# | micro av. pr.       | 0.316602  |
# | macro av. pr.       | 0.153461  |
# | micro av. auc       | 0.698015  |
# | macro av. auc       | 0.445202  |
# | coverage error      | 0.892     |
# | ranking loss        | 0.081     |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (250, 8)
# ground truth shape =  (250, 12)
# Evaluation mode is single
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.158    |
# | zero_one_loss       | 0.448    |
# | one_error           | 0.004    |
# | micro av. jaccard   | 0        |
# | macro av. jaccard   | 0        |
# | micro av. precision | 0        |
# | macro av. precision | 0        |
# | micro av. recall    | 0        |
# | macro av. recall    | 0        |
# | micro av. f1        | 0        |
# | macro av. f1        | 0        |
# | micro av. pr.       | 0.309487 |
# | macro av. pr.       | 0.150264 |
# | micro av. auc       | 0.697879 |
# | macro av. auc       | 0.441798 |
# | coverage error      | 0.892    |
# | ranking loss        | 0.081    |
#
# label index list [0, 4, 8, 12]
# Task: 1, s index: 4, e index: 8
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | hamming loss        | 0.158    | 0.439    |
# | zero_one_loss       | 0.448    | 0.984    |
# | one_error           | 0.004    | 0.008    |
# | micro av. jaccard   | 0        | 0.214669 |
# | macro av. jaccard   | 0        | 0.121918 |
# | micro av. precision | 0        | 0.242915 |
# | macro av. precision | 0        | 0.121918 |
# | micro av. recall    | 0        | 0.648649 |
# | macro av. recall    | 0        | 0.5      |
# | micro av. f1        | 0        | 0.353461 |
# | macro av. f1        | 0        | 0.193036 |
# | micro av. pr.       | 0.309487 | 0.200153 |
# | macro av. pr.       | 0.150264 | 0.211229 |
# | micro av. auc       | 0.697879 | 0.550224 |
# | macro av. auc       | 0.441798 | 0.547818 |
# | coverage error      | 0.892    | 1.452    |
# | ranking loss        | 0.081    | 0.253    |
#
# Beginning compression, old model output size = 4
# Inter end shape =  8
# Old model output shape = 8
# Train single mode Epoch: 100%|██████████████████| 15/15 [00:56<00:00,  3.75s/it]
# Old model output shape =  8
# Train single mode Epoch: 100%|██████████████████| 40/40 [02:15<00:00,  3.38s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:12<00:00,  2.44s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | hamming loss        | 0.158    | 0.439    |
# | zero_one_loss       | 0.448    | 0.984    |
# | one_error           | 0.004    | 0.008    |
# | micro av. jaccard   | 0        | 0.214669 |
# | macro av. jaccard   | 0        | 0.121918 |
# | micro av. precision | 0        | 0.242915 |
# | macro av. precision | 0        | 0.121918 |
# | micro av. recall    | 0        | 0.648649 |
# | macro av. recall    | 0        | 0.5      |
# | micro av. f1        | 0        | 0.353461 |
# | macro av. f1        | 0        | 0.193036 |
# | micro av. pr.       | 0.309487 | 0.200153 |
# | macro av. pr.       | 0.150264 | 0.211229 |
# | micro av. auc       | 0.697879 | 0.550224 |
# | macro av. auc       | 0.441798 | 0.547818 |
# | coverage error      | 0.892    | 1.452    |
# | ranking loss        | 0.081    | 0.253    |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (250, 12)
# ground truth shape =  (250, 12)
# Evaluation mode is single
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.223     |
# | zero_one_loss       | 0.772     |
# | one_error           | 0         |
# | micro av. jaccard   | 0.292063  |
# | macro av. jaccard   | 0.092     |
# | micro av. precision | 0.368     |
# | macro av. precision | 0.092     |
# | micro av. recall    | 0.585987  |
# | macro av. recall    | 0.25      |
# | micro av. f1        | 0.452088  |
# | macro av. f1        | 0.134503  |
# | micro av. pr.       | 0.275855  |
# | macro av. pr.       | 0.144599  |
# | micro av. auc       | 0.671487  |
# | macro av. auc       | 0.435916  |
# | coverage error      | 0.916     |
# | ranking loss        | 0.0943333 |
#
# label index list [0, 4, 8, 12]
# Task: 1, s index: 4, e index: 8
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |        1 |
# |:--------------------|----------:|---------:|
# | hamming loss        | 0.223     | 0.521    |
# | zero_one_loss       | 0.772     | 0.992    |
# | one_error           | 0         | 0.024    |
# | micro av. jaccard   | 0.292063  | 0.223547 |
# | macro av. jaccard   | 0.092     | 0.169669 |
# | micro av. precision | 0.368     | 0.235849 |
# | macro av. precision | 0.092     | 0.175147 |
# | micro av. recall    | 0.585987  | 0.810811 |
# | macro av. recall    | 0.25      | 0.666667 |
# | micro av. f1        | 0.452088  | 0.365408 |
# | macro av. f1        | 0.134503  | 0.273693 |
# | micro av. pr.       | 0.275855  | 0.280001 |
# | macro av. pr.       | 0.144599  | 0.193237 |
# | micro av. auc       | 0.671487  | 0.639184 |
# | macro av. auc       | 0.435916  | 0.472695 |
# | coverage error      | 0.916     | 1.256    |
# | ranking loss        | 0.0943333 | 0.177667 |
#
# label index list [0, 4, 8, 12]
# Task: 2, s index: 8, e index: 12
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |        1 |        2 |
# |:--------------------|----------:|---------:|---------:|
# | hamming loss        | 0.223     | 0.521    | 0.11     |
# | zero_one_loss       | 0.772     | 0.992    | 0.356    |
# | one_error           | 0         | 0.024    | 0        |
# | micro av. jaccard   | 0.292063  | 0.223547 | 0.621993 |
# | macro av. jaccard   | 0.092     | 0.169669 | 0.181    |
# | micro av. precision | 0.368     | 0.235849 | 0.724    |
# | macro av. precision | 0.092     | 0.175147 | 0.181    |
# | micro av. recall    | 0.585987  | 0.810811 | 0.815315 |
# | macro av. recall    | 0.25      | 0.666667 | 0.25     |
# | micro av. f1        | 0.452088  | 0.365408 | 0.766949 |
# | macro av. f1        | 0.134503  | 0.273693 | 0.209977 |
# | micro av. pr.       | 0.275855  | 0.280001 | 0.659636 |
# | macro av. pr.       | 0.144599  | 0.193237 | 0.225483 |
# | micro av. auc       | 0.671487  | 0.639184 | 0.867108 |
# | macro av. auc       | 0.435916  | 0.472695 | 0.465014 |
# | coverage error      | 0.916     | 1.256    | 1.064    |
# | ranking loss        | 0.0943333 | 0.177667 | 0.057    |
#
# Individual Task Results
# |                     |         0 |        1 |        2 |
# |:--------------------|----------:|---------:|---------:|
# | hamming loss        | 0.223     | 0.521    | 0.11     |
# | zero_one_loss       | 0.772     | 0.992    | 0.356    |
# | one_error           | 0         | 0.024    | 0        |
# | micro av. jaccard   | 0.292063  | 0.223547 | 0.621993 |
# | macro av. jaccard   | 0.092     | 0.169669 | 0.181    |
# | micro av. precision | 0.368     | 0.235849 | 0.724    |
# | macro av. precision | 0.092     | 0.175147 | 0.181    |
# | micro av. recall    | 0.585987  | 0.810811 | 0.815315 |
# | macro av. recall    | 0.25      | 0.666667 | 0.25     |
# | micro av. f1        | 0.452088  | 0.365408 | 0.766949 |
# | macro av. f1        | 0.134503  | 0.273693 | 0.209977 |
# | micro av. pr.       | 0.275855  | 0.280001 | 0.659636 |
# | macro av. pr.       | 0.144599  | 0.193237 | 0.225483 |
# | micro av. auc       | 0.671487  | 0.639184 | 0.867108 |
# | macro av. auc       | 0.435916  | 0.472695 | 0.465014 |
# | coverage error      | 0.916     | 1.256    | 1.064    |
# | ranking loss        | 0.0943333 | 0.177667 | 0.057    |
#
# ======================== Final Result ========================
# output shape =  (250, 12)
# ground truth shape =  (250, 12)
# Evaluation mode is incremental
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.223     |
# | zero_one_loss       | 0.772     |
# | one_error           | 0         |
# | micro av. jaccard   | 0.292063  |
# | macro av. jaccard   | 0.092     |
# | micro av. precision | 0.368     |
# | macro av. precision | 0.092     |
# | micro av. recall    | 0.585987  |
# | macro av. recall    | 0.25      |
# | micro av. f1        | 0.452088  |
# | macro av. f1        | 0.134503  |
# | micro av. pr.       | 0.275855  |
# | macro av. pr.       | 0.144599  |
# | micro av. auc       | 0.671487  |
# | macro av. auc       | 0.435916  |
# | coverage error      | 0.916     |
# | ranking loss        | 0.0943333 |
#
# label index list [0, 4, 8, 12]
# Task: 1, s index: 0, e index: 8
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |        1 |
# |:--------------------|----------:|---------:|
# | hamming loss        | 0.223     | 0.372    |
# | zero_one_loss       | 0.772     | 0.996    |
# | one_error           | 0         | 0        |
# | micro av. jaccard   | 0.292063  | 0.245436 |
# | macro av. jaccard   | 0.092     | 0.130834 |
# | micro av. precision | 0.368     | 0.273138 |
# | macro av. precision | 0.092     | 0.133574 |
# | micro av. recall    | 0.585987  | 0.707602 |
# | macro av. recall    | 0.25      | 0.458333 |
# | micro av. f1        | 0.452088  | 0.394137 |
# | macro av. f1        | 0.134503  | 0.204098 |
# | micro av. pr.       | 0.275855  | 0.289861 |
# | macro av. pr.       | 0.144599  | 0.168918 |
# | micro av. auc       | 0.671487  | 0.679057 |
# | macro av. auc       | 0.435916  | 0.454305 |
# | coverage error      | 0.916     | 2.868    |
# | ranking loss        | 0.0943333 | 0.183736 |
#
# label index list [0, 4, 8, 12]
# Task: 2, s index: 0, e index: 12
# The test shape is (250, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |        1 |        2 |
# |:--------------------|----------:|---------:|---------:|
# | hamming loss        | 0.223     | 0.372    | 0.284667 |
# | zero_one_loss       | 0.772     | 0.996    | 0.996    |
# | one_error           | 0         | 0        | 0        |
# | micro av. jaccard   | 0.292063  | 0.245436 | 0.331245 |
# | macro av. jaccard   | 0.092     | 0.130834 | 0.147556 |
# | micro av. precision | 0.368     | 0.273138 | 0.372359 |
# | macro av. precision | 0.092     | 0.133574 | 0.149382 |
# | micro av. recall    | 0.585987  | 0.707602 | 0.75     |
# | macro av. recall    | 0.25      | 0.458333 | 0.388889 |
# | micro av. f1        | 0.452088  | 0.394137 | 0.497647 |
# | macro av. f1        | 0.134503  | 0.204098 | 0.206058 |
# | micro av. pr.       | 0.275855  | 0.289861 | 0.516557 |
# | macro av. pr.       | 0.144599  | 0.168918 | 0.187773 |
# | micro av. auc       | 0.671487  | 0.679057 | 0.784176 |
# | macro av. auc       | 0.435916  | 0.454305 | 0.457875 |
# | coverage error      | 0.916     | 2.868    | 4.56     |
# | ranking loss        | 0.0943333 | 0.183736 | 0.151311 |
#
# Overall Task Results
# |                     |         0 |        1 |        2 |
# |:--------------------|----------:|---------:|---------:|
# | hamming loss        | 0.223     | 0.372    | 0.284667 |
# | zero_one_loss       | 0.772     | 0.996    | 0.996    |
# | one_error           | 0         | 0        | 0        |
# | micro av. jaccard   | 0.292063  | 0.245436 | 0.331245 |
# | macro av. jaccard   | 0.092     | 0.130834 | 0.147556 |
# | micro av. precision | 0.368     | 0.273138 | 0.372359 |
# | macro av. precision | 0.092     | 0.133574 | 0.149382 |
# | micro av. recall    | 0.585987  | 0.707602 | 0.75     |
# | macro av. recall    | 0.25      | 0.458333 | 0.388889 |
# | micro av. f1        | 0.452088  | 0.394137 | 0.497647 |
# | macro av. f1        | 0.134503  | 0.204098 | 0.206058 |
# | micro av. pr.       | 0.275855  | 0.289861 | 0.516557 |
# | macro av. pr.       | 0.144599  | 0.168918 | 0.187773 |
# | micro av. auc       | 0.671487  | 0.679057 | 0.784176 |
# | macro av. auc       | 0.435916  | 0.454305 | 0.457875 |
# | coverage error      | 0.916     | 2.868    | 4.56     |
# | ranking loss        | 0.0943333 | 0.183736 | 0.151311 |
# 757.6527507305145 s.
