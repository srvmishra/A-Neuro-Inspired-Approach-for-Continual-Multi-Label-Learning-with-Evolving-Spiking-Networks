# %%
# !python3 main.py --name plant --shuffle 1 --seed 2 --device 0
# Out:
# data_name: plant.
# seed: 2.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (588, 452) (390, 452)
# torch.Size([390, 12])
# 0.08803418803418804
# task: 0, #samples: 196, #negative samples: 118, #positive samples: 0
# task: 1, #samples: 196, #negative samples: 125, #positive samples: 0
# task: 2, #samples: 196, #negative samples: 136, #positive samples: 0
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:37<00:00,  2.43s/it]
# The task 0 result is following:
# output shape =  (390, 8)
# ground truth shape =  (390, 12)
# Evaluation mode is single
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.14359   |
# | zero_one_loss       | 0.507692  |
# | one_error           | 0         |
# | micro av. jaccard   | 0.128405  |
# | macro av. jaccard   | 0.0669046 |
# | micro av. precision | 0.246269  |
# | macro av. precision | 0.121324  |
# | micro av. recall    | 0.211538  |
# | macro av. recall    | 0.123116  |
# | micro av. f1        | 0.227586  |
# | macro av. f1        | 0.117055  |
# | micro av. pr.       | 0.208427  |
# | macro av. pr.       | 0.127591  |
# | micro av. auc       | 0.726336  |
# | macro av. auc       | 0.534148  |
# | coverage error      | 0.674359  |
# | ranking loss        | 0.0912393 |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:16<00:00,  3.39s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.14359   |
# | zero_one_loss       | 0.507692  |
# | one_error           | 0         |
# | micro av. jaccard   | 0.128405  |
# | macro av. jaccard   | 0.0669046 |
# | micro av. precision | 0.246269  |
# | macro av. precision | 0.121324  |
# | micro av. recall    | 0.211538  |
# | macro av. recall    | 0.123116  |
# | micro av. f1        | 0.227586  |
# | macro av. f1        | 0.117055  |
# | micro av. pr.       | 0.208427  |
# | macro av. pr.       | 0.127591  |
# | micro av. auc       | 0.726336  |
# | macro av. auc       | 0.534148  |
# | coverage error      | 0.674359  |
# | ranking loss        | 0.0912393 |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (390, 8)
# ground truth shape =  (390, 12)
# Evaluation mode is single
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.103846  |
# | zero_one_loss       | 0.407692  |
# | one_error           | 0         |
# | micro av. jaccard   | 0.0181818 |
# | macro av. jaccard   | 0.0113978 |
# | micro av. precision | 0.25      |
# | macro av. precision | 0.121429  |
# | micro av. recall    | 0.0192308 |
# | macro av. recall    | 0.0122931 |
# | micro av. f1        | 0.0357143 |
# | macro av. f1        | 0.0222039 |
# | micro av. pr.       | 0.187195  |
# | macro av. pr.       | 0.131114  |
# | micro av. auc       | 0.698901  |
# | macro av. auc       | 0.538727  |
# | coverage error      | 0.735897  |
# | ranking loss        | 0.113034  |
#
# label index list [0, 4, 8, 12]
# Task: 1, s index: 4, e index: 8
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |         1 |
# |:--------------------|----------:|----------:|
# | hamming loss        | 0.103846  | 0.428846  |
# | zero_one_loss       | 0.407692  | 1         |
# | one_error           | 0         | 0         |
# | micro av. jaccard   | 0.0181818 | 0.158491  |
# | macro av. jaccard   | 0.0113978 | 0.0817183 |
# | micro av. precision | 0.25      | 0.162162  |
# | macro av. precision | 0.121429  | 0.0817183 |
# | micro av. recall    | 0.0192308 | 0.875     |
# | macro av. recall    | 0.0122931 | 0.5       |
# | micro av. f1        | 0.0357143 | 0.273616  |
# | macro av. f1        | 0.0222039 | 0.129154  |
# | micro av. pr.       | 0.187195  | 0.118162  |
# | macro av. pr.       | 0.131114  | 0.124069  |
# | micro av. auc       | 0.698901  | 0.643271  |
# | macro av. auc       | 0.538727  | 0.598677  |
# | coverage error      | 0.735897  | 0.730769  |
# | ranking loss        | 0.113034  | 0.119231  |
#
# Beginning compression, old model output size = 4
# Inter end shape =  8
# Old model output shape = 8
# Train single mode Epoch: 100%|██████████████████| 15/15 [00:53<00:00,  3.60s/it]
# Old model output shape =  8
# Train single mode Epoch: 100%|██████████████████| 40/40 [02:29<00:00,  3.74s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:17<00:00,  3.46s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |         0 |         1 |
# |:--------------------|----------:|----------:|
# | hamming loss        | 0.103846  | 0.428846  |
# | zero_one_loss       | 0.407692  | 1         |
# | one_error           | 0         | 0         |
# | micro av. jaccard   | 0.0181818 | 0.158491  |
# | macro av. jaccard   | 0.0113978 | 0.0817183 |
# | micro av. precision | 0.25      | 0.162162  |
# | macro av. precision | 0.121429  | 0.0817183 |
# | micro av. recall    | 0.0192308 | 0.875     |
# | macro av. recall    | 0.0122931 | 0.5       |
# | micro av. f1        | 0.0357143 | 0.273616  |
# | macro av. f1        | 0.0222039 | 0.129154  |
# | micro av. pr.       | 0.187195  | 0.118162  |
# | macro av. pr.       | 0.131114  | 0.124069  |
# | micro av. auc       | 0.698901  | 0.643271  |
# | macro av. auc       | 0.538727  | 0.598677  |
# | coverage error      | 0.735897  | 0.730769  |
# | ranking loss        | 0.113034  | 0.119231  |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (390, 12)
# ground truth shape =  (390, 12)
# Evaluation mode is single
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.280128  |
# | zero_one_loss       | 0.858974  |
# | one_error           | 0         |
# | micro av. jaccard   | 0.127745  |
# | macro av. jaccard   | 0.0576228 |
# | micro av. precision | 0.156479  |
# | macro av. precision | 0.128644  |
# | micro av. recall    | 0.410256  |
# | macro av. recall    | 0.274648  |
# | micro av. f1        | 0.226549  |
# | macro av. f1        | 0.102647  |
# | micro av. pr.       | 0.142206  |
# | macro av. pr.       | 0.115938  |
# | micro av. auc       | 0.66584   |
# | macro av. auc       | 0.495549  |
# | coverage error      | 0.735897  |
# | ranking loss        | 0.113034  |
#
# label index list [0, 4, 8, 12]
# Task: 1, s index: 4, e index: 8
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |         1 |
# |:--------------------|----------:|----------:|
# | hamming loss        | 0.280128  | 0.196154  |
# | zero_one_loss       | 0.858974  | 0.707692  |
# | one_error           | 0         | 0         |
# | micro av. jaccard   | 0.127745  | 0.271429  |
# | macro av. jaccard   | 0.0576228 | 0.0730769 |
# | micro av. precision | 0.156479  | 0.292308  |
# | macro av. precision | 0.128644  | 0.0730769 |
# | micro av. recall    | 0.410256  | 0.791667  |
# | macro av. recall    | 0.274648  | 0.25      |
# | micro av. f1        | 0.226549  | 0.426966  |
# | macro av. f1        | 0.102647  | 0.113095  |
# | micro av. pr.       | 0.142206  | 0.324966  |
# | macro av. pr.       | 0.115938  | 0.117006  |
# | micro av. auc       | 0.66584   | 0.806024  |
# | macro av. auc       | 0.495549  | 0.494257  |
# | coverage error      | 0.735897  | 0.502564  |
# | ranking loss        | 0.113034  | 0.0450855 |
#
# label index list [0, 4, 8, 12]
# Task: 2, s index: 8, e index: 12
# The test shape is (390, 12).
# |                     |         0 |         1 |         2 |
# |:--------------------|----------:|----------:|----------:|
# | hamming loss        | 0.280128  | 0.196154  | 0.298718  |
# | zero_one_loss       | 0.858974  | 0.707692  | 0.94359   |
# | one_error           | 0         | 0         | 0         |
# | micro av. jaccard   | 0.127745  | 0.271429  | 0.0470348 |
# | macro av. jaccard   | 0.0576228 | 0.0730769 | 0.0180708 |
# | micro av. precision | 0.156479  | 0.292308  | 0.0575    |
# | macro av. precision | 0.128644  | 0.0730769 | 0.0641026 |
# | micro av. recall    | 0.410256  | 0.791667  | 0.205357  |
# | macro av. recall    | 0.274648  | 0.25      | 0.254237  |
# | micro av. f1        | 0.226549  | 0.426966  | 0.0898438 |
# | macro av. f1        | 0.102647  | 0.113095  | 0.0345115 |
# | micro av. pr.       | 0.142206  | 0.324966  | 0.0796826 |
# | macro av. pr.       | 0.115938  | 0.117006  | 0.0854232 |
# | micro av. auc       | 0.66584   | 0.806024  | 0.570568  |
# | macro av. auc       | 0.495549  | 0.494257  | 0.522161  |
# | coverage error      | 0.735897  | 0.502564  | 0.64359   |
# | ranking loss        | 0.113034  | 0.0450855 | 0.118803  |
#
# Individual Task Results
# |                     |         0 |         1 |         2 |
# |:--------------------|----------:|----------:|----------:|
# | hamming loss        | 0.280128  | 0.196154  | 0.298718  |
# | zero_one_loss       | 0.858974  | 0.707692  | 0.94359   |
# | one_error           | 0         | 0         | 0         |
# | micro av. jaccard   | 0.127745  | 0.271429  | 0.0470348 |
# | macro av. jaccard   | 0.0576228 | 0.0730769 | 0.0180708 |
# | micro av. precision | 0.156479  | 0.292308  | 0.0575    |
# | macro av. precision | 0.128644  | 0.0730769 | 0.0641026 |
# | micro av. recall    | 0.410256  | 0.791667  | 0.205357  |
# | macro av. recall    | 0.274648  | 0.25      | 0.254237  |
# | micro av. f1        | 0.226549  | 0.426966  | 0.0898438 |
# | macro av. f1        | 0.102647  | 0.113095  | 0.0345115 |
# | micro av. pr.       | 0.142206  | 0.324966  | 0.0796826 |
# | macro av. pr.       | 0.115938  | 0.117006  | 0.0854232 |
# | micro av. auc       | 0.66584   | 0.806024  | 0.570568  |
# | macro av. auc       | 0.495549  | 0.494257  | 0.522161  |
# | coverage error      | 0.735897  | 0.502564  | 0.64359   |
# | ranking loss        | 0.113034  | 0.0450855 | 0.118803  |
#
# ======================== Final Result ========================
# output shape =  (390, 12)
# ground truth shape =  (390, 12)
# Evaluation mode is incremental
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.280128  |
# | zero_one_loss       | 0.858974  |
# | one_error           | 0         |
# | micro av. jaccard   | 0.127745  |
# | macro av. jaccard   | 0.0576228 |
# | micro av. precision | 0.156479  |
# | macro av. precision | 0.128644  |
# | micro av. recall    | 0.410256  |
# | macro av. recall    | 0.274648  |
# | micro av. f1        | 0.226549  |
# | macro av. f1        | 0.102647  |
# | micro av. pr.       | 0.142206  |
# | macro av. pr.       | 0.115938  |
# | micro av. auc       | 0.66584   |
# | macro av. auc       | 0.495549  |
# | coverage error      | 0.735897  |
# | ranking loss        | 0.113034  |
#
# label index list [0, 4, 8, 12]
# Task: 1, s index: 0, e index: 8
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |         1 |
# |:--------------------|----------:|----------:|
# | hamming loss        | 0.280128  | 0.238141  |
# | zero_one_loss       | 0.858974  | 0.997436  |
# | one_error           | 0         | 0         |
# | micro av. jaccard   | 0.127745  | 0.193268  |
# | macro av. jaccard   | 0.0576228 | 0.0653499 |
# | micro av. precision | 0.156479  | 0.222778  |
# | macro av. precision | 0.128644  | 0.10086   |
# | micro av. recall    | 0.410256  | 0.593333  |
# | macro av. recall    | 0.274648  | 0.262324  |
# | micro av. f1        | 0.226549  | 0.323931  |
# | macro av. f1        | 0.102647  | 0.107871  |
# | micro av. pr.       | 0.142206  | 0.207818  |
# | macro av. pr.       | 0.115938  | 0.116472  |
# | micro av. auc       | 0.66584   | 0.744681  |
# | macro av. auc       | 0.495549  | 0.494903  |
# | coverage error      | 0.735897  | 2.08205   |
# | ranking loss        | 0.113034  | 0.186679  |
#
# label index list [0, 4, 8, 12]
# Task: 2, s index: 0, e index: 12
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |         1 |         2 |
# |:--------------------|----------:|----------:|----------:|
# | hamming loss        | 0.280128  | 0.238141  | 0.258333  |
# | zero_one_loss       | 0.858974  | 0.997436  | 1         |
# | one_error           | 0         | 0         | 0         |
# | micro av. jaccard   | 0.127745  | 0.193268  | 0.142553  |
# | macro av. jaccard   | 0.0576228 | 0.0653499 | 0.0495902 |
# | micro av. precision | 0.156479  | 0.222778  | 0.16764   |
# | macro av. precision | 0.128644  | 0.10086   | 0.0886077 |
# | micro av. recall    | 0.410256  | 0.593333  | 0.487864  |
# | macro av. recall    | 0.274648  | 0.262324  | 0.259628  |
# | micro av. f1        | 0.226549  | 0.323931  | 0.249534  |
# | macro av. f1        | 0.102647  | 0.107871  | 0.083418  |
# | micro av. pr.       | 0.142206  | 0.207818  | 0.142393  |
# | macro av. pr.       | 0.115938  | 0.116472  | 0.106122  |
# | micro av. auc       | 0.66584   | 0.744681  | 0.687611  |
# | macro av. auc       | 0.495549  | 0.494903  | 0.503989  |
# | coverage error      | 0.735897  | 2.08205   | 4.58205   |
# | ranking loss        | 0.113034  | 0.186679  | 0.319308  |
#
# Overall Task Results
# |                     |         0 |         1 |         2 |
# |:--------------------|----------:|----------:|----------:|
# | hamming loss        | 0.280128  | 0.238141  | 0.258333  |
# | zero_one_loss       | 0.858974  | 0.997436  | 1         |
# | one_error           | 0         | 0         | 0         |
# | micro av. jaccard   | 0.127745  | 0.193268  | 0.142553  |
# | macro av. jaccard   | 0.0576228 | 0.0653499 | 0.0495902 |
# | micro av. precision | 0.156479  | 0.222778  | 0.16764   |
# | macro av. precision | 0.128644  | 0.10086   | 0.0886077 |
# | micro av. recall    | 0.410256  | 0.593333  | 0.487864  |
# | macro av. recall    | 0.274648  | 0.262324  | 0.259628  |
# | micro av. f1        | 0.226549  | 0.323931  | 0.249534  |
# | macro av. f1        | 0.102647  | 0.107871  | 0.083418  |
# | micro av. pr.       | 0.142206  | 0.207818  | 0.142393  |
# | macro av. pr.       | 0.115938  | 0.116472  | 0.106122  |
# | micro av. auc       | 0.66584   | 0.744681  | 0.687611  |
# | macro av. auc       | 0.495549  | 0.494903  | 0.503989  |
# | coverage error      | 0.735897  | 2.08205   | 4.58205   |
# | ranking loss        | 0.113034  | 0.186679  | 0.319308  |
# 826.3705885410309 s.

# %%
# !python3 main.py --name plant --shuffle 1 --seed 244 --device 0
# Out:
# data_name: plant.
# seed: 244.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (588, 452) (390, 452)
# torch.Size([390, 12])
# 0.08803418803418804
# task: 0, #samples: 196, #negative samples: 118, #positive samples: 0
# task: 1, #samples: 196, #negative samples: 179, #positive samples: 0
# task: 2, #samples: 196, #negative samples: 93, #positive samples: 0
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:36<00:00,  2.42s/it]
# The task 0 result is following:
# output shape =  (390, 8)
# ground truth shape =  (390, 12)
# Evaluation mode is single
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.14359  |
# | zero_one_loss       | 0.45641  |
# | one_error           | 0        |
# | micro av. jaccard   | 0.238095 |
# | macro av. jaccard   | 0.130229 |
# | micro av. precision | 0.331754 |
# | macro av. precision | 0.176392 |
# | micro av. recall    | 0.457516 |
# | macro av. recall    | 0.265099 |
# | micro av. f1        | 0.384615 |
# | macro av. f1        | 0.206608 |
# | micro av. pr.       | 0.27876  |
# | macro av. pr.       | 0.183096 |
# | micro av. auc       | 0.787607 |
# | macro av. auc       | 0.648433 |
# | coverage error      | 0.617949 |
# | ranking loss        | 0.075    |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:15<00:00,  3.12s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.14359  |
# | zero_one_loss       | 0.45641  |
# | one_error           | 0        |
# | micro av. jaccard   | 0.238095 |
# | macro av. jaccard   | 0.130229 |
# | micro av. precision | 0.331754 |
# | macro av. precision | 0.176392 |
# | micro av. recall    | 0.457516 |
# | macro av. recall    | 0.265099 |
# | micro av. f1        | 0.384615 |
# | macro av. f1        | 0.206608 |
# | micro av. pr.       | 0.27876  |
# | macro av. pr.       | 0.183096 |
# | micro av. auc       | 0.787607 |
# | macro av. auc       | 0.648433 |
# | coverage error      | 0.617949 |
# | ranking loss        | 0.075    |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (390, 8)
# ground truth shape =  (390, 12)
# Evaluation mode is single
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.103205  |
# | zero_one_loss       | 0.371795  |
# | one_error           | 0         |
# | micro av. jaccard   | 0.0301205 |
# | macro av. jaccard   | 0.0179487 |
# | micro av. precision | 0.277778  |
# | macro av. precision | 0.138889  |
# | micro av. recall    | 0.0326797 |
# | macro av. recall    | 0.0197541 |
# | micro av. f1        | 0.0584795 |
# | macro av. f1        | 0.0345588 |
# | micro av. pr.       | 0.270951  |
# | macro av. pr.       | 0.180705  |
# | micro av. auc       | 0.766095  |
# | macro av. auc       | 0.648775  |
# | coverage error      | 0.671795  |
# | ranking loss        | 0.0929487 |
#
# label index list [0, 4, 8, 12]
# Task: 1, s index: 4, e index: 8
# The test shape is (390, 12).
# |                     |         0 |         1 |
# |:--------------------|----------:|----------:|
# | hamming loss        | 0.103205  | 0.278846  |
# | zero_one_loss       | 0.371795  | 0.982051  |
# | one_error           | 0         | 0         |
# | micro av. jaccard   | 0.0301205 | 0.0268456 |
# | macro av. jaccard   | 0.0179487 | 0.0281824 |
# | micro av. precision | 0.277778  | 0.0290557 |
# | macro av. precision | 0.138889  | 0.0358551 |
# | micro av. recall    | 0.0326797 | 0.26087   |
# | macro av. recall    | 0.0197541 | 0.3125    |
# | micro av. f1        | 0.0584795 | 0.0522876 |
# | macro av. f1        | 0.0345588 | 0.0525628 |
# | micro av. pr.       | 0.270951  | 0.0288664 |
# | macro av. pr.       | 0.180705  | 0.0485254 |
# | micro av. auc       | 0.766095  | 0.437583  |
# | macro av. auc       | 0.648775  | 0.521859  |
# | coverage error      | 0.671795  | 0.289744  |
# | ranking loss        | 0.0929487 | 0.0561966 |
#
# Beginning compression, old model output size = 4
# Inter end shape =  8
# Old model output shape = 8
# Train single mode Epoch: 100%|██████████████████| 15/15 [00:50<00:00,  3.40s/it]
# Old model output shape =  8
# Train single mode Epoch: 100%|██████████████████| 40/40 [02:15<00:00,  3.39s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:15<00:00,  3.06s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |         0 |         1 |
# |:--------------------|----------:|----------:|
# | hamming loss        | 0.103205  | 0.278846  |
# | zero_one_loss       | 0.371795  | 0.982051  |
# | one_error           | 0         | 0         |
# | micro av. jaccard   | 0.0301205 | 0.0268456 |
# | macro av. jaccard   | 0.0179487 | 0.0281824 |
# | micro av. precision | 0.277778  | 0.0290557 |
# | macro av. precision | 0.138889  | 0.0358551 |
# | micro av. recall    | 0.0326797 | 0.26087   |
# | macro av. recall    | 0.0197541 | 0.3125    |
# | micro av. f1        | 0.0584795 | 0.0522876 |
# | macro av. f1        | 0.0345588 | 0.0525628 |
# | micro av. pr.       | 0.270951  | 0.0288664 |
# | macro av. pr.       | 0.180705  | 0.0485254 |
# | micro av. auc       | 0.766095  | 0.437583  |
# | macro av. auc       | 0.648775  | 0.521859  |
# | coverage error      | 0.671795  | 0.289744  |
# | ranking loss        | 0.0929487 | 0.0561966 |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (390, 12)
# ground truth shape =  (390, 12)
# Evaluation mode is single
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.303205  |
# | zero_one_loss       | 0.907692  |
# | one_error           | 0         |
# | micro av. jaccard   | 0.13211   |
# | macro av. jaccard   | 0.0624417 |
# | micro av. precision | 0.155172  |
# | macro av. precision | 0.0817394 |
# | micro av. recall    | 0.470588  |
# | macro av. recall    | 0.295775  |
# | micro av. f1        | 0.233387  |
# | macro av. f1        | 0.110529  |
# | micro av. pr.       | 0.136547  |
# | macro av. pr.       | 0.0866698 |
# | micro av. auc       | 0.659016  |
# | macro av. auc       | 0.410312  |
# | coverage error      | 0.684615  |
# | ranking loss        | 0.0974359 |
#
# label index list [0, 4, 8, 12]
# Task: 1, s index: 4, e index: 8
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |          1 |
# |:--------------------|----------:|-----------:|
# | hamming loss        | 0.303205  | 0.0730769  |
# | zero_one_loss       | 0.907692  | 0.266667   |
# | one_error           | 0         | 0          |
# | micro av. jaccard   | 0.13211   | 0.00869565 |
# | macro av. jaccard   | 0.0624417 | 0.00568182 |
# | micro av. precision | 0.155172  | 0.0142857  |
# | macro av. precision | 0.0817394 | 0.00757576 |
# | micro av. recall    | 0.470588  | 0.0217391  |
# | macro av. recall    | 0.295775  | 0.0208333  |
# | micro av. f1        | 0.233387  | 0.0172414  |
# | macro av. f1        | 0.110529  | 0.0111111  |
# | micro av. pr.       | 0.136547  | 0.0251903  |
# | macro av. pr.       | 0.0866698 | 0.0347622  |
# | micro av. auc       | 0.659016  | 0.409583   |
# | macro av. auc       | 0.410312  | 0.443257   |
# | coverage error      | 0.684615  | 0.294872   |
# | ranking loss        | 0.0974359 | 0.0587607  |
#
# label index list [0, 4, 8, 12]
# Task: 2, s index: 8, e index: 12
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |          1 |        2 |
# |:--------------------|----------:|-----------:|---------:|
# | hamming loss        | 0.303205  | 0.0730769  | 0.482692 |
# | zero_one_loss       | 0.907692  | 0.266667   | 0.933333 |
# | one_error           | 0         | 0          | 0.025641 |
# | micro av. jaccard   | 0.13211   | 0.00869565 | 0.15583  |
# | macro av. jaccard   | 0.0624417 | 0.00568182 | 0.102846 |
# | micro av. precision | 0.155172  | 0.0142857  | 0.169927 |
# | macro av. precision | 0.0817394 | 0.00757576 | 0.104163 |
# | micro av. recall    | 0.470588  | 0.0217391  | 0.652582 |
# | macro av. recall    | 0.295775  | 0.0208333  | 0.551216 |
# | micro av. f1        | 0.233387  | 0.0172414  | 0.269641 |
# | macro av. f1        | 0.110529  | 0.0111111  | 0.167222 |
# | micro av. pr.       | 0.136547  | 0.0251903  | 0.281455 |
# | macro av. pr.       | 0.0866698 | 0.0347622  | 0.18996  |
# | micro av. auc       | 0.659016  | 0.409583   | 0.635349 |
# | macro av. auc       | 0.410312  | 0.443257   | 0.561971 |
# | coverage error      | 0.684615  | 0.294872   | 1.1641   |
# | ranking loss        | 0.0974359 | 0.0587607  | 0.206197 |
#
# Individual Task Results
# |                     |         0 |          1 |        2 |
# |:--------------------|----------:|-----------:|---------:|
# | hamming loss        | 0.303205  | 0.0730769  | 0.482692 |
# | zero_one_loss       | 0.907692  | 0.266667   | 0.933333 |
# | one_error           | 0         | 0          | 0.025641 |
# | micro av. jaccard   | 0.13211   | 0.00869565 | 0.15583  |
# | macro av. jaccard   | 0.0624417 | 0.00568182 | 0.102846 |
# | micro av. precision | 0.155172  | 0.0142857  | 0.169927 |
# | macro av. precision | 0.0817394 | 0.00757576 | 0.104163 |
# | micro av. recall    | 0.470588  | 0.0217391  | 0.652582 |
# | macro av. recall    | 0.295775  | 0.0208333  | 0.551216 |
# | micro av. f1        | 0.233387  | 0.0172414  | 0.269641 |
# | macro av. f1        | 0.110529  | 0.0111111  | 0.167222 |
# | micro av. pr.       | 0.136547  | 0.0251903  | 0.281455 |
# | macro av. pr.       | 0.0866698 | 0.0347622  | 0.18996  |
# | micro av. auc       | 0.659016  | 0.409583   | 0.635349 |
# | macro av. auc       | 0.410312  | 0.443257   | 0.561971 |
# | coverage error      | 0.684615  | 0.294872   | 1.1641   |
# | ranking loss        | 0.0974359 | 0.0587607  | 0.206197 |
#
# ======================== Final Result ========================
# output shape =  (390, 12)
# ground truth shape =  (390, 12)
# Evaluation mode is incremental
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.303205  |
# | zero_one_loss       | 0.907692  |
# | one_error           | 0         |
# | micro av. jaccard   | 0.13211   |
# | macro av. jaccard   | 0.0624417 |
# | micro av. precision | 0.155172  |
# | macro av. precision | 0.0817394 |
# | micro av. recall    | 0.470588  |
# | macro av. recall    | 0.295775  |
# | micro av. f1        | 0.233387  |
# | macro av. f1        | 0.110529  |
# | micro av. pr.       | 0.136547  |
# | macro av. pr.       | 0.0866698 |
# | micro av. auc       | 0.659016  |
# | macro av. auc       | 0.410312  |
# | coverage error      | 0.684615  |
# | ranking loss        | 0.0974359 |
#
# label index list [0, 4, 8, 12]
# Task: 1, s index: 0, e index: 8
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |         1 |
# |:--------------------|----------:|----------:|
# | hamming loss        | 0.303205  | 0.188141  |
# | zero_one_loss       | 0.907692  | 0.925641  |
# | one_error           | 0         | 0         |
# | micro av. jaccard   | 0.13211   | 0.110606  |
# | macro av. jaccard   | 0.0624417 | 0.0340618 |
# | micro av. precision | 0.155172  | 0.136704  |
# | macro av. precision | 0.0817394 | 0.0446576 |
# | micro av. recall    | 0.470588  | 0.366834  |
# | macro av. recall    | 0.295775  | 0.158304  |
# | micro av. f1        | 0.233387  | 0.199181  |
# | macro av. f1        | 0.110529  | 0.0608201 |
# | micro av. pr.       | 0.136547  | 0.107897  |
# | macro av. pr.       | 0.0866698 | 0.060716  |
# | micro av. auc       | 0.659016  | 0.663176  |
# | macro av. auc       | 0.410312  | 0.426785  |
# | coverage error      | 0.684615  | 1.50256   |
# | ranking loss        | 0.0974359 | 0.140018  |
#
# label index list [0, 4, 8, 12]
# Task: 2, s index: 0, e index: 12
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |         1 |         2 |
# |:--------------------|----------:|----------:|----------:|
# | hamming loss        | 0.303205  | 0.188141  | 0.286325  |
# | zero_one_loss       | 0.907692  | 0.925641  | 1         |
# | one_error           | 0         | 0         | 0         |
# | micro av. jaccard   | 0.13211   | 0.110606  | 0.136598  |
# | macro av. jaccard   | 0.0624417 | 0.0340618 | 0.0569898 |
# | micro av. precision | 0.155172  | 0.136704  | 0.156805  |
# | macro av. precision | 0.0817394 | 0.0446576 | 0.0644928 |
# | micro av. recall    | 0.470588  | 0.366834  | 0.514563  |
# | macro av. recall    | 0.295775  | 0.158304  | 0.289275  |
# | micro av. f1        | 0.233387  | 0.199181  | 0.240363  |
# | macro av. f1        | 0.110529  | 0.0608201 | 0.0962875 |
# | micro av. pr.       | 0.136547  | 0.107897  | 0.181253  |
# | macro av. pr.       | 0.0866698 | 0.060716  | 0.103797  |
# | micro av. auc       | 0.659016  | 0.663176  | 0.642664  |
# | macro av. auc       | 0.410312  | 0.426785  | 0.471847  |
# | coverage error      | 0.684615  | 1.50256   | 4.96154   |
# | ranking loss        | 0.0974359 | 0.140018  | 0.348992  |
#
# Overall Task Results
# |                     |         0 |         1 |         2 |
# |:--------------------|----------:|----------:|----------:|
# | hamming loss        | 0.303205  | 0.188141  | 0.286325  |
# | zero_one_loss       | 0.907692  | 0.925641  | 1         |
# | one_error           | 0         | 0         | 0         |
# | micro av. jaccard   | 0.13211   | 0.110606  | 0.136598  |
# | macro av. jaccard   | 0.0624417 | 0.0340618 | 0.0569898 |
# | micro av. precision | 0.155172  | 0.136704  | 0.156805  |
# | macro av. precision | 0.0817394 | 0.0446576 | 0.0644928 |
# | micro av. recall    | 0.470588  | 0.366834  | 0.514563  |
# | macro av. recall    | 0.295775  | 0.158304  | 0.289275  |
# | micro av. f1        | 0.233387  | 0.199181  | 0.240363  |
# | macro av. f1        | 0.110529  | 0.0608201 | 0.0962875 |
# | micro av. pr.       | 0.136547  | 0.107897  | 0.181253  |
# | macro av. pr.       | 0.0866698 | 0.060716  | 0.103797  |
# | micro av. auc       | 0.659016  | 0.663176  | 0.642664  |
# | macro av. auc       | 0.410312  | 0.426785  | 0.471847  |
# | coverage error      | 0.684615  | 1.50256   | 4.96154   |
# | ranking loss        | 0.0974359 | 0.140018  | 0.348992  |
# 760.3739790916443 s.

# %%
# !python3 main.py --name plant --shuffle 1 --seed 833 --device 0
# Out:
# data_name: plant.
# seed: 833.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (588, 452) (390, 452)
# torch.Size([390, 12])
# 0.08803418803418804
# task: 0, #samples: 196, #negative samples: 75, #positive samples: 0
# task: 1, #samples: 196, #negative samples: 157, #positive samples: 0
# task: 2, #samples: 196, #negative samples: 173, #positive samples: 0
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:39<00:00,  2.48s/it]
# The task 0 result is following:
# output shape =  (390, 8)
# ground truth shape =  (390, 12)
# Evaluation mode is single
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.242308 |
# | zero_one_loss       | 0.689744 |
# | one_error           | 0        |
# | micro av. jaccard   | 0.255906 |
# | macro av. jaccard   | 0.204464 |
# | micro av. precision | 0.343008 |
# | macro av. precision | 0.25968  |
# | micro av. recall    | 0.501931 |
# | macro av. recall    | 0.404764 |
# | micro av. f1        | 0.407524 |
# | macro av. f1        | 0.316226 |
# | micro av. pr.       | 0.33339  |
# | macro av. pr.       | 0.288777 |
# | micro av. auc       | 0.744165 |
# | macro av. auc       | 0.666458 |
# | coverage error      | 1.14359  |
# | ranking loss        | 0.161966 |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:16<00:00,  3.23s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.242308 |
# | zero_one_loss       | 0.689744 |
# | one_error           | 0        |
# | micro av. jaccard   | 0.255906 |
# | macro av. jaccard   | 0.204464 |
# | micro av. precision | 0.343008 |
# | macro av. precision | 0.25968  |
# | micro av. recall    | 0.501931 |
# | macro av. recall    | 0.404764 |
# | micro av. f1        | 0.407524 |
# | macro av. f1        | 0.316226 |
# | micro av. pr.       | 0.33339  |
# | macro av. pr.       | 0.288777 |
# | micro av. auc       | 0.744165 |
# | macro av. auc       | 0.666458 |
# | coverage error      | 1.14359  |
# | ranking loss        | 0.161966 |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (390, 8)
# ground truth shape =  (390, 12)
# Evaluation mode is single
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.195513 |
# | zero_one_loss       | 0.638462 |
# | one_error           | 0        |
# | micro av. jaccard   | 0.199475 |
# | macro av. jaccard   | 0.144672 |
# | micro av. precision | 0.383838 |
# | macro av. precision | 0.295998 |
# | micro av. recall    | 0.293436 |
# | macro av. recall    | 0.211225 |
# | micro av. f1        | 0.332604 |
# | macro av. f1        | 0.238197 |
# | micro av. pr.       | 0.323554 |
# | macro av. pr.       | 0.290091 |
# | micro av. auc       | 0.735971 |
# | macro av. auc       | 0.670879 |
# | coverage error      | 1.20769  |
# | ranking loss        | 0.182906 |
#
# label index list [0, 4, 8, 12]
# Task: 1, s index: 4, e index: 8
# The test shape is (390, 12).
# |                     |        0 |         1 |
# |:--------------------|---------:|----------:|
# | hamming loss        | 0.195513 | 0.271154  |
# | zero_one_loss       | 0.638462 | 0.697436  |
# | one_error           | 0        | 0.0102564 |
# | micro av. jaccard   | 0.199475 | 0.0451467 |
# | macro av. jaccard   | 0.144672 | 0.0529319 |
# | micro av. precision | 0.383838 | 0.0549451 |
# | macro av. precision | 0.295998 | 0.0906787 |
# | micro av. recall    | 0.293436 | 0.20202   |
# | macro av. recall    | 0.211225 | 0.33443   |
# | micro av. f1        | 0.332604 | 0.0863931 |
# | macro av. f1        | 0.238197 | 0.0999954 |
# | micro av. pr.       | 0.323554 | 0.0580198 |
# | macro av. pr.       | 0.290091 | 0.0851562 |
# | micro av. auc       | 0.735971 | 0.469763  |
# | macro av. auc       | 0.670879 | 0.569983  |
# | coverage error      | 1.20769  | 0.653846  |
# | ranking loss        | 0.182906 | 0.133547  |
#
# Beginning compression, old model output size = 4
# Inter end shape =  8
# Old model output shape = 8
# Train single mode Epoch: 100%|██████████████████| 15/15 [00:57<00:00,  3.81s/it]
# Old model output shape =  8
# Train single mode Epoch: 100%|██████████████████| 40/40 [02:34<00:00,  3.87s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:18<00:00,  3.76s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |         1 |
# |:--------------------|---------:|----------:|
# | hamming loss        | 0.195513 | 0.271154  |
# | zero_one_loss       | 0.638462 | 0.697436  |
# | one_error           | 0        | 0.0102564 |
# | micro av. jaccard   | 0.199475 | 0.0451467 |
# | macro av. jaccard   | 0.144672 | 0.0529319 |
# | micro av. precision | 0.383838 | 0.0549451 |
# | macro av. precision | 0.295998 | 0.0906787 |
# | micro av. recall    | 0.293436 | 0.20202   |
# | macro av. recall    | 0.211225 | 0.33443   |
# | micro av. f1        | 0.332604 | 0.0863931 |
# | macro av. f1        | 0.238197 | 0.0999954 |
# | micro av. pr.       | 0.323554 | 0.0580198 |
# | macro av. pr.       | 0.290091 | 0.0851562 |
# | micro av. auc       | 0.735971 | 0.469763  |
# | macro av. auc       | 0.670879 | 0.569983  |
# | coverage error      | 1.20769  | 0.653846  |
# | ranking loss        | 0.182906 | 0.133547  |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (390, 12)
# ground truth shape =  (390, 12)
# Evaluation mode is single
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.292949  |
# | zero_one_loss       | 0.771795  |
# | one_error           | 0         |
# | micro av. jaccard   | 0.210708  |
# | macro av. jaccard   | 0.0920011 |
# | micro av. precision | 0.276018  |
# | macro av. precision | 0.115075  |
# | micro av. recall    | 0.471042  |
# | macro av. recall    | 0.279497  |
# | micro av. f1        | 0.348074  |
# | macro av. f1        | 0.148616  |
# | micro av. pr.       | 0.270703  |
# | macro av. pr.       | 0.187932  |
# | micro av. auc       | 0.66974   |
# | macro av. auc       | 0.530225  |
# | coverage error      | 1.21282   |
# | ranking loss        | 0.186966  |
#
# label index list [0, 4, 8, 12]
# Task: 1, s index: 4, e index: 8
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |         1 |
# |:--------------------|----------:|----------:|
# | hamming loss        | 0.292949  | 0.292949  |
# | zero_one_loss       | 0.771795  | 0.887179  |
# | one_error           | 0         | 0.0025641 |
# | micro av. jaccard   | 0.210708  | 0.109162  |
# | macro av. jaccard   | 0.0920011 | 0.0508694 |
# | micro av. precision | 0.276018  | 0.119149  |
# | macro av. precision | 0.115075  | 0.0530843 |
# | micro av. recall    | 0.471042  | 0.565657  |
# | macro av. recall    | 0.279497  | 0.326754  |
# | micro av. f1        | 0.348074  | 0.196837  |
# | macro av. f1        | 0.148616  | 0.0909646 |
# | micro av. pr.       | 0.270703  | 0.104061  |
# | macro av. pr.       | 0.187932  | 0.0673179 |
# | micro av. auc       | 0.66974   | 0.679381  |
# | macro av. auc       | 0.530225  | 0.519511  |
# | coverage error      | 1.21282   | 0.441026  |
# | ranking loss        | 0.186966  | 0.0653846 |
#
# label index list [0, 4, 8, 12]
# Task: 2, s index: 8, e index: 12
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |         1 |          2 |
# |:--------------------|----------:|----------:|-----------:|
# | hamming loss        | 0.292949  | 0.292949  | 0.276923   |
# | zero_one_loss       | 0.771795  | 0.887179  | 0.948718   |
# | one_error           | 0         | 0.0025641 | 0          |
# | micro av. jaccard   | 0.210708  | 0.109162  | 0.0181818  |
# | macro av. jaccard   | 0.0920011 | 0.0508694 | 0.00550964 |
# | micro av. precision | 0.276018  | 0.119149  | 0.0203046  |
# | macro av. precision | 0.115075  | 0.0530843 | 0.00550964 |
# | micro av. recall    | 0.471042  | 0.565657  | 0.148148   |
# | macro av. recall    | 0.279497  | 0.326754  | 0.25       |
# | micro av. f1        | 0.348074  | 0.196837  | 0.0357143  |
# | macro av. f1        | 0.148616  | 0.0909646 | 0.0107817  |
# | micro av. pr.       | 0.270703  | 0.104061  | 0.0338345  |
# | macro av. pr.       | 0.187932  | 0.0673179 | 0.0440874  |
# | micro av. auc       | 0.66974   | 0.679381  | 0.523265   |
# | macro av. auc       | 0.530225  | 0.519511  | 0.538285   |
# | coverage error      | 1.21282   | 0.441026  | 0.341026   |
# | ranking loss        | 0.186966  | 0.0653846 | 0.0675214  |
#
# Individual Task Results
# |                     |         0 |         1 |          2 |
# |:--------------------|----------:|----------:|-----------:|
# | hamming loss        | 0.292949  | 0.292949  | 0.276923   |
# | zero_one_loss       | 0.771795  | 0.887179  | 0.948718   |
# | one_error           | 0         | 0.0025641 | 0          |
# | micro av. jaccard   | 0.210708  | 0.109162  | 0.0181818  |
# | macro av. jaccard   | 0.0920011 | 0.0508694 | 0.00550964 |
# | micro av. precision | 0.276018  | 0.119149  | 0.0203046  |
# | macro av. precision | 0.115075  | 0.0530843 | 0.00550964 |
# | micro av. recall    | 0.471042  | 0.565657  | 0.148148   |
# | macro av. recall    | 0.279497  | 0.326754  | 0.25       |
# | micro av. f1        | 0.348074  | 0.196837  | 0.0357143  |
# | macro av. f1        | 0.148616  | 0.0909646 | 0.0107817  |
# | micro av. pr.       | 0.270703  | 0.104061  | 0.0338345  |
# | macro av. pr.       | 0.187932  | 0.0673179 | 0.0440874  |
# | micro av. auc       | 0.66974   | 0.679381  | 0.523265   |
# | macro av. auc       | 0.530225  | 0.519511  | 0.538285   |
# | coverage error      | 1.21282   | 0.441026  | 0.341026   |
# | ranking loss        | 0.186966  | 0.0653846 | 0.0675214  |
#
# ======================== Final Result ========================
# output shape =  (390, 12)
# ground truth shape =  (390, 12)
# Evaluation mode is incremental
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.292949  |
# | zero_one_loss       | 0.771795  |
# | one_error           | 0         |
# | micro av. jaccard   | 0.210708  |
# | macro av. jaccard   | 0.0920011 |
# | micro av. precision | 0.276018  |
# | macro av. precision | 0.115075  |
# | micro av. recall    | 0.471042  |
# | macro av. recall    | 0.279497  |
# | micro av. f1        | 0.348074  |
# | macro av. f1        | 0.148616  |
# | micro av. pr.       | 0.270703  |
# | macro av. pr.       | 0.187932  |
# | micro av. auc       | 0.66974   |
# | macro av. auc       | 0.530225  |
# | coverage error      | 1.21282   |
# | ranking loss        | 0.186966  |
#
# label index list [0, 4, 8, 12]
# Task: 1, s index: 0, e index: 8
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |         1 |
# |:--------------------|----------:|----------:|
# | hamming loss        | 0.292949  | 0.292949  |
# | zero_one_loss       | 0.771795  | 0.997436  |
# | one_error           | 0         | 0         |
# | micro av. jaccard   | 0.210708  | 0.163004  |
# | macro av. jaccard   | 0.0920011 | 0.0714353 |
# | micro av. precision | 0.276018  | 0.195175  |
# | macro av. precision | 0.115075  | 0.0840796 |
# | micro av. recall    | 0.471042  | 0.497207  |
# | macro av. recall    | 0.279497  | 0.303126  |
# | micro av. f1        | 0.348074  | 0.280315  |
# | macro av. f1        | 0.148616  | 0.11979   |
# | micro av. pr.       | 0.270703  | 0.210933  |
# | macro av. pr.       | 0.187932  | 0.127625  |
# | micro av. auc       | 0.66974   | 0.656849  |
# | macro av. auc       | 0.530225  | 0.524868  |
# | coverage error      | 1.21282   | 2.87949   |
# | ranking loss        | 0.186966  | 0.280696  |
#
# label index list [0, 4, 8, 12]
# Task: 2, s index: 0, e index: 12
# The test shape is (390, 12).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |         1 |         2 |
# |:--------------------|----------:|----------:|----------:|
# | hamming loss        | 0.292949  | 0.292949  | 0.287607  |
# | zero_one_loss       | 0.771795  | 0.997436  | 1         |
# | one_error           | 0         | 0         | 0         |
# | micro av. jaccard   | 0.210708  | 0.163004  | 0.12141   |
# | macro av. jaccard   | 0.0920011 | 0.0714353 | 0.0494601 |
# | micro av. precision | 0.276018  | 0.195175  | 0.14242   |
# | macro av. precision | 0.115075  | 0.0840796 | 0.0578896 |
# | micro av. recall    | 0.471042  | 0.497207  | 0.451456  |
# | macro av. recall    | 0.279497  | 0.303126  | 0.285417  |
# | micro av. f1        | 0.348074  | 0.280315  | 0.216531  |
# | macro av. f1        | 0.148616  | 0.11979   | 0.0834542 |
# | micro av. pr.       | 0.270703  | 0.210933  | 0.16719   |
# | macro av. pr.       | 0.187932  | 0.127625  | 0.099779  |
# | micro av. auc       | 0.66974   | 0.656849  | 0.645305  |
# | macro av. auc       | 0.530225  | 0.524868  | 0.52934   |
# | coverage error      | 1.21282   | 2.87949   | 4.8       |
# | ranking loss        | 0.186966  | 0.280696  | 0.337941  |
#
# Overall Task Results
# |                     |         0 |         1 |         2 |
# |:--------------------|----------:|----------:|----------:|
# | hamming loss        | 0.292949  | 0.292949  | 0.287607  |
# | zero_one_loss       | 0.771795  | 0.997436  | 1         |
# | one_error           | 0         | 0         | 0         |
# | micro av. jaccard   | 0.210708  | 0.163004  | 0.12141   |
# | macro av. jaccard   | 0.0920011 | 0.0714353 | 0.0494601 |
# | micro av. precision | 0.276018  | 0.195175  | 0.14242   |
# | macro av. precision | 0.115075  | 0.0840796 | 0.0578896 |
# | micro av. recall    | 0.471042  | 0.497207  | 0.451456  |
# | macro av. recall    | 0.279497  | 0.303126  | 0.285417  |
# | micro av. f1        | 0.348074  | 0.280315  | 0.216531  |
# | macro av. f1        | 0.148616  | 0.11979   | 0.0834542 |
# | micro av. pr.       | 0.270703  | 0.210933  | 0.16719   |
# | macro av. pr.       | 0.187932  | 0.127625  | 0.099779  |
# | micro av. auc       | 0.66974   | 0.656849  | 0.645305  |
# | macro av. auc       | 0.530225  | 0.524868  | 0.52934   |
# | coverage error      | 1.21282   | 2.87949   | 4.8       |
# | ranking loss        | 0.186966  | 0.280696  | 0.337941  |
# 832.7265782356262 s.
