# %%
# !python3 main.py --name yeast --shuffle 1 --seed 5 --device 3
# Out:
# data_name: yeast.
# seed: 5.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (1500, 117) (917, 117)
# torch.Size([917, 14])
# 0.3037077426390403
# task: 0, #samples: 500, #negative samples: 28, #positive samples: 5
# task: 1, #samples: 500, #negative samples: 389, #positive samples: 8
# task: 2, #samples: 500, #negative samples: 184, #positive samples: 0
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:25<00:00,  2.14s/it]
# The task 0 result is following:
# output shape =  (917, 10)
# ground truth shape =  (917, 14)
# Evaluation mode is single
# label index list [0, 7, 10, 13]
# Task: 0, s index: 0, e index: 7
# The test shape is (917, 14).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.24334  |
# | zero_one_loss       | 0.790622 |
# | one_error           | 0        |
# | micro av. jaccard   | 0.551149 |
# | macro av. jaccard   | 0.357852 |
# | micro av. precision | 0.649949 |
# | macro av. precision | 0.428961 |
# | micro av. recall    | 0.783817 |
# | macro av. recall    | 0.523017 |
# | micro av. f1        | 0.710634 |
# | macro av. f1        | 0.45782  |
# | micro av. pr.       | 0.702279 |
# | macro av. pr.       | 0.479209 |
# | micro av. auc       | 0.818063 |
# | macro av. auc       | 0.601593 |
# | coverage error      | 3.52563  |
# | ranking loss        | 0.144747 |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:17<00:00,  3.52s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.24334  |
# | zero_one_loss       | 0.790622 |
# | one_error           | 0        |
# | micro av. jaccard   | 0.551149 |
# | macro av. jaccard   | 0.357852 |
# | micro av. precision | 0.649949 |
# | macro av. precision | 0.428961 |
# | micro av. recall    | 0.783817 |
# | macro av. recall    | 0.523017 |
# | micro av. f1        | 0.710634 |
# | macro av. f1        | 0.45782  |
# | micro av. pr.       | 0.702279 |
# | macro av. pr.       | 0.479209 |
# | micro av. auc       | 0.818063 |
# | macro av. auc       | 0.601593 |
# | coverage error      | 3.52563  |
# | ranking loss        | 0.144747 |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (917, 10)
# ground truth shape =  (917, 14)
# Evaluation mode is single
# label index list [0, 7, 10, 13]
# Task: 0, s index: 0, e index: 7
# The test shape is (917, 14).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |          0 |
# |:--------------------|-----------:|
# | hamming loss        | 0.236953   |
# | zero_one_loss       | 0.757906   |
# | one_error           | 0.00109051 |
# | micro av. jaccard   | 0.543517   |
# | macro av. jaccard   | 0.332042   |
# | micro av. precision | 0.671736   |
# | macro av. precision | 0.459612   |
# | micro av. recall    | 0.74009    |
# | macro av. recall    | 0.467788   |
# | micro av. f1        | 0.704258   |
# | macro av. f1        | 0.424503   |
# | micro av. pr.       | 0.698078   |
# | macro av. pr.       | 0.480219   |
# | micro av. auc       | 0.817468   |
# | macro av. auc       | 0.596799   |
# | coverage error      | 3.52236    |
# | ranking loss        | 0.144875   |
#
# label index list [0, 7, 10, 13]
# Task: 1, s index: 7, e index: 10
# The test shape is (917, 14).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |          0 |         1 |
# |:--------------------|-----------:|----------:|
# | hamming loss        | 0.236953   | 0.628862  |
# | zero_one_loss       | 0.757906   | 0.944384  |
# | one_error           | 0.00109051 | 0.0294438 |
# | micro av. jaccard   | 0.543517   | 0.135432  |
# | macro av. jaccard   | 0.332042   | 0.0985096 |
# | micro av. precision | 0.671736   | 0.147764  |
# | macro av. precision | 0.459612   | 0.0985096 |
# | micro av. recall    | 0.74009    | 0.618721  |
# | macro av. recall    | 0.467788   | 0.666667  |
# | micro av. f1        | 0.704258   | 0.238556  |
# | macro av. f1        | 0.424503   | 0.168416  |
# | micro av. pr.       | 0.698078   | 0.147695  |
# | macro av. pr.       | 0.480219   | 0.174514  |
# | micro av. auc       | 0.817468   | 0.47187   |
# | macro av. auc       | 0.596799   | 0.521844  |
# | coverage error      | 3.52236    | 0.693566  |
# | ranking loss        | 0.144875   | 0.153762  |
#
# Beginning compression, old model output size = 7
# Inter end shape =  10
# Old model output shape = 10
# Train single mode Epoch: 100%|██████████████████| 15/15 [00:51<00:00,  3.45s/it]
# Old model output shape =  10
# Train single mode Epoch: 100%|██████████████████| 40/40 [02:18<00:00,  3.47s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:17<00:00,  3.43s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |          0 |         1 |
# |:--------------------|-----------:|----------:|
# | hamming loss        | 0.236953   | 0.628862  |
# | zero_one_loss       | 0.757906   | 0.944384  |
# | one_error           | 0.00109051 | 0.0294438 |
# | micro av. jaccard   | 0.543517   | 0.135432  |
# | macro av. jaccard   | 0.332042   | 0.0985096 |
# | micro av. precision | 0.671736   | 0.147764  |
# | macro av. precision | 0.459612   | 0.0985096 |
# | micro av. recall    | 0.74009    | 0.618721  |
# | macro av. recall    | 0.467788   | 0.666667  |
# | micro av. f1        | 0.704258   | 0.238556  |
# | macro av. f1        | 0.424503   | 0.168416  |
# | micro av. pr.       | 0.698078   | 0.147695  |
# | macro av. pr.       | 0.480219   | 0.174514  |
# | micro av. auc       | 0.817468   | 0.47187   |
# | macro av. auc       | 0.596799   | 0.521844  |
# | coverage error      | 3.52236    | 0.693566  |
# | ranking loss        | 0.144875   | 0.153762  |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (917, 13)
# ground truth shape =  (917, 14)
# Evaluation mode is single
# label index list [0, 7, 10, 13]
# Task: 0, s index: 0, e index: 7
# The test shape is (917, 14).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |          0 |
# |:--------------------|-----------:|
# | hamming loss        | 0.260165   |
# | zero_one_loss       | 0.806979   |
# | one_error           | 0.00109051 |
# | micro av. jaccard   | 0.513687   |
# | macro av. jaccard   | 0.274809   |
# | micro av. precision | 0.641221   |
# | macro av. precision | 0.274809   |
# | micro av. recall    | 0.720883   |
# | macro av. recall    | 0.428571   |
# | micro av. f1        | 0.678723   |
# | macro av. f1        | 0.330153   |
# | micro av. pr.       | 0.688975   |
# | macro av. pr.       | 0.398016   |
# | micro av. auc       | 0.788178   |
# | macro av. auc       | 0.534756   |
# | coverage error      | 3.62486    |
# | ranking loss        | 0.156398   |
#
# label index list [0, 7, 10, 13]
# Task: 1, s index: 7, e index: 10
# The test shape is (917, 14).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |          0 |         1 |
# |:--------------------|-----------:|----------:|
# | hamming loss        | 0.260165   | 0.498364  |
# | zero_one_loss       | 0.806979   | 0.902944  |
# | one_error           | 0.00109051 | 0.0152672 |
# | micro av. jaccard   | 0.513687   | 0.183443  |
# | macro av. jaccard   | 0.274809   | 0.126614  |
# | micro av. precision | 0.641221   | 0.198838  |
# | macro av. precision | 0.274809   | 0.131138  |
# | micro av. recall    | 0.720883   | 0.703196  |
# | macro av. recall    | 0.428571   | 0.566866  |
# | micro av. f1        | 0.678723   | 0.310015  |
# | macro av. f1        | 0.330153   | 0.212544  |
# | micro av. pr.       | 0.688975   | 0.18746   |
# | macro av. pr.       | 0.398016   | 0.165951  |
# | micro av. auc       | 0.788178   | 0.594383  |
# | macro av. auc       | 0.534756   | 0.489679  |
# | coverage error      | 3.62486    | 0.59651   |
# | ranking loss        | 0.156398   | 0.0594329 |
#
# label index list [0, 7, 10, 13]
# Task: 2, s index: 10, e index: 13
# The test shape is (917, 14).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |          0 |         1 |          2 |
# |:--------------------|-----------:|----------:|-----------:|
# | hamming loss        | 0.260165   | 0.498364  | 0.325336   |
# | zero_one_loss       | 0.806979   | 0.902944  | 0.70229    |
# | one_error           | 0.00109051 | 0.0152672 | 0.00654308 |
# | micro av. jaccard   | 0.513687   | 0.183443  | 0.269388   |
# | macro av. jaccard   | 0.274809   | 0.126614  | 0.119956   |
# | micro av. precision | 0.641221   | 0.198838  | 0.356371   |
# | macro av. precision | 0.274809   | 0.131138  | 0.119956   |
# | micro av. recall    | 0.720883   | 0.703196  | 0.524642   |
# | macro av. recall    | 0.428571   | 0.566866  | 0.333333   |
# | micro av. f1        | 0.678723   | 0.310015  | 0.424437   |
# | macro av. f1        | 0.330153   | 0.212544  | 0.176423   |
# | micro av. pr.       | 0.688975   | 0.18746   | 0.479649   |
# | macro av. pr.       | 0.398016   | 0.165951  | 0.395206   |
# | micro av. auc       | 0.788178   | 0.594383  | 0.714507   |
# | macro av. auc       | 0.534756   | 0.489679  | 0.626863   |
# | coverage error      | 3.62486    | 0.59651   | 1.08833    |
# | ranking loss        | 0.156398   | 0.0594329 | 0.2012     |
#
# Individual Task Results
# |                     |          0 |         1 |          2 |
# |:--------------------|-----------:|----------:|-----------:|
# | hamming loss        | 0.260165   | 0.498364  | 0.325336   |
# | zero_one_loss       | 0.806979   | 0.902944  | 0.70229    |
# | one_error           | 0.00109051 | 0.0152672 | 0.00654308 |
# | micro av. jaccard   | 0.513687   | 0.183443  | 0.269388   |
# | macro av. jaccard   | 0.274809   | 0.126614  | 0.119956   |
# | micro av. precision | 0.641221   | 0.198838  | 0.356371   |
# | macro av. precision | 0.274809   | 0.131138  | 0.119956   |
# | micro av. recall    | 0.720883   | 0.703196  | 0.524642   |
# | macro av. recall    | 0.428571   | 0.566866  | 0.333333   |
# | micro av. f1        | 0.678723   | 0.310015  | 0.424437   |
# | macro av. f1        | 0.330153   | 0.212544  | 0.176423   |
# | micro av. pr.       | 0.688975   | 0.18746   | 0.479649   |
# | macro av. pr.       | 0.398016   | 0.165951  | 0.395206   |
# | micro av. auc       | 0.788178   | 0.594383  | 0.714507   |
# | macro av. auc       | 0.534756   | 0.489679  | 0.626863   |
# | coverage error      | 3.62486    | 0.59651   | 1.08833    |
# | ranking loss        | 0.156398   | 0.0594329 | 0.2012     |
#
# ======================== Final Result ========================
# output shape =  (917, 13)
# ground truth shape =  (917, 14)
# Evaluation mode is incremental
# label index list [0, 7, 10, 13]
# Task: 0, s index: 0, e index: 7
# The test shape is (917, 14).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |          0 |
# |:--------------------|-----------:|
# | hamming loss        | 0.260165   |
# | zero_one_loss       | 0.806979   |
# | one_error           | 0.00109051 |
# | micro av. jaccard   | 0.513687   |
# | macro av. jaccard   | 0.274809   |
# | micro av. precision | 0.641221   |
# | macro av. precision | 0.274809   |
# | micro av. recall    | 0.720883   |
# | macro av. recall    | 0.428571   |
# | micro av. f1        | 0.678723   |
# | macro av. f1        | 0.330153   |
# | micro av. pr.       | 0.688975   |
# | macro av. pr.       | 0.398016   |
# | micro av. auc       | 0.788178   |
# | macro av. auc       | 0.534756   |
# | coverage error      | 3.62486    |
# | ranking loss        | 0.156398   |
#
# label index list [0, 7, 10, 13]
# Task: 1, s index: 0, e index: 10
# The test shape is (917, 14).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |          0 |        1 |
# |:--------------------|-----------:|---------:|
# | hamming loss        | 0.260165   | 0.331625 |
# | zero_one_loss       | 0.806979   | 0.990185 |
# | one_error           | 0.00109051 | 0        |
# | micro av. jaccard   | 0.513687   | 0.405242 |
# | macro av. jaccard   | 0.274809   | 0.230351 |
# | micro av. precision | 0.641221   | 0.48186  |
# | macro av. precision | 0.274809   | 0.231708 |
# | micro av. recall    | 0.720883   | 0.718198 |
# | macro av. recall    | 0.428571   | 0.47006  |
# | micro av. f1        | 0.678723   | 0.576757 |
# | macro av. f1        | 0.330153   | 0.29487  |
# | micro av. pr.       | 0.688975   | 0.595735 |
# | macro av. pr.       | 0.398016   | 0.328396 |
# | micro av. auc       | 0.788178   | 0.735511 |
# | macro av. auc       | 0.534756   | 0.521233 |
# | coverage error      | 3.62486    | 5.57688  |
# | ranking loss        | 0.156398   | 0.214839 |
#
# label index list [0, 7, 10, 13]
# Task: 2, s index: 0, e index: 13
# The test shape is (917, 14).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |          0 |        1 |        2 |
# |:--------------------|-----------:|---------:|---------:|
# | hamming loss        | 0.260165   | 0.331625 | 0.330174 |
# | zero_one_loss       | 0.806979   | 0.990185 | 1        |
# | one_error           | 0.00109051 | 0        | 0        |
# | micro av. jaccard   | 0.513687   | 0.405242 | 0.378984 |
# | macro av. jaccard   | 0.274809   | 0.230351 | 0.204875 |
# | micro av. precision | 0.641221   | 0.48186  | 0.459625 |
# | macro av. precision | 0.274809   | 0.231708 | 0.205919 |
# | micro av. recall    | 0.720883   | 0.718198 | 0.683552 |
# | macro av. recall    | 0.428571   | 0.47006  | 0.438508 |
# | micro av. f1        | 0.678723   | 0.576757 | 0.549657 |
# | macro av. f1        | 0.330153   | 0.29487  | 0.267536 |
# | micro av. pr.       | 0.688975   | 0.595735 | 0.570065 |
# | macro av. pr.       | 0.398016   | 0.328396 | 0.343814 |
# | micro av. auc       | 0.788178   | 0.735511 | 0.723765 |
# | macro av. auc       | 0.534756   | 0.521233 | 0.545609 |
# | coverage error      | 3.62486    | 5.57688  | 8.30207  |
# | ranking loss        | 0.156398   | 0.214839 | 0.265266 |
#
# Overall Task Results
# |                     |          0 |        1 |        2 |
# |:--------------------|-----------:|---------:|---------:|
# | hamming loss        | 0.260165   | 0.331625 | 0.330174 |
# | zero_one_loss       | 0.806979   | 0.990185 | 1        |
# | one_error           | 0.00109051 | 0        | 0        |
# | micro av. jaccard   | 0.513687   | 0.405242 | 0.378984 |
# | macro av. jaccard   | 0.274809   | 0.230351 | 0.204875 |
# | micro av. precision | 0.641221   | 0.48186  | 0.459625 |
# | macro av. precision | 0.274809   | 0.231708 | 0.205919 |
# | micro av. recall    | 0.720883   | 0.718198 | 0.683552 |
# | macro av. recall    | 0.428571   | 0.47006  | 0.438508 |
# | micro av. f1        | 0.678723   | 0.576757 | 0.549657 |
# | macro av. f1        | 0.330153   | 0.29487  | 0.267536 |
# | micro av. pr.       | 0.688975   | 0.595735 | 0.570065 |
# | macro av. pr.       | 0.398016   | 0.328396 | 0.343814 |
# | micro av. auc       | 0.788178   | 0.735511 | 0.723765 |
# | macro av. auc       | 0.534756   | 0.521233 | 0.545609 |
# | coverage error      | 3.62486    | 5.57688  | 8.30207  |
# | ranking loss        | 0.156398   | 0.214839 | 0.265266 |
# 750.9911122322083 s.

# %%
# !python3 main.py --name yeast --shuffle 1 --seed 3 --device 3
# Out:
# data_name: yeast.
# seed: 3.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (1500, 117) (917, 117)
# torch.Size([917, 14])
# 0.3037077426390403
# task: 0, #samples: 500, #negative samples: 44, #positive samples: 0
# task: 1, #samples: 500, #negative samples: 152, #positive samples: 10
# task: 2, #samples: 500, #negative samples: 144, #positive samples: 7
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:41<00:00,  2.53s/it]
# The task 0 result is following:
# output shape =  (917, 10)
# ground truth shape =  (917, 14)
# Evaluation mode is single
# label index list [0, 7, 10, 13]
# Task: 0, s index: 0, e index: 7
# The test shape is (917, 14).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.195358 |
# | zero_one_loss       | 0.615049 |
# | one_error           | 0        |
# | micro av. jaccard   | 0.552782 |
# | macro av. jaccard   | 0.27157  |
# | micro av. precision | 0.714945 |
# | macro av. precision | 0.290146 |
# | micro av. recall    | 0.709058 |
# | macro av. recall    | 0.375125 |
# | micro av. f1        | 0.711989 |
# | macro av. f1        | 0.326927 |
# | micro av. pr.       | 0.703898 |
# | macro av. pr.       | 0.420446 |
# | micro av. auc       | 0.826516 |
# | macro av. auc       | 0.608936 |
# | coverage error      | 3.32606  |
# | ranking loss        | 0.140422 |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:18<00:00,  3.65s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.195358 |
# | zero_one_loss       | 0.615049 |
# | one_error           | 0        |
# | micro av. jaccard   | 0.552782 |
# | macro av. jaccard   | 0.27157  |
# | micro av. precision | 0.714945 |
# | macro av. precision | 0.290146 |
# | micro av. recall    | 0.709058 |
# | macro av. recall    | 0.375125 |
# | micro av. f1        | 0.711989 |
# | macro av. f1        | 0.326927 |
# | micro av. pr.       | 0.703898 |
# | macro av. pr.       | 0.420446 |
# | micro av. auc       | 0.826516 |
# | macro av. auc       | 0.608936 |
# | coverage error      | 3.32606  |
# | ranking loss        | 0.140422 |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (917, 10)
# ground truth shape =  (917, 14)
# Evaluation mode is single
# label index list [0, 7, 10, 13]
# Task: 0, s index: 0, e index: 7
# The test shape is (917, 14).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.189593 |
# | zero_one_loss       | 0.599782 |
# | one_error           | 0        |
# | micro av. jaccard   | 0.555353 |
# | macro av. jaccard   | 0.270498 |
# | micro av. precision | 0.733945 |
# | macro av. precision | 0.303398 |
# | micro av. recall    | 0.695334 |
# | macro av. recall    | 0.36014  |
# | micro av. f1        | 0.714118 |
# | macro av. f1        | 0.325837 |
# | micro av. pr.       | 0.70261  |
# | macro av. pr.       | 0.421651 |
# | micro av. auc       | 0.826549 |
# | macro av. auc       | 0.609203 |
# | coverage error      | 3.40458  |
# | ranking loss        | 0.14193  |
#
# label index list [0, 7, 10, 13]
# Task: 1, s index: 7, e index: 10
# The test shape is (917, 14).
# |                     |        0 |         1 |
# |:--------------------|---------:|----------:|
# | hamming loss        | 0.189593 | 0.514358  |
# | zero_one_loss       | 0.599782 | 0.810251  |
# | one_error           | 0        | 0.23446   |
# | micro av. jaccard   | 0.555353 | 0.135614  |
# | macro av. jaccard   | 0.270498 | 0.0834777 |
# | micro av. precision | 0.733945 | 0.24      |
# | macro av. precision | 0.303398 | 0.218289  |
# | micro av. recall    | 0.695334 | 0.237687  |
# | macro av. recall    | 0.36014  | 0.334618  |
# | micro av. f1        | 0.714118 | 0.238838  |
# | macro av. f1        | 0.325837 | 0.13642   |
# | micro av. pr.       | 0.70261  | 0.29252   |
# | macro av. pr.       | 0.421651 | 0.335011  |
# | micro av. auc       | 0.826549 | 0.433489  |
# | macro av. auc       | 0.609203 | 0.497446  |
# | coverage error      | 3.40458  | 1.61505   |
# | ranking loss        | 0.14193  | 0.416031  |
#
# Beginning compression, old model output size = 7
# Inter end shape =  10
# Old model output shape = 10
# Train single mode Epoch: 100%|██████████████████| 15/15 [00:50<00:00,  3.40s/it]
# Old model output shape =  10
# Train single mode Epoch: 100%|██████████████████| 40/40 [02:25<00:00,  3.63s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:18<00:00,  3.71s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |         1 |
# |:--------------------|---------:|----------:|
# | hamming loss        | 0.189593 | 0.514358  |
# | zero_one_loss       | 0.599782 | 0.810251  |
# | one_error           | 0        | 0.23446   |
# | micro av. jaccard   | 0.555353 | 0.135614  |
# | macro av. jaccard   | 0.270498 | 0.0834777 |
# | micro av. precision | 0.733945 | 0.24      |
# | macro av. precision | 0.303398 | 0.218289  |
# | micro av. recall    | 0.695334 | 0.237687  |
# | macro av. recall    | 0.36014  | 0.334618  |
# | micro av. f1        | 0.714118 | 0.238838  |
# | macro av. f1        | 0.325837 | 0.13642   |
# | micro av. pr.       | 0.70261  | 0.29252   |
# | macro av. pr.       | 0.421651 | 0.335011  |
# | micro av. auc       | 0.826549 | 0.433489  |
# | macro av. auc       | 0.609203 | 0.497446  |
# | coverage error      | 3.40458  | 1.61505   |
# | ranking loss        | 0.14193  | 0.416031  |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (917, 13)
# ground truth shape =  (917, 14)
# Evaluation mode is single
# label index list [0, 7, 10, 13]
# Task: 0, s index: 0, e index: 7
# The test shape is (917, 14).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.199096 |
# | zero_one_loss       | 0.654308 |
# | one_error           | 0        |
# | micro av. jaccard   | 0.517554 |
# | macro av. jaccard   | 0.213585 |
# | micro av. precision | 0.747546 |
# | macro av. precision | 0.213585 |
# | micro av. recall    | 0.627173 |
# | macro av. recall    | 0.285714 |
# | micro av. f1        | 0.68209  |
# | macro av. f1        | 0.244439 |
# | micro av. pr.       | 0.665511 |
# | macro av. pr.       | 0.355976 |
# | micro av. auc       | 0.792313 |
# | macro av. auc       | 0.505164 |
# | coverage error      | 3.33915  |
# | ranking loss        | 0.145493 |
#
# label index list [0, 7, 10, 13]
# Task: 1, s index: 7, e index: 10
# The test shape is (917, 14).
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | hamming loss        | 0.199096 | 0.480916 |
# | zero_one_loss       | 0.654308 | 0.805889 |
# | one_error           | 0        | 0.175573 |
# | micro av. jaccard   | 0.517554 | 0.252964 |
# | macro av. jaccard   | 0.213585 | 0.239188 |
# | micro av. precision | 0.747546 | 0.348638 |
# | macro av. precision | 0.213585 | 0.325784 |
# | micro av. recall    | 0.627173 | 0.479657 |
# | macro av. recall    | 0.285714 | 0.44701  |
# | micro av. f1        | 0.68209  | 0.403785 |
# | macro av. f1        | 0.244439 | 0.37651  |
# | micro av. pr.       | 0.665511 | 0.343506 |
# | macro av. pr.       | 0.355976 | 0.335863 |
# | micro av. auc       | 0.792313 | 0.519183 |
# | macro av. auc       | 0.505164 | 0.476975 |
# | coverage error      | 3.33915  | 1.64995  |
# | ranking loss        | 0.145493 | 0.358779 |
#
# label index list [0, 7, 10, 13]
# Task: 2, s index: 10, e index: 13
# The test shape is (917, 14).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | hamming loss        | 0.199096 | 0.480916 | 0.423119 |
# | zero_one_loss       | 0.654308 | 0.805889 | 0.805889 |
# | one_error           | 0        | 0.175573 | 0.046892 |
# | micro av. jaccard   | 0.517554 | 0.252964 | 0.213514 |
# | macro av. jaccard   | 0.213585 | 0.239188 | 0.126915 |
# | micro av. precision | 0.747546 | 0.348638 | 0.306796 |
# | macro av. precision | 0.213585 | 0.325784 | 0.20539  |
# | micro av. recall    | 0.627173 | 0.479657 | 0.412533 |
# | macro av. recall    | 0.285714 | 0.44701  | 0.36302  |
# | micro av. f1        | 0.68209  | 0.403785 | 0.351893 |
# | macro av. f1        | 0.244439 | 0.37651  | 0.202485 |
# | micro av. pr.       | 0.665511 | 0.343506 | 0.294198 |
# | macro av. pr.       | 0.355976 | 0.335863 | 0.236371 |
# | micro av. auc       | 0.792313 | 0.519183 | 0.571653 |
# | macro av. auc       | 0.505164 | 0.476975 | 0.420659 |
# | coverage error      | 3.33915  | 1.64995  | 1.28026  |
# | ranking loss        | 0.145493 | 0.358779 | 0.245911 |
#
# Individual Task Results
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | hamming loss        | 0.199096 | 0.480916 | 0.423119 |
# | zero_one_loss       | 0.654308 | 0.805889 | 0.805889 |
# | one_error           | 0        | 0.175573 | 0.046892 |
# | micro av. jaccard   | 0.517554 | 0.252964 | 0.213514 |
# | macro av. jaccard   | 0.213585 | 0.239188 | 0.126915 |
# | micro av. precision | 0.747546 | 0.348638 | 0.306796 |
# | macro av. precision | 0.213585 | 0.325784 | 0.20539  |
# | micro av. recall    | 0.627173 | 0.479657 | 0.412533 |
# | macro av. recall    | 0.285714 | 0.44701  | 0.36302  |
# | micro av. f1        | 0.68209  | 0.403785 | 0.351893 |
# | macro av. f1        | 0.244439 | 0.37651  | 0.202485 |
# | micro av. pr.       | 0.665511 | 0.343506 | 0.294198 |
# | macro av. pr.       | 0.355976 | 0.335863 | 0.236371 |
# | micro av. auc       | 0.792313 | 0.519183 | 0.571653 |
# | macro av. auc       | 0.505164 | 0.476975 | 0.420659 |
# | coverage error      | 3.33915  | 1.64995  | 1.28026  |
# | ranking loss        | 0.145493 | 0.358779 | 0.245911 |
#
# ======================== Final Result ========================
# output shape =  (917, 13)
# ground truth shape =  (917, 14)
# Evaluation mode is incremental
# label index list [0, 7, 10, 13]
# Task: 0, s index: 0, e index: 7
# The test shape is (917, 14).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.199096 |
# | zero_one_loss       | 0.654308 |
# | one_error           | 0        |
# | micro av. jaccard   | 0.517554 |
# | macro av. jaccard   | 0.213585 |
# | micro av. precision | 0.747546 |
# | macro av. precision | 0.213585 |
# | micro av. recall    | 0.627173 |
# | macro av. recall    | 0.285714 |
# | micro av. f1        | 0.68209  |
# | macro av. f1        | 0.244439 |
# | micro av. pr.       | 0.665511 |
# | macro av. pr.       | 0.355976 |
# | micro av. auc       | 0.792313 |
# | macro av. auc       | 0.505164 |
# | coverage error      | 3.33915  |
# | ranking loss        | 0.145493 |
#
# label index list [0, 7, 10, 13]
# Task: 1, s index: 0, e index: 10
# The test shape is (917, 14).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | hamming loss        | 0.199096 | 0.283642 |
# | zero_one_loss       | 0.654308 | 0.916031 |
# | one_error           | 0        | 0        |
# | micro av. jaccard   | 0.517554 | 0.411538 |
# | macro av. jaccard   | 0.213585 | 0.221266 |
# | micro av. precision | 0.747546 | 0.5832   |
# | macro av. precision | 0.213585 | 0.247245 |
# | micro av. recall    | 0.627173 | 0.583013 |
# | macro av. recall    | 0.285714 | 0.334103 |
# | micro av. f1        | 0.68209  | 0.583106 |
# | macro av. f1        | 0.244439 | 0.28406  |
# | micro av. pr.       | 0.665511 | 0.619744 |
# | macro av. pr.       | 0.355976 | 0.349942 |
# | micro av. auc       | 0.792313 | 0.753259 |
# | macro av. auc       | 0.505164 | 0.496707 |
# | coverage error      | 3.33915  | 6.14395  |
# | ranking loss        | 0.145493 | 0.241969 |
#
# label index list [0, 7, 10, 13]
# Task: 2, s index: 0, e index: 13
# The test shape is (917, 14).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | hamming loss        | 0.199096 | 0.283642 | 0.315829 |
# | zero_one_loss       | 0.654308 | 0.916031 | 0.991276 |
# | one_error           | 0        | 0        | 0        |
# | micro av. jaccard   | 0.517554 | 0.411538 | 0.361864 |
# | macro av. jaccard   | 0.213585 | 0.221266 | 0.199492 |
# | micro av. precision | 0.747546 | 0.5832   | 0.514582 |
# | macro av. precision | 0.213585 | 0.247245 | 0.237586 |
# | micro av. recall    | 0.627173 | 0.583013 | 0.549408 |
# | macro av. recall    | 0.285714 | 0.334103 | 0.340776 |
# | micro av. f1        | 0.68209  | 0.583106 | 0.531425 |
# | macro av. f1        | 0.244439 | 0.28406  | 0.265235 |
# | micro av. pr.       | 0.665511 | 0.619744 | 0.543471 |
# | macro av. pr.       | 0.355976 | 0.349942 | 0.323733 |
# | micro av. auc       | 0.792313 | 0.753259 | 0.718828 |
# | macro av. auc       | 0.505164 | 0.496707 | 0.479158 |
# | coverage error      | 3.33915  | 6.14395  | 8.27372  |
# | ranking loss        | 0.145493 | 0.241969 | 0.266467 |
#
# Overall Task Results
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | hamming loss        | 0.199096 | 0.283642 | 0.315829 |
# | zero_one_loss       | 0.654308 | 0.916031 | 0.991276 |
# | one_error           | 0        | 0        | 0        |
# | micro av. jaccard   | 0.517554 | 0.411538 | 0.361864 |
# | macro av. jaccard   | 0.213585 | 0.221266 | 0.199492 |
# | micro av. precision | 0.747546 | 0.5832   | 0.514582 |
# | macro av. precision | 0.213585 | 0.247245 | 0.237586 |
# | micro av. recall    | 0.627173 | 0.583013 | 0.549408 |
# | macro av. recall    | 0.285714 | 0.334103 | 0.340776 |
# | micro av. f1        | 0.68209  | 0.583106 | 0.531425 |
# | macro av. f1        | 0.244439 | 0.28406  | 0.265235 |
# | micro av. pr.       | 0.665511 | 0.619744 | 0.543471 |
# | macro av. pr.       | 0.355976 | 0.349942 | 0.323733 |
# | micro av. auc       | 0.792313 | 0.753259 | 0.718828 |
# | macro av. auc       | 0.505164 | 0.496707 | 0.479158 |
# | coverage error      | 3.33915  | 6.14395  | 8.27372  |
# | ranking loss        | 0.145493 | 0.241969 | 0.266467 |
# 825.5328843593597 s.

# %%
# !python3 main.py --name yeast --shuffle 1 --seed 4 --device 3
# Out:
# data_name: yeast.
# seed: 4.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (1500, 117) (917, 117)
# torch.Size([917, 14])
# 0.3037077426390403
# task: 0, #samples: 500, #negative samples: 19, #positive samples: 1
# task: 1, #samples: 500, #negative samples: 337, #positive samples: 2
# task: 2, #samples: 500, #negative samples: 288, #positive samples: 0
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:38<00:00,  2.45s/it]
# The task 0 result is following:
# output shape =  (917, 10)
# ground truth shape =  (917, 14)
# Evaluation mode is single
# label index list [0, 7, 10, 13]
# Task: 0, s index: 0, e index: 7
# The test shape is (917, 14).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.298177 |
# | zero_one_loss       | 0.933479 |
# | one_error           | 0        |
# | micro av. jaccard   | 0.48576  |
# | macro av. jaccard   | 0.389889 |
# | micro av. precision | 0.57543  |
# | macro av. precision | 0.461645 |
# | micro av. recall    | 0.757119 |
# | macro av. recall    | 0.618148 |
# | micro av. f1        | 0.653888 |
# | macro av. f1        | 0.524222 |
# | micro av. pr.       | 0.653145 |
# | macro av. pr.       | 0.526757 |
# | micro av. auc       | 0.776909 |
# | macro av. auc       | 0.65431  |
# | coverage error      | 3.94438  |
# | ranking loss        | 0.198891 |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:18<00:00,  3.61s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.298177 |
# | zero_one_loss       | 0.933479 |
# | one_error           | 0        |
# | micro av. jaccard   | 0.48576  |
# | macro av. jaccard   | 0.389889 |
# | micro av. precision | 0.57543  |
# | macro av. precision | 0.461645 |
# | micro av. recall    | 0.757119 |
# | macro av. recall    | 0.618148 |
# | micro av. f1        | 0.653888 |
# | macro av. f1        | 0.524222 |
# | micro av. pr.       | 0.653145 |
# | macro av. pr.       | 0.526757 |
# | micro av. auc       | 0.776909 |
# | macro av. auc       | 0.65431  |
# | coverage error      | 3.94438  |
# | ranking loss        | 0.198891 |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (917, 10)
# ground truth shape =  (917, 14)
# Evaluation mode is single
# label index list [0, 7, 10, 13]
# Task: 0, s index: 0, e index: 7
# The test shape is (917, 14).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.281975 |
# | zero_one_loss       | 0.898582 |
# | one_error           | 0        |
# | micro av. jaccard   | 0.480034 |
# | macro av. jaccard   | 0.367593 |
# | micro av. precision | 0.604559 |
# | macro av. precision | 0.492022 |
# | micro av. recall    | 0.699749 |
# | macro av. recall    | 0.545898 |
# | micro av. f1        | 0.64868  |
# | macro av. f1        | 0.496925 |
# | micro av. pr.       | 0.650103 |
# | macro av. pr.       | 0.524623 |
# | micro av. auc       | 0.774516 |
# | macro av. auc       | 0.653638 |
# | coverage error      | 3.94984  |
# | ranking loss        | 0.198219 |
#
# label index list [0, 7, 10, 13]
# Task: 1, s index: 7, e index: 10
# The test shape is (917, 14).
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | hamming loss        | 0.281975 | 0.653217 |
# | zero_one_loss       | 0.898582 | 0.950927 |
# | one_error           | 0        | 0.189749 |
# | micro av. jaccard   | 0.480034 | 0.133976 |
# | macro av. jaccard   | 0.367593 | 0.108192 |
# | micro av. precision | 0.604559 | 0.139628 |
# | macro av. precision | 0.492022 | 0.113372 |
# | micro av. recall    | 0.699749 | 0.767956 |
# | macro av. recall    | 0.545898 | 0.692308 |
# | micro av. f1        | 0.64868  | 0.236294 |
# | macro av. f1        | 0.496925 | 0.187233 |
# | micro av. pr.       | 0.650103 | 0.149492 |
# | macro av. pr.       | 0.524623 | 0.133548 |
# | micro av. auc       | 0.774516 | 0.543094 |
# | macro av. auc       | 0.653638 | 0.483736 |
# | coverage error      | 3.94984  | 0.628135 |
# | ranking loss        | 0.198219 | 0.118321 |
#
# Beginning compression, old model output size = 7
# Inter end shape =  10
# Old model output shape = 10
# Train single mode Epoch: 100%|██████████████████| 15/15 [01:05<00:00,  4.35s/it]
# Old model output shape =  10
# Train single mode Epoch: 100%|██████████████████| 40/40 [03:01<00:00,  4.53s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:21<00:00,  4.23s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | hamming loss        | 0.281975 | 0.653217 |
# | zero_one_loss       | 0.898582 | 0.950927 |
# | one_error           | 0        | 0.189749 |
# | micro av. jaccard   | 0.480034 | 0.133976 |
# | macro av. jaccard   | 0.367593 | 0.108192 |
# | micro av. precision | 0.604559 | 0.139628 |
# | macro av. precision | 0.492022 | 0.113372 |
# | micro av. recall    | 0.699749 | 0.767956 |
# | macro av. recall    | 0.545898 | 0.692308 |
# | micro av. f1        | 0.64868  | 0.236294 |
# | macro av. f1        | 0.496925 | 0.187233 |
# | micro av. pr.       | 0.650103 | 0.149492 |
# | macro av. pr.       | 0.524623 | 0.133548 |
# | micro av. auc       | 0.774516 | 0.543094 |
# | macro av. auc       | 0.653638 | 0.483736 |
# | coverage error      | 3.94984  | 0.628135 |
# | ranking loss        | 0.198219 | 0.118321 |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (917, 13)
# ground truth shape =  (917, 14)
# Evaluation mode is single
# label index list [0, 7, 10, 13]
# Task: 0, s index: 0, e index: 7
# The test shape is (917, 14).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.332918 |
# | zero_one_loss       | 0.91385  |
# | one_error           | 0        |
# | micro av. jaccard   | 0.402238 |
# | macro av. jaccard   | 0.23333  |
# | micro av. precision | 0.54781  |
# | macro av. precision | 0.300048 |
# | micro av. recall    | 0.602178 |
# | macro av. recall    | 0.418677 |
# | micro av. f1        | 0.573708 |
# | macro av. f1        | 0.300811 |
# | micro av. pr.       | 0.58155  |
# | macro av. pr.       | 0.418672 |
# | micro av. auc       | 0.711488 |
# | macro av. auc       | 0.552437 |
# | coverage error      | 4.10905  |
# | ranking loss        | 0.247346 |
#
# label index list [0, 7, 10, 13]
# Task: 1, s index: 7, e index: 10
# The test shape is (917, 14).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |         1 |
# |:--------------------|---------:|----------:|
# | hamming loss        | 0.332918 | 0.361687  |
# | zero_one_loss       | 0.91385  | 0.900763  |
# | one_error           | 0        | 0.0207197 |
# | micro av. jaccard   | 0.402238 | 0.137034  |
# | macro av. jaccard   | 0.23333  | 0.0809903 |
# | micro av. precision | 0.54781  | 0.166491  |
# | macro av. precision | 0.300048 | 0.0907837 |
# | micro av. recall    | 0.602178 | 0.436464  |
# | macro av. recall    | 0.418677 | 0.310262  |
# | micro av. f1        | 0.573708 | 0.241037  |
# | macro av. f1        | 0.300811 | 0.140183  |
# | micro av. pr.       | 0.58155  | 0.165345  |
# | macro av. pr.       | 0.418672 | 0.13348   |
# | micro av. auc       | 0.711488 | 0.57084   |
# | macro av. auc       | 0.552437 | 0.463919  |
# | coverage error      | 4.10905  | 0.603053  |
# | ranking loss        | 0.247346 | 0.115049  |
#
# label index list [0, 7, 10, 13]
# Task: 2, s index: 10, e index: 13
# The test shape is (917, 14).
# |                     |        0 |         1 |          2 |
# |:--------------------|---------:|----------:|-----------:|
# | hamming loss        | 0.332918 | 0.361687  | 0.462014   |
# | zero_one_loss       | 0.91385  | 0.900763  | 0.943293   |
# | one_error           | 0        | 0.0207197 | 0.00981461 |
# | micro av. jaccard   | 0.402238 | 0.137034  | 0.250147   |
# | macro av. jaccard   | 0.23333  | 0.0809903 | 0.172754   |
# | micro av. precision | 0.54781  | 0.166491  | 0.256503   |
# | macro av. precision | 0.300048 | 0.0907837 | 0.177166   |
# | micro av. recall    | 0.602178 | 0.436464  | 0.909871   |
# | macro av. recall    | 0.418677 | 0.310262  | 0.632867   |
# | micro av. f1        | 0.573708 | 0.241037  | 0.400189   |
# | macro av. f1        | 0.300811 | 0.140183  | 0.270446   |
# | micro av. pr.       | 0.58155  | 0.165345  | 0.236835   |
# | macro av. pr.       | 0.418672 | 0.13348   | 0.198481   |
# | micro av. auc       | 0.711488 | 0.57084   | 0.684941   |
# | macro av. auc       | 0.552437 | 0.463919  | 0.553915   |
# | coverage error      | 4.10905  | 0.603053  | 0.785169   |
# | ranking loss        | 0.247346 | 0.115049  | 0.139586   |
#
# Individual Task Results
# |                     |        0 |         1 |          2 |
# |:--------------------|---------:|----------:|-----------:|
# | hamming loss        | 0.332918 | 0.361687  | 0.462014   |
# | zero_one_loss       | 0.91385  | 0.900763  | 0.943293   |
# | one_error           | 0        | 0.0207197 | 0.00981461 |
# | micro av. jaccard   | 0.402238 | 0.137034  | 0.250147   |
# | macro av. jaccard   | 0.23333  | 0.0809903 | 0.172754   |
# | micro av. precision | 0.54781  | 0.166491  | 0.256503   |
# | macro av. precision | 0.300048 | 0.0907837 | 0.177166   |
# | micro av. recall    | 0.602178 | 0.436464  | 0.909871   |
# | macro av. recall    | 0.418677 | 0.310262  | 0.632867   |
# | micro av. f1        | 0.573708 | 0.241037  | 0.400189   |
# | macro av. f1        | 0.300811 | 0.140183  | 0.270446   |
# | micro av. pr.       | 0.58155  | 0.165345  | 0.236835   |
# | macro av. pr.       | 0.418672 | 0.13348   | 0.198481   |
# | micro av. auc       | 0.711488 | 0.57084   | 0.684941   |
# | macro av. auc       | 0.552437 | 0.463919  | 0.553915   |
# | coverage error      | 4.10905  | 0.603053  | 0.785169   |
# | ranking loss        | 0.247346 | 0.115049  | 0.139586   |
#
# ======================== Final Result ========================
# output shape =  (917, 13)
# ground truth shape =  (917, 14)
# Evaluation mode is incremental
# label index list [0, 7, 10, 13]
# Task: 0, s index: 0, e index: 7
# The test shape is (917, 14).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.332918 |
# | zero_one_loss       | 0.91385  |
# | one_error           | 0        |
# | micro av. jaccard   | 0.402238 |
# | macro av. jaccard   | 0.23333  |
# | micro av. precision | 0.54781  |
# | macro av. precision | 0.300048 |
# | micro av. recall    | 0.602178 |
# | macro av. recall    | 0.418677 |
# | micro av. f1        | 0.573708 |
# | macro av. f1        | 0.300811 |
# | micro av. pr.       | 0.58155  |
# | macro av. pr.       | 0.418672 |
# | micro av. auc       | 0.711488 |
# | macro av. auc       | 0.552437 |
# | coverage error      | 4.10905  |
# | ranking loss        | 0.247346 |
#
# label index list [0, 7, 10, 13]
# Task: 1, s index: 0, e index: 10
# The test shape is (917, 14).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | hamming loss        | 0.332918 | 0.341549 |
# | zero_one_loss       | 0.91385  | 0.991276 |
# | one_error           | 0        | 0        |
# | micro av. jaccard   | 0.402238 | 0.337563 |
# | macro av. jaccard   | 0.23333  | 0.187628 |
# | micro av. precision | 0.54781  | 0.446558 |
# | macro av. precision | 0.300048 | 0.237269 |
# | micro av. recall    | 0.602178 | 0.580364 |
# | macro av. recall    | 0.418677 | 0.386152 |
# | micro av. f1        | 0.573708 | 0.504744 |
# | macro av. f1        | 0.300811 | 0.252622 |
# | micro av. pr.       | 0.58155  | 0.498571 |
# | macro av. pr.       | 0.418672 | 0.333114 |
# | micro av. auc       | 0.711488 | 0.681159 |
# | macro av. auc       | 0.552437 | 0.525881 |
# | coverage error      | 4.10905  | 6.03162  |
# | ranking loss        | 0.247346 | 0.281444 |
#
# label index list [0, 7, 10, 13]
# Task: 2, s index: 0, e index: 13
# The test shape is (917, 14).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | hamming loss        | 0.332918 | 0.341549 | 0.369348 |
# | zero_one_loss       | 0.91385  | 0.991276 | 1        |
# | one_error           | 0        | 0        | 0        |
# | micro av. jaccard   | 0.402238 | 0.337563 | 0.314495 |
# | macro av. jaccard   | 0.23333  | 0.187628 | 0.184195 |
# | micro av. precision | 0.54781  | 0.446558 | 0.386455 |
# | macro av. precision | 0.300048 | 0.237269 | 0.223399 |
# | micro av. recall    | 0.602178 | 0.580364 | 0.628109 |
# | macro av. recall    | 0.418677 | 0.386152 | 0.443086 |
# | micro av. f1        | 0.573708 | 0.504744 | 0.478503 |
# | macro av. f1        | 0.300811 | 0.252622 | 0.256735 |
# | micro av. pr.       | 0.58155  | 0.498571 | 0.46366  |
# | macro av. pr.       | 0.418672 | 0.333114 | 0.302045 |
# | micro av. auc       | 0.711488 | 0.681159 | 0.676256 |
# | macro av. auc       | 0.552437 | 0.525881 | 0.532351 |
# | coverage error      | 4.10905  | 6.03162  | 8.43293  |
# | ranking loss        | 0.247346 | 0.281444 | 0.306134 |
#
# Overall Task Results
# |                     |        0 |        1 |        2 |
# |:--------------------|---------:|---------:|---------:|
# | hamming loss        | 0.332918 | 0.341549 | 0.369348 |
# | zero_one_loss       | 0.91385  | 0.991276 | 1        |
# | one_error           | 0        | 0        | 0        |
# | micro av. jaccard   | 0.402238 | 0.337563 | 0.314495 |
# | macro av. jaccard   | 0.23333  | 0.187628 | 0.184195 |
# | micro av. precision | 0.54781  | 0.446558 | 0.386455 |
# | macro av. precision | 0.300048 | 0.237269 | 0.223399 |
# | micro av. recall    | 0.602178 | 0.580364 | 0.628109 |
# | macro av. recall    | 0.418677 | 0.386152 | 0.443086 |
# | micro av. f1        | 0.573708 | 0.504744 | 0.478503 |
# | macro av. f1        | 0.300811 | 0.252622 | 0.256735 |
# | micro av. pr.       | 0.58155  | 0.498571 | 0.46366  |
# | macro av. pr.       | 0.418672 | 0.333114 | 0.302045 |
# | micro av. auc       | 0.711488 | 0.681159 | 0.676256 |
# | macro av. auc       | 0.552437 | 0.525881 | 0.532351 |
# | coverage error      | 4.10905  | 6.03162  | 8.43293  |
# | ranking loss        | 0.247346 | 0.281444 | 0.306134 |
# 919.3961794376373 s.
