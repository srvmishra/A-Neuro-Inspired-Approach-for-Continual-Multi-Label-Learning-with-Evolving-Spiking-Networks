# %% [markdown]
# ## Yeast

# %%
# !python3 main.py --name yeast --shuffle 1 --seed 0 --device 3
# Out:
# data_name: yeast.
# seed: 0.
# shuffle: True.
# upper_bound: False.
# embed_dim: 20.
# task_num: 6.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 20.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 20.
# sti_epoch: 15.
# ste_epoch: 20.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (1500, 117) (917, 117)
# torch.Size([917, 14])
# 0.3037077426390403
# task: 0, #samples: 250, #negative samples: 140, #positive samples: 3
# task: 1, #samples: 250, #negative samples: 211, #positive samples: 0
# task: 2, #samples: 250, #negative samples: 169, #positive samples: 1
# task: 3, #samples: 250, #negative samples: 68, #positive samples: 180
# task: 4, #samples: 250, #negative samples: 111, #positive samples: 5
# task: 5, #samples: 250, #negative samples: 92, #positive samples: 10
# ======================== Task 0 ========================
# ...

# %% [markdown]
# ## Enron

# %%
# !python3 main.py --name enron --shuffle 1 --seed 0 --device 3
# Out:
# data_name: enron.
# seed: 0.
# shuffle: True.
# upper_bound: False.
# embed_dim: 20.
# task_num: 10.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 20.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 20.
# sti_epoch: 15.
# ste_epoch: 20.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (1123, 1054) (579, 1054)
# torch.Size([579, 53])
# 0.06344706227392707
# task: 0, #samples: 112, #negative samples: 60, #positive samples: 0
# task: 1, #samples: 112, #negative samples: 61, #positive samples: 0
# task: 2, #samples: 112, #negative samples: 37, #positive samples: 0
# task: 3, #samples: 112, #negative samples: 93, #positive samples: 0
# task: 4, #samples: 112, #negative samples: 94, #positive samples: 0
# task: 5, #samples: 112, #negative samples: 105, #positive samples: 0
# task: 6, #samples: 112, #negative samples: 101, #positive samples: 0
# ...

# %% [markdown]
# ## Mediamill 20 tasks

# %%
# !python3 main.py --name mediamill_20 --shuffle 1 --seed 0 --device 3
# Out:
# data_name: mediamill_20.
# seed: 0.
# shuffle: True.
# upper_bound: False.
# embed_dim: 20.
# task_num: 20.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 20.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 20.
# sti_epoch: 15.
# ste_epoch: 20.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (30993, 221) (12914, 221)
# torch.Size([12914, 101])
# 0.043625231347666285
# task: 0, #samples: 1549, #negative samples: 1248, #positive samples: 0
# task: 1, #samples: 1549, #negative samples: 1441, #positive samples: 0
# task: 2, #samples: 1549, #negative samples: 849, #positive samples: 0
# task: 3, #samples: 1549, #negative samples: 1162, #positive samples: 0
# task: 4, #samples: 1549, #negative samples: 1491, #positive samples: 0
# task: 5, #samples: 1549, #negative samples: 1406, #positive samples: 0
# task: 6, #samples: 1549, #negative samples: 1512, #positive samples: 0
# ...

# %% [markdown]
# ## Mediamill 50 tasks

# %%
# !python3 main.py --name mediamill_50 --shuffle 1 --seed 0 --device 3
# Out:
# data_name: mediamill_50.
# seed: 0.
# shuffle: True.
# upper_bound: False.
# embed_dim: 20.
# task_num: 50.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 20.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 20.
# sti_epoch: 15.
# ste_epoch: 20.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (30993, 221) (12914, 221)
# torch.Size([12914, 101])
# 0.043625231347666285
# task: 0, #samples: 619, #negative samples: 619, #positive samples: 0
# task: 1, #samples: 619, #negative samples: 614, #positive samples: 0
# task: 2, #samples: 619, #negative samples: 497, #positive samples: 0
# task: 3, #samples: 619, #negative samples: 599, #positive samples: 0
# task: 4, #samples: 619, #negative samples: 597, #positive samples: 0
# task: 5, #samples: 619, #negative samples: 369, #positive samples: 7
# task: 6, #samples: 619, #negative samples: 549, #positive samples: 0
# ...

# %% [markdown]
# ## Delicious 20 tasks

# %%
# !python3 main.py --name delicious_20 --shuffle 1 --seed 0 --device 3

# %% [markdown]
# ## Delicious 50 tasks

# %%
# !python3 main.py --name delicious_50 --shuffle 1 --seed 0 --device 3
