# %%
# !python3 main.py --name yeast_big --shuffle 1 --seed 5 --device 2
# Out:
# data_name: yeast.
# seed: 5.
# shuffle: True.
# upper_bound: False.
# embed_dim: 20.
# task_num: 6.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (1500, 117) (917, 117)
# torch.Size([917, 14])
# 0.3037077426390403
# task: 0, #samples: 250, #negative samples: 156, #positive samples: 6
# task: 1, #samples: 250, #negative samples: 62, #positive samples: 27
# task: 2, #samples: 250, #negative samples: 54, #positive samples: 50
# task: 3, #samples: 250, #negative samples: 110, #positive samples: 16
# task: 4, #samples: 250, #negative samples: 194, #positive samples: 2
# task: 5, #samples: 250, #negative samples: 95, #positive samples: 0
# ======================== Task 0 ========================
# ...

# %%
# !python3 main.py --name foodtruck_big --shuffle 1 --seed 5 --device 2
# Out:
# data_name: foodtruck.
# seed: 5.
# shuffle: True.
# upper_bound: False.
# embed_dim: 20.
# task_num: 6.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (250, 33) (250, 33)
# torch.Size([250, 12])
# 0.188
# task: 0, #samples: 40, #negative samples: 24, #positive samples: 3
# task: 1, #samples: 40, #negative samples: 32, #positive samples: 0
# task: 2, #samples: 40, #negative samples: 23, #positive samples: 2
# task: 3, #samples: 40, #negative samples: 18, #positive samples: 2
# task: 4, #samples: 40, #negative samples: 36, #positive samples: 0
# task: 5, #samples: 50, #negative samples: 41, #positive samples: 2
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [00:43<00:00,  1.10s/it]
# ...

# %%
# !python3 main.py --name birds --shuffle 1 --seed 5 --device 2
# Out:
# data_name: birds.
# seed: 5.
# shuffle: True.
# upper_bound: False.
# embed_dim: 20.
# task_num: 6.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (322, 279) (323, 279)
# torch.Size([323, 19])
# 0.05100211829884308
# task: 0, #samples: 54, #negative samples: 52, #positive samples: 0
# task: 1, #samples: 54, #negative samples: 47, #positive samples: 0
# task: 2, #samples: 54, #negative samples: 46, #positive samples: 0
# task: 3, #samples: 54, #negative samples: 47, #positive samples: 0
# task: 4, #samples: 54, #negative samples: 40, #positive samples: 0
# task: 5, #samples: 52, #negative samples: 43, #positive samples: 0
# ======================== Task 0 ========================
# ...

# %%
# !python3 main.py --name human --shuffle 1 --seed 2 --device 2
# Out:
# data_name: human.
# seed: 2.
# shuffle: True.
# upper_bound: False.
# embed_dim: 20.
# task_num: 5.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 20.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 20.
# sti_epoch: 15.
# ste_epoch: 20.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (1862, 451) (1244, 451)
# torch.Size([1244, 11])
# 0.1050862320958784
# task: 0, #samples: 310, #negative samples: 192, #positive samples: 1
# task: 1, #samples: 310, #negative samples: 289, #positive samples: 0
# task: 2, #samples: 310, #negative samples: 266, #positive samples: 1
# task: 3, #samples: 310, #negative samples: 220, #positive samples: 2
# task: 4, #samples: 622, #negative samples: 417, #positive samples: 0
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 20/20 [00:26<00:00,  1.34s/it]
# The task 0 result is following:
# ...

# %%
# !python3 main.py --name eukaryote --shuffle 1 --seed 2 --device 2
# Out:
# data_name: eukaryote.
# seed: 2.
# shuffle: True.
# upper_bound: False.
# embed_dim: 20.
# task_num: 10.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (4658, 459) (3108, 459)
# torch.Size([3108, 19])
# 0.060014902120165275
# task: 0, #samples: 435, #negative samples: 417, #positive samples: 0
# task: 1, #samples: 530, #negative samples: 525, #positive samples: 0
# task: 2, #samples: 438, #negative samples: 408, #positive samples: 0
# task: 3, #samples: 465, #negative samples: 420, #positive samples: 0
# task: 4, #samples: 465, #negative samples: 296, #positive samples: 0
# task: 5, #samples: 465, #negative samples: 454, #positive samples: 0
# task: 6, #samples: 465, #negative samples: 459, #positive samples: 0
# ...
