# %% [markdown]
# ## Yeast

# %%
# !python3 main.py --name yeast --shuffle 1 --seed 0 --device 1
# Out:
# upper_bound: False.
# data_name: yeast.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (1500, 117) (917, 117)
# torch.Size([917, 14])
# 0.3037077426390403
# task: 0, #samples: 500, #negative samples: 24, #positive samples: 0
# task: 1, #samples: 500, #negative samples: 210, #positive samples: 2
# task: 2, #samples: 500, #negative samples: 252, #positive samples: 0
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:07<00:00,  1.69s/it]
# The task 0 result is following:
# output shape =  (917, 10)
# ground truth shape =  (917, 14)
# Evaluation mode is single
# label index list [0, 7, 10, 13]
# Task: 0, s index: 0, e index: 7
# ...

# %% [markdown]
# ## Emotions

# %%
# !python3 main.py --name emotions --shuffle 1 --seed 0 --device 1
# Out:
# upper_bound: False.
# data_name: emotions.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (391, 78) (202, 78)
# torch.Size([202, 6])
# 0.3292079207920792
# task: 0, #samples: 130, #negative samples: 60, #positive samples: 2
# task: 1, #samples: 130, #negative samples: 52, #positive samples: 21
# task: 2, #samples: 131, #negative samples: 62, #positive samples: 1
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [00:50<00:00,  1.26s/it]
# The task 0 result is following:
# output shape =  (202, 4)
# ground truth shape =  (202, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (202, 6).
# ...

# %% [markdown]
# ## Scene

# %%
# !python3 main.py --name scene --shuffle 1 --seed 0 --device 1
# Out:
# upper_bound: False.
# data_name: scene.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (1211, 300) (1196, 300)
# torch.Size([1196, 6])
# 0.1810200668896321
# task: 0, #samples: 405, #negative samples: 259, #positive samples: 1
# task: 1, #samples: 403, #negative samples: 282, #positive samples: 0
# task: 2, #samples: 403, #negative samples: 252, #positive samples: 9
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [00:53<00:00,  1.35s/it]
# The task 0 result is following:
# output shape =  (1196, 4)
# ground truth shape =  (1196, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# ...

# %% [markdown]
# ## GNegative

# %%
# !python3 main.py --name gnegative --shuffle 1 --seed 0 --device 1
# Out:
# upper_bound: False.
# data_name: gnegative.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (836, 448) (556, 448)
# torch.Size([556, 8])
# 0.13196942446043167
# task: 0, #samples: 278, #negative samples: 147, #positive samples: 0
# task: 1, #samples: 280, #negative samples: 256, #positive samples: 0
# task: 2, #samples: 278, #negative samples: 134, #positive samples: 0
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [00:51<00:00,  1.28s/it]
# The task 0 result is following:
# output shape =  (556, 5)
# ground truth shape =  (556, 8)
# Evaluation mode is single
# label index list [0, 3, 5, 8]
# Task: 0, s index: 0, e index: 3
# ...

# %% [markdown]
# ## Plants

# %%
# !python3 main.py --name plant --shuffle 1 --seed 0 --device 1
# Out:
# upper_bound: False.
# data_name: plant.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (588, 452) (390, 452)
# torch.Size([390, 12])
# 0.08803418803418804
# task: 0, #samples: 196, #negative samples: 151, #positive samples: 0
# task: 1, #samples: 196, #negative samples: 97, #positive samples: 0
# task: 2, #samples: 196, #negative samples: 132, #positive samples: 0
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [00:54<00:00,  1.36s/it]
# The task 0 result is following:
# output shape =  (390, 8)
# ground truth shape =  (390, 12)
# Evaluation mode is single
# label index list [0, 4, 8, 12]
# Task: 0, s index: 0, e index: 4
# ...

# %% [markdown]
# ## Human

# %%
# !python3 main.py --name human --shuffle 1 --seed 0 --device 1
# Out:
# upper_bound: False.
# data_name: human.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (1862, 454) (1244, 454)
# torch.Size([1244, 14])
# 0.0841180523656408
# task: 0, #samples: 621, #negative samples: 320, #positive samples: 0
# task: 1, #samples: 621, #negative samples: 540, #positive samples: 0
# task: 2, #samples: 620, #negative samples: 309, #positive samples: 0
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [00:53<00:00,  1.35s/it]
# The task 0 result is following:
# output shape =  (1244, 10)
# ground truth shape =  (1244, 14)
# Evaluation mode is single
# label index list [0, 4, 10, 14]
# Task: 0, s index: 0, e index: 4
# ...

# %% [markdown]
# ## Virus

# %%
# !python3 main.py --name virus --shuffle 1 --seed 0 --device 1
# Out:
# upper_bound: False.
# data_name: virus.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (124, 446) (83, 446)
# torch.Size([83, 6])
# 0.19879518072289157
# task: 0, #samples: 41, #negative samples: 24, #positive samples: 0
# task: 1, #samples: 41, #negative samples: 37, #positive samples: 1
# task: 2, #samples: 42, #negative samples: 19, #positive samples: 0
# ======================== Task 0 ========================
# Train single mode Epoch:  60%|██████████▊       | 24/40 [00:34<00:21,  1.35s/it]
