# %%
# !python3 main.py --name scene --shuffle 1 --seed 2 --device 3
# Out:
# data_name: scene.
# seed: 2.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (1211, 300) (1196, 300)
# torch.Size([1196, 6])
# 0.1810200668896321
# task: 0, #samples: 405, #negative samples: 245, #positive samples: 9
# task: 1, #samples: 403, #negative samples: 285, #positive samples: 1
# task: 2, #samples: 403, #negative samples: 273, #positive samples: 0
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:39<00:00,  2.48s/it]
# The task 0 result is following:
# output shape =  (1196, 4)
# ground truth shape =  (1196, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (1196, 6).
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.195652  |
# | zero_one_loss       | 0.353679  |
# | one_error           | 0.0376254 |
# | micro av. jaccard   | 0.35      |
# | macro av. jaccard   | 0.35302   |
# | micro av. precision | 0.488372  |
# | macro av. precision | 0.609999  |
# | micro av. recall    | 0.552632  |
# | macro av. recall    | 0.535391  |
# | micro av. f1        | 0.518519  |
# | macro av. f1        | 0.521777  |
# | micro av. pr.       | 0.461998  |
# | macro av. pr.       | 0.570045  |
# | micro av. auc       | 0.82869   |
# | macro av. auc       | 0.841086  |
# | coverage error      | 0.445652  |
# | ranking loss        | 0.0643813 |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:19<00:00,  4.00s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.195652  |
# | zero_one_loss       | 0.353679  |
# | one_error           | 0.0376254 |
# | micro av. jaccard   | 0.35      |
# | macro av. jaccard   | 0.35302   |
# | micro av. precision | 0.488372  |
# | macro av. precision | 0.609999  |
# | micro av. recall    | 0.552632  |
# | macro av. recall    | 0.535391  |
# | micro av. f1        | 0.518519  |
# | macro av. f1        | 0.521777  |
# | micro av. pr.       | 0.461998  |
# | macro av. pr.       | 0.570045  |
# | micro av. auc       | 0.82869   |
# | macro av. auc       | 0.841086  |
# | coverage error      | 0.445652  |
# | ranking loss        | 0.0643813 |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (1196, 4)
# ground truth shape =  (1196, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (1196, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.186455  |
# | zero_one_loss       | 0.35786   |
# | one_error           | 0.0150502 |
# | micro av. jaccard   | 0.0387931 |
# | macro av. jaccard   | 0.0340909 |
# | micro av. precision | 0.692308  |
# | macro av. precision | 0.346154  |
# | micro av. recall    | 0.0394737 |
# | macro av. recall    | 0.0351562 |
# | micro av. f1        | 0.0746888 |
# | macro av. f1        | 0.0638298 |
# | micro av. pr.       | 0.521353  |
# | macro av. pr.       | 0.539356  |
# | micro av. auc       | 0.831562  |
# | macro av. auc       | 0.838112  |
# | coverage error      | 0.448997  |
# | ranking loss        | 0.0677258 |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 2, e index: 4
# The test shape is (1196, 6).
# |                     |         0 |         1 |
# |:--------------------|----------:|----------:|
# | hamming loss        | 0.186455  | 0.521739  |
# | zero_one_loss       | 0.35786   | 0.772575  |
# | one_error           | 0.0150502 | 0.270903  |
# | micro av. jaccard   | 0.0387931 | 0.207116  |
# | macro av. jaccard   | 0.0340909 | 0.204802  |
# | micro av. precision | 0.692308  | 0.22283   |
# | macro av. precision | 0.346154  | 0.220979  |
# | micro av. recall    | 0.0394737 | 0.745995  |
# | macro av. recall    | 0.0351562 | 0.765042  |
# | micro av. f1        | 0.0746888 | 0.343158  |
# | macro av. f1        | 0.0638298 | 0.339156  |
# | micro av. pr.       | 0.521353  | 0.324562  |
# | macro av. pr.       | 0.539356  | 0.342379  |
# | micro av. auc       | 0.831562  | 0.680448  |
# | macro av. auc       | 0.838112  | 0.704277  |
# | coverage error      | 0.448997  | 0.45903   |
# | ranking loss        | 0.0677258 | 0.0936455 |
#
# Beginning compression, old model output size = 2
# Inter end shape =  4
# Old model output shape = 4
# Train single mode Epoch: 100%|██████████████████| 15/15 [00:58<00:00,  3.87s/it]
# Old model output shape =  4
# Train single mode Epoch: 100%|██████████████████| 40/40 [02:37<00:00,  3.95s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:18<00:00,  3.78s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |         0 |         1 |
# |:--------------------|----------:|----------:|
# | hamming loss        | 0.186455  | 0.521739  |
# | zero_one_loss       | 0.35786   | 0.772575  |
# | one_error           | 0.0150502 | 0.270903  |
# | micro av. jaccard   | 0.0387931 | 0.207116  |
# | macro av. jaccard   | 0.0340909 | 0.204802  |
# | micro av. precision | 0.692308  | 0.22283   |
# | macro av. precision | 0.346154  | 0.220979  |
# | micro av. recall    | 0.0394737 | 0.745995  |
# | macro av. recall    | 0.0351562 | 0.765042  |
# | micro av. f1        | 0.0746888 | 0.343158  |
# | macro av. f1        | 0.0638298 | 0.339156  |
# | micro av. pr.       | 0.521353  | 0.324562  |
# | macro av. pr.       | 0.539356  | 0.342379  |
# | micro av. auc       | 0.831562  | 0.680448  |
# | macro av. auc       | 0.838112  | 0.704277  |
# | coverage error      | 0.448997  | 0.45903   |
# | ranking loss        | 0.0677258 | 0.0936455 |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (1196, 6)
# ground truth shape =  (1196, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (1196, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.476589 |
# | zero_one_loss       | 0.800167 |
# | one_error           | 0.15301  |
# | micro av. jaccard   | 0.183381 |
# | macro av. jaccard   | 0.107023 |
# | micro av. precision | 0.214047 |
# | macro av. precision | 0.107023 |
# | micro av. recall    | 0.561404 |
# | macro av. recall    | 0.5      |
# | micro av. f1        | 0.309927 |
# | macro av. f1        | 0.176309 |
# | micro av. pr.       | 0.174132 |
# | macro av. pr.       | 0.153569 |
# | micro av. auc       | 0.460454 |
# | macro av. auc       | 0.35029  |
# | coverage error      | 0.534281 |
# | ranking loss        | 0.15301  |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 2, e index: 4
# The test shape is (1196, 6).
# |                     |        0 |         1 |
# |:--------------------|---------:|----------:|
# | hamming loss        | 0.476589 | 0.336538  |
# | zero_one_loss       | 0.800167 | 0.572742  |
# | one_error           | 0.15301  | 0.100334  |
# | micro av. jaccard   | 0.183381 | 0.0789474 |
# | macro av. jaccard   | 0.107023 | 0.0831956 |
# | micro av. precision | 0.214047 | 0.136364  |
# | macro av. precision | 0.107023 | 0.158942  |
# | micro av. recall    | 0.561404 | 0.157895  |
# | macro av. recall    | 0.5      | 0.157669  |
# | micro av. f1        | 0.309927 | 0.146341  |
# | macro av. f1        | 0.176309 | 0.153247  |
# | micro av. pr.       | 0.174132 | 0.146121  |
# | macro av. pr.       | 0.153569 | 0.161007  |
# | micro av. auc       | 0.460454 | 0.390932  |
# | macro av. auc       | 0.35029  | 0.410205  |
# | coverage error      | 0.534281 | 0.601171  |
# | ranking loss        | 0.15301  | 0.235786  |
#
# label index list [0, 2, 4, 6]
# Task: 2, s index: 4, e index: 6
# The test shape is (1196, 6).
# |                     |        0 |         1 |         2 |
# |:--------------------|---------:|----------:|----------:|
# | hamming loss        | 0.476589 | 0.336538  | 0.504181  |
# | zero_one_loss       | 0.800167 | 0.572742  | 0.833612  |
# | one_error           | 0.15301  | 0.100334  | 0.174749  |
# | micro av. jaccard   | 0.183381 | 0.0789474 | 0.141026  |
# | macro av. jaccard   | 0.107023 | 0.0831956 | 0.0882497 |
# | micro av. precision | 0.214047 | 0.136364  | 0.165552  |
# | macro av. precision | 0.107023 | 0.158942  | 0.114568  |
# | micro av. recall    | 0.561404 | 0.157895  | 0.487685  |
# | macro av. recall    | 0.5      | 0.157669  | 0.497293  |
# | micro av. f1        | 0.309927 | 0.146341  | 0.247191  |
# | macro av. f1        | 0.176309 | 0.153247  | 0.152239  |
# | micro av. pr.       | 0.174132 | 0.146121  | 0.37618   |
# | macro av. pr.       | 0.153569 | 0.161007  | 0.397847  |
# | micro av. auc       | 0.460454 | 0.390932  | 0.605072  |
# | macro av. auc       | 0.35029  | 0.410205  | 0.726618  |
# | coverage error      | 0.534281 | 0.601171  | 0.515886  |
# | ranking loss        | 0.15301  | 0.235786  | 0.176421  |
#
# Individual Task Results
# |                     |        0 |         1 |         2 |
# |:--------------------|---------:|----------:|----------:|
# | hamming loss        | 0.476589 | 0.336538  | 0.504181  |
# | zero_one_loss       | 0.800167 | 0.572742  | 0.833612  |
# | one_error           | 0.15301  | 0.100334  | 0.174749  |
# | micro av. jaccard   | 0.183381 | 0.0789474 | 0.141026  |
# | macro av. jaccard   | 0.107023 | 0.0831956 | 0.0882497 |
# | micro av. precision | 0.214047 | 0.136364  | 0.165552  |
# | macro av. precision | 0.107023 | 0.158942  | 0.114568  |
# | micro av. recall    | 0.561404 | 0.157895  | 0.487685  |
# | macro av. recall    | 0.5      | 0.157669  | 0.497293  |
# | micro av. f1        | 0.309927 | 0.146341  | 0.247191  |
# | macro av. f1        | 0.176309 | 0.153247  | 0.152239  |
# | micro av. pr.       | 0.174132 | 0.146121  | 0.37618   |
# | macro av. pr.       | 0.153569 | 0.161007  | 0.397847  |
# | micro av. auc       | 0.460454 | 0.390932  | 0.605072  |
# | macro av. auc       | 0.35029  | 0.410205  | 0.726618  |
# | coverage error      | 0.534281 | 0.601171  | 0.515886  |
# | ranking loss        | 0.15301  | 0.235786  | 0.176421  |
#
# ======================== Final Result ========================
# output shape =  (1196, 6)
# ground truth shape =  (1196, 6)
# Evaluation mode is incremental
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (1196, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.476589 |
# | zero_one_loss       | 0.800167 |
# | one_error           | 0.15301  |
# | micro av. jaccard   | 0.183381 |
# | macro av. jaccard   | 0.107023 |
# | micro av. precision | 0.214047 |
# | macro av. precision | 0.107023 |
# | micro av. recall    | 0.561404 |
# | macro av. recall    | 0.5      |
# | micro av. f1        | 0.309927 |
# | macro av. f1        | 0.176309 |
# | micro av. pr.       | 0.174132 |
# | macro av. pr.       | 0.153569 |
# | micro av. auc       | 0.460454 |
# | macro av. auc       | 0.35029  |
# | coverage error      | 0.534281 |
# | ranking loss        | 0.15301  |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 0, e index: 4
# The test shape is (1196, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |         1 |
# |:--------------------|---------:|----------:|
# | hamming loss        | 0.476589 | 0.406564  |
# | zero_one_loss       | 0.800167 | 0.867893  |
# | one_error           | 0.15301  | 0         |
# | micro av. jaccard   | 0.183381 | 0.143172  |
# | macro av. jaccard   | 0.107023 | 0.0951095 |
# | micro av. precision | 0.214047 | 0.190952  |
# | macro av. precision | 0.107023 | 0.132983  |
# | micro av. recall    | 0.561404 | 0.363942  |
# | macro av. recall    | 0.5      | 0.328834  |
# | micro av. f1        | 0.309927 | 0.250482  |
# | macro av. f1        | 0.176309 | 0.164778  |
# | micro av. pr.       | 0.174132 | 0.169034  |
# | macro av. pr.       | 0.153569 | 0.157288  |
# | micro av. auc       | 0.460454 | 0.459911  |
# | macro av. auc       | 0.35029  | 0.380247  |
# | coverage error      | 0.534281 | 1.77676   |
# | ranking loss        | 0.15301  | 0.34058   |
#
# label index list [0, 2, 4, 6]
# Task: 2, s index: 0, e index: 6
# The test shape is (1196, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |         1 |         2 |
# |:--------------------|---------:|----------:|----------:|
# | hamming loss        | 0.476589 | 0.406564  | 0.439103  |
# | zero_one_loss       | 0.800167 | 0.867893  | 0.999164  |
# | one_error           | 0.15301  | 0         | 0         |
# | micro av. jaccard   | 0.183381 | 0.143172  | 0.142352  |
# | macro av. jaccard   | 0.107023 | 0.0951095 | 0.0928229 |
# | micro av. precision | 0.214047 | 0.190952  | 0.180469  |
# | macro av. precision | 0.107023 | 0.132983  | 0.126844  |
# | micro av. recall    | 0.561404 | 0.363942  | 0.402617  |
# | macro av. recall    | 0.5      | 0.328834  | 0.384987  |
# | micro av. f1        | 0.309927 | 0.250482  | 0.249226  |
# | macro av. f1        | 0.176309 | 0.164778  | 0.160598  |
# | micro av. pr.       | 0.174132 | 0.169034  | 0.20368   |
# | macro av. pr.       | 0.153569 | 0.157288  | 0.237474  |
# | micro av. auc       | 0.460454 | 0.459911  | 0.485032  |
# | macro av. auc       | 0.35029  | 0.380247  | 0.495704  |
# | coverage error      | 0.534281 | 1.77676   | 3.67224   |
# | ranking loss        | 0.15301  | 0.34058   | 0.517559  |
#
# Overall Task Results
# |                     |        0 |         1 |         2 |
# |:--------------------|---------:|----------:|----------:|
# | hamming loss        | 0.476589 | 0.406564  | 0.439103  |
# | zero_one_loss       | 0.800167 | 0.867893  | 0.999164  |
# | one_error           | 0.15301  | 0         | 0         |
# | micro av. jaccard   | 0.183381 | 0.143172  | 0.142352  |
# | macro av. jaccard   | 0.107023 | 0.0951095 | 0.0928229 |
# | micro av. precision | 0.214047 | 0.190952  | 0.180469  |
# | macro av. precision | 0.107023 | 0.132983  | 0.126844  |
# | micro av. recall    | 0.561404 | 0.363942  | 0.402617  |
# | macro av. recall    | 0.5      | 0.328834  | 0.384987  |
# | micro av. f1        | 0.309927 | 0.250482  | 0.249226  |
# | macro av. f1        | 0.176309 | 0.164778  | 0.160598  |
# | micro av. pr.       | 0.174132 | 0.169034  | 0.20368   |
# | macro av. pr.       | 0.153569 | 0.157288  | 0.237474  |
# | micro av. auc       | 0.460454 | 0.459911  | 0.485032  |
# | macro av. auc       | 0.35029  | 0.380247  | 0.495704  |
# | coverage error      | 0.534281 | 1.77676   | 3.67224   |
# | ranking loss        | 0.15301  | 0.34058   | 0.517559  |
# 863.5564458370209 s.

# %%
# !python3 main.py --name scene --shuffle 1 --seed 63 --device 3
# Out:
# data_name: scene.
# seed: 63.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (1211, 300) (1196, 300)
# torch.Size([1196, 6])
# 0.1810200668896321
# task: 0, #samples: 405, #negative samples: 232, #positive samples: 10
# task: 1, #samples: 403, #negative samples: 269, #positive samples: 2
# task: 2, #samples: 403, #negative samples: 256, #positive samples: 0
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:32<00:00,  2.32s/it]
# The task 0 result is following:
# output shape =  (1196, 4)
# ground truth shape =  (1196, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (1196, 6).
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.183528  |
# | zero_one_loss       | 0.321906  |
# | one_error           | 0.0451505 |
# | micro av. jaccard   | 0.406757  |
# | macro av. jaccard   | 0.420235  |
# | micro av. precision | 0.51453   |
# | macro av. precision | 0.542073  |
# | micro av. recall    | 0.660088  |
# | macro av. recall    | 0.658984  |
# | micro av. f1        | 0.57829   |
# | macro av. f1        | 0.589856  |
# | micro av. pr.       | 0.562633  |
# | macro av. pr.       | 0.588757  |
# | micro av. auc       | 0.852939  |
# | macro av. auc       | 0.848917  |
# | coverage error      | 0.441472  |
# | ranking loss        | 0.0602007 |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:16<00:00,  3.34s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.183528  |
# | zero_one_loss       | 0.321906  |
# | one_error           | 0.0451505 |
# | micro av. jaccard   | 0.406757  |
# | macro av. jaccard   | 0.420235  |
# | micro av. precision | 0.51453   |
# | macro av. precision | 0.542073  |
# | micro av. recall    | 0.660088  |
# | macro av. recall    | 0.658984  |
# | micro av. f1        | 0.57829   |
# | macro av. f1        | 0.589856  |
# | micro av. pr.       | 0.562633  |
# | macro av. pr.       | 0.588757  |
# | micro av. auc       | 0.852939  |
# | macro av. auc       | 0.848917  |
# | coverage error      | 0.441472  |
# | ranking loss        | 0.0602007 |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (1196, 4)
# ground truth shape =  (1196, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (1196, 6).
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.155936  |
# | zero_one_loss       | 0.293478  |
# | one_error           | 0.0183946 |
# | micro av. jaccard   | 0.23251   |
# | macro av. jaccard   | 0.24773   |
# | micro av. precision | 0.79021   |
# | macro av. precision | 0.758437  |
# | micro av. recall    | 0.247807  |
# | macro av. recall    | 0.268828  |
# | micro av. f1        | 0.377295  |
# | macro av. f1        | 0.372261  |
# | micro av. pr.       | 0.601142  |
# | macro av. pr.       | 0.60242   |
# | micro av. auc       | 0.849166  |
# | macro av. auc       | 0.848928  |
# | coverage error      | 0.447324  |
# | ranking loss        | 0.0660535 |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 2, e index: 4
# The test shape is (1196, 6).
# |                     |         0 |         1 |
# |:--------------------|----------:|----------:|
# | hamming loss        | 0.155936  | 0.529264  |
# | zero_one_loss       | 0.293478  | 0.843645  |
# | one_error           | 0.0183946 | 0.214883  |
# | micro av. jaccard   | 0.23251   | 0.14053   |
# | macro av. jaccard   | 0.24773   | 0.0986997 |
# | micro av. precision | 0.79021   | 0.166533  |
# | macro av. precision | 0.758437  | 0.119469  |
# | micro av. recall    | 0.247807  | 0.473684  |
# | macro av. recall    | 0.268828  | 0.514768  |
# | micro av. f1        | 0.377295  | 0.246429  |
# | macro av. f1        | 0.372261  | 0.170376  |
# | micro av. pr.       | 0.601142  | 0.286458  |
# | macro av. pr.       | 0.60242   | 0.297786  |
# | micro av. auc       | 0.849166  | 0.559429  |
# | macro av. auc       | 0.848928  | 0.679105  |
# | coverage error      | 0.447324  | 0.545151  |
# | ranking loss        | 0.0660535 | 0.179766  |
#
# Beginning compression, old model output size = 2
# Inter end shape =  4
# Old model output shape = 4
# Train single mode Epoch: 100%|██████████████████| 15/15 [00:51<00:00,  3.41s/it]
# Old model output shape =  4
# Train single mode Epoch: 100%|██████████████████| 40/40 [02:16<00:00,  3.42s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:16<00:00,  3.40s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |         0 |         1 |
# |:--------------------|----------:|----------:|
# | hamming loss        | 0.155936  | 0.529264  |
# | zero_one_loss       | 0.293478  | 0.843645  |
# | one_error           | 0.0183946 | 0.214883  |
# | micro av. jaccard   | 0.23251   | 0.14053   |
# | macro av. jaccard   | 0.24773   | 0.0986997 |
# | micro av. precision | 0.79021   | 0.166533  |
# | macro av. precision | 0.758437  | 0.119469  |
# | micro av. recall    | 0.247807  | 0.473684  |
# | macro av. recall    | 0.268828  | 0.514768  |
# | micro av. f1        | 0.377295  | 0.246429  |
# | macro av. f1        | 0.372261  | 0.170376  |
# | micro av. pr.       | 0.601142  | 0.286458  |
# | macro av. pr.       | 0.60242   | 0.297786  |
# | micro av. auc       | 0.849166  | 0.559429  |
# | macro av. auc       | 0.848928  | 0.679105  |
# | coverage error      | 0.447324  | 0.545151  |
# | ranking loss        | 0.0660535 | 0.179766  |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (1196, 6)
# ground truth shape =  (1196, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (1196, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.523411 |
# | zero_one_loss       | 0.84699  |
# | one_error           | 0.199833 |
# | micro av. jaccard   | 0.137741 |
# | macro av. jaccard   | 0.083612 |
# | micro av. precision | 0.167224 |
# | macro av. precision | 0.083612 |
# | micro av. recall    | 0.438596 |
# | macro av. recall    | 0.5      |
# | micro av. f1        | 0.242131 |
# | macro av. f1        | 0.143266 |
# | micro av. pr.       | 0.175899 |
# | macro av. pr.       | 0.242702 |
# | micro av. auc       | 0.499868 |
# | macro av. auc       | 0.564481 |
# | coverage error      | 0.581104 |
# | ranking loss        | 0.199833 |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 2, e index: 4
# The test shape is (1196, 6).
# |                     |        0 |        1 |
# |:--------------------|---------:|---------:|
# | hamming loss        | 0.523411 | 0.445234 |
# | zero_one_loss       | 0.84699  | 0.76087  |
# | one_error           | 0.199833 | 0.129599 |
# | micro av. jaccard   | 0.137741 | 0.183908 |
# | macro av. jaccard   | 0.083612 | 0.133581 |
# | micro av. precision | 0.167224 | 0.216606 |
# | macro av. precision | 0.083612 | 0.208821 |
# | micro av. recall    | 0.438596 | 0.549199 |
# | macro av. recall    | 0.5      | 0.511403 |
# | micro av. f1        | 0.242131 | 0.31068  |
# | macro av. f1        | 0.143266 | 0.2264   |
# | micro av. pr.       | 0.175899 | 0.172654 |
# | macro av. pr.       | 0.242702 | 0.149833 |
# | micro av. auc       | 0.499868 | 0.478529 |
# | macro av. auc       | 0.564481 | 0.378996 |
# | coverage error      | 0.581104 | 0.507525 |
# | ranking loss        | 0.199833 | 0.14214  |
#
# label index list [0, 2, 4, 6]
# Task: 2, s index: 4, e index: 6
# The test shape is (1196, 6).
# |                     |        0 |        1 |         2 |
# |:--------------------|---------:|---------:|----------:|
# | hamming loss        | 0.523411 | 0.445234 | 0.426839  |
# | zero_one_loss       | 0.84699  | 0.76087  | 0.758361  |
# | one_error           | 0.199833 | 0.129599 | 0.0953177 |
# | micro av. jaccard   | 0.137741 | 0.183908 | 0.214011  |
# | macro av. jaccard   | 0.083612 | 0.133581 | 0.261093  |
# | micro av. precision | 0.167224 | 0.216606 | 0.237404  |
# | macro av. precision | 0.083612 | 0.208821 | 0.495282  |
# | micro av. recall    | 0.438596 | 0.549199 | 0.684729  |
# | macro av. recall    | 0.5      | 0.511403 | 0.678489  |
# | micro av. f1        | 0.242131 | 0.31068  | 0.352568  |
# | macro av. f1        | 0.143266 | 0.2264   | 0.409073  |
# | micro av. pr.       | 0.175899 | 0.172654 | 0.42276   |
# | macro av. pr.       | 0.242702 | 0.149833 | 0.558059  |
# | micro av. auc       | 0.499868 | 0.478529 | 0.731264  |
# | macro av. auc       | 0.564481 | 0.378996 | 0.839285  |
# | coverage error      | 0.581104 | 0.507525 | 0.441472  |
# | ranking loss        | 0.199833 | 0.14214  | 0.102007  |
#
# Individual Task Results
# |                     |        0 |        1 |         2 |
# |:--------------------|---------:|---------:|----------:|
# | hamming loss        | 0.523411 | 0.445234 | 0.426839  |
# | zero_one_loss       | 0.84699  | 0.76087  | 0.758361  |
# | one_error           | 0.199833 | 0.129599 | 0.0953177 |
# | micro av. jaccard   | 0.137741 | 0.183908 | 0.214011  |
# | macro av. jaccard   | 0.083612 | 0.133581 | 0.261093  |
# | micro av. precision | 0.167224 | 0.216606 | 0.237404  |
# | macro av. precision | 0.083612 | 0.208821 | 0.495282  |
# | micro av. recall    | 0.438596 | 0.549199 | 0.684729  |
# | macro av. recall    | 0.5      | 0.511403 | 0.678489  |
# | micro av. f1        | 0.242131 | 0.31068  | 0.352568  |
# | macro av. f1        | 0.143266 | 0.2264   | 0.409073  |
# | micro av. pr.       | 0.175899 | 0.172654 | 0.42276   |
# | macro av. pr.       | 0.242702 | 0.149833 | 0.558059  |
# | micro av. auc       | 0.499868 | 0.478529 | 0.731264  |
# | macro av. auc       | 0.564481 | 0.378996 | 0.839285  |
# | coverage error      | 0.581104 | 0.507525 | 0.441472  |
# | ranking loss        | 0.199833 | 0.14214  | 0.102007  |
#
# ======================== Final Result ========================
# output shape =  (1196, 6)
# ground truth shape =  (1196, 6)
# Evaluation mode is incremental
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (1196, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.523411 |
# | zero_one_loss       | 0.84699  |
# | one_error           | 0.199833 |
# | micro av. jaccard   | 0.137741 |
# | macro av. jaccard   | 0.083612 |
# | micro av. precision | 0.167224 |
# | macro av. precision | 0.083612 |
# | micro av. recall    | 0.438596 |
# | macro av. recall    | 0.5      |
# | micro av. f1        | 0.242131 |
# | macro av. f1        | 0.143266 |
# | micro av. pr.       | 0.175899 |
# | macro av. pr.       | 0.242702 |
# | micro av. auc       | 0.499868 |
# | macro av. auc       | 0.564481 |
# | coverage error      | 0.581104 |
# | ranking loss        | 0.199833 |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 0, e index: 4
# The test shape is (1196, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |          1 |
# |:--------------------|---------:|-----------:|
# | hamming loss        | 0.523411 | 0.484323   |
# | zero_one_loss       | 0.84699  | 0.982441   |
# | one_error           | 0.199833 | 0.00501672 |
# | micro av. jaccard   | 0.137741 | 0.159594   |
# | macro av. jaccard   | 0.083612 | 0.108596   |
# | micro av. precision | 0.167224 | 0.190972   |
# | macro av. precision | 0.083612 | 0.146216   |
# | micro av. recall    | 0.438596 | 0.492721   |
# | macro av. recall    | 0.5      | 0.505701   |
# | micro av. f1        | 0.242131 | 0.275258   |
# | macro av. f1        | 0.143266 | 0.184833   |
# | micro av. pr.       | 0.175899 | 0.171452   |
# | macro av. pr.       | 0.242702 | 0.196268   |
# | micro av. auc       | 0.499868 | 0.47886    |
# | macro av. auc       | 0.564481 | 0.471738   |
# | coverage error      | 0.581104 | 1.76756    |
# | ranking loss        | 0.199833 | 0.345527   |
#
# label index list [0, 2, 4, 6]
# Task: 2, s index: 0, e index: 6
# The test shape is (1196, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |          1 |        2 |
# |:--------------------|---------:|-----------:|---------:|
# | hamming loss        | 0.523411 | 0.484323   | 0.465162 |
# | zero_one_loss       | 0.84699  | 0.982441   | 1        |
# | one_error           | 0.199833 | 0.00501672 | 0        |
# | micro av. jaccard   | 0.137741 | 0.159594   | 0.177022 |
# | macro av. jaccard   | 0.083612 | 0.108596   | 0.159429 |
# | micro av. precision | 0.167224 | 0.190972   | 0.206619 |
# | macro av. precision | 0.083612 | 0.146216   | 0.262572 |
# | micro av. recall    | 0.438596 | 0.492721   | 0.552733 |
# | macro av. recall    | 0.5      | 0.505701   | 0.563297 |
# | micro av. f1        | 0.242131 | 0.275258   | 0.300796 |
# | macro av. f1        | 0.143266 | 0.184833   | 0.25958  |
# | micro av. pr.       | 0.175899 | 0.171452   | 0.252373 |
# | macro av. pr.       | 0.242702 | 0.196268   | 0.316865 |
# | micro av. auc       | 0.499868 | 0.47886    | 0.564811 |
# | macro av. auc       | 0.564481 | 0.471738   | 0.594254 |
# | coverage error      | 0.581104 | 1.76756    | 3.29097  |
# | ranking loss        | 0.199833 | 0.345527   | 0.442349 |
#
# Overall Task Results
# |                     |        0 |          1 |        2 |
# |:--------------------|---------:|-----------:|---------:|
# | hamming loss        | 0.523411 | 0.484323   | 0.465162 |
# | zero_one_loss       | 0.84699  | 0.982441   | 1        |
# | one_error           | 0.199833 | 0.00501672 | 0        |
# | micro av. jaccard   | 0.137741 | 0.159594   | 0.177022 |
# | macro av. jaccard   | 0.083612 | 0.108596   | 0.159429 |
# | micro av. precision | 0.167224 | 0.190972   | 0.206619 |
# | macro av. precision | 0.083612 | 0.146216   | 0.262572 |
# | micro av. recall    | 0.438596 | 0.492721   | 0.552733 |
# | macro av. recall    | 0.5      | 0.505701   | 0.563297 |
# | micro av. f1        | 0.242131 | 0.275258   | 0.300796 |
# | macro av. f1        | 0.143266 | 0.184833   | 0.25958  |
# | micro av. pr.       | 0.175899 | 0.171452   | 0.252373 |
# | macro av. pr.       | 0.242702 | 0.196268   | 0.316865 |
# | micro av. auc       | 0.499868 | 0.47886    | 0.564811 |
# | macro av. auc       | 0.564481 | 0.471738   | 0.594254 |
# | coverage error      | 0.581104 | 1.76756    | 3.29097  |
# | ranking loss        | 0.199833 | 0.345527   | 0.442349 |
# 755.1912310123444 s.

# %%
# !python3 main.py --name scene --shuffle 1 --seed 66 --device 3
# Out:
# data_name: scene.
# seed: 66.
# shuffle: True.
# upper_bound: False.
# embed_dim: 200.
# task_num: 3.
# weight: 30.
# use_teacher: False.
# gamma: 8.
# first_epoch: 40.
# pse_epoch: 1.
# ssl_epoch 1.
# new_epoch: 40.
# sti_epoch: 15.
# ste_epoch: 40.
# ts_epoch: 5.
# as_epoch: 20
# first_batch: 64.
# ssl_batch: 64.
# new_batch: 64.
# st_batch: 64.
# ts_batch: 64.
# as_batch: 64
#
# (1211, 300) (1196, 300)
# torch.Size([1196, 6])
# 0.1810200668896321
# task: 0, #samples: 405, #negative samples: 251, #positive samples: 6
# task: 1, #samples: 403, #negative samples: 268, #positive samples: 0
# task: 2, #samples: 403, #negative samples: 274, #positive samples: 1
# ======================== Task 0 ========================
# Train single mode Epoch: 100%|██████████████████| 40/40 [01:33<00:00,  2.34s/it]
# The task 0 result is following:
# output shape =  (1196, 4)
# ground truth shape =  (1196, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (1196, 6).
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.158027  |
# | zero_one_loss       | 0.284281  |
# | one_error           | 0.0317726 |
# | micro av. jaccard   | 0.3952    |
# | macro av. jaccard   | 0.405522  |
# | micro av. precision | 0.59375   |
# | macro av. precision | 0.594244  |
# | micro av. recall    | 0.541667  |
# | macro av. recall    | 0.555156  |
# | micro av. f1        | 0.566514  |
# | macro av. f1        | 0.572221  |
# | micro av. pr.       | 0.638642  |
# | macro av. pr.       | 0.635828  |
# | micro av. auc       | 0.858392  |
# | macro av. auc       | 0.855691  |
# | coverage error      | 0.440635  |
# | ranking loss        | 0.0593645 |
#
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:21<00:00,  4.26s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.158027  |
# | zero_one_loss       | 0.284281  |
# | one_error           | 0.0317726 |
# | micro av. jaccard   | 0.3952    |
# | macro av. jaccard   | 0.405522  |
# | micro av. precision | 0.59375   |
# | macro av. precision | 0.594244  |
# | micro av. recall    | 0.541667  |
# | macro av. recall    | 0.555156  |
# | micro av. f1        | 0.566514  |
# | macro av. f1        | 0.572221  |
# | micro av. pr.       | 0.638642  |
# | macro av. pr.       | 0.635828  |
# | micro av. auc       | 0.858392  |
# | macro av. auc       | 0.855691  |
# | coverage error      | 0.440635  |
# | ranking loss        | 0.0593645 |
#
# ======================== Task 1 ========================
# Joint train passed.
# output shape =  (1196, 4)
# ground truth shape =  (1196, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (1196, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |
# |:--------------------|----------:|
# | hamming loss        | 0.157609  |
# | zero_one_loss       | 0.302676  |
# | one_error           | 0.0125418 |
# | micro av. jaccard   | 0.212944  |
# | macro av. jaccard   | 0.2287    |
# | micro av. precision | 0.816     |
# | macro av. precision | 0.408     |
# | micro av. recall    | 0.223684  |
# | macro av. recall    | 0.255     |
# | micro av. f1        | 0.351119  |
# | macro av. f1        | 0.313846  |
# | micro av. pr.       | 0.536544  |
# | macro av. pr.       | 0.636411  |
# | micro av. auc       | 0.7811    |
# | macro av. auc       | 0.857766  |
# | coverage error      | 0.513378  |
# | ranking loss        | 0.132107  |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 2, e index: 4
# The test shape is (1196, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |         0 |        1 |
# |:--------------------|----------:|---------:|
# | hamming loss        | 0.157609  | 0.503344 |
# | zero_one_loss       | 0.302676  | 0.833612 |
# | one_error           | 0.0125418 | 0.173077 |
# | micro av. jaccard   | 0.212944  | 0.141839 |
# | macro av. jaccard   | 0.2287    | 0.083194 |
# | micro av. precision | 0.816     | 0.166388 |
# | macro av. precision | 0.408     | 0.083194 |
# | micro av. recall    | 0.223684  | 0.490148 |
# | macro av. recall    | 0.255     | 0.5      |
# | micro av. f1        | 0.351119  | 0.248439 |
# | macro av. f1        | 0.313846  | 0.142652 |
# | micro av. pr.       | 0.536544  | 0.168073 |
# | macro av. pr.       | 0.636411  | 0.170425 |
# | micro av. auc       | 0.7811    | 0.493989 |
# | macro av. auc       | 0.857766  | 0.499847 |
# | coverage error      | 0.513378  | 0.512542 |
# | ranking loss        | 0.132107  | 0.173077 |
#
# Beginning compression, old model output size = 2
# Inter end shape =  4
# Old model output shape = 4
# Train single mode Epoch: 100%|██████████████████| 15/15 [00:54<00:00,  3.64s/it]
# Old model output shape =  4
# Train single mode Epoch: 100%|██████████████████| 40/40 [02:55<00:00,  4.38s/it]
# Student train teacher passed.
# Train single mode Epoch: 100%|████████████████████| 5/5 [00:21<00:00,  4.23s/it]
# Teacher train student passed.
# Individual Task Results
# |                     |         0 |        1 |
# |:--------------------|----------:|---------:|
# | hamming loss        | 0.157609  | 0.503344 |
# | zero_one_loss       | 0.302676  | 0.833612 |
# | one_error           | 0.0125418 | 0.173077 |
# | micro av. jaccard   | 0.212944  | 0.141839 |
# | macro av. jaccard   | 0.2287    | 0.083194 |
# | micro av. precision | 0.816     | 0.166388 |
# | macro av. precision | 0.408     | 0.083194 |
# | micro av. recall    | 0.223684  | 0.490148 |
# | macro av. recall    | 0.255     | 0.5      |
# | micro av. f1        | 0.351119  | 0.248439 |
# | macro av. f1        | 0.313846  | 0.142652 |
# | micro av. pr.       | 0.536544  | 0.168073 |
# | macro av. pr.       | 0.636411  | 0.170425 |
# | micro av. auc       | 0.7811    | 0.493989 |
# | macro av. auc       | 0.857766  | 0.499847 |
# | coverage error      | 0.513378  | 0.512542 |
# | ranking loss        | 0.132107  | 0.173077 |
#
# ======================== Task 2 ========================
# Joint train passed.
# output shape =  (1196, 6)
# ground truth shape =  (1196, 6)
# Evaluation mode is single
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (1196, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.523411 |
# | zero_one_loss       | 0.84699  |
# | one_error           | 0.199833 |
# | micro av. jaccard   | 0.137741 |
# | macro av. jaccard   | 0.083612 |
# | micro av. precision | 0.167224 |
# | macro av. precision | 0.083612 |
# | micro av. recall    | 0.438596 |
# | macro av. recall    | 0.5      |
# | micro av. f1        | 0.242131 |
# | macro av. f1        | 0.143266 |
# | micro av. pr.       | 0.170528 |
# | macro av. pr.       | 0.285159 |
# | micro av. auc       | 0.500568 |
# | macro av. auc       | 0.554929 |
# | coverage error      | 0.581104 |
# | ranking loss        | 0.199833 |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 2, e index: 4
# The test shape is (1196, 6).
# |                     |        0 |          1 |
# |:--------------------|---------:|-----------:|
# | hamming loss        | 0.523411 | 0.186037   |
# | zero_one_loss       | 0.84699  | 0.353679   |
# | one_error           | 0.199833 | 0.0183946  |
# | micro av. jaccard   | 0.137741 | 0.00224215 |
# | macro av. jaccard   | 0.083612 | 0.00204082 |
# | micro av. precision | 0.167224 | 0.0243902  |
# | macro av. precision | 0.083612 | 0.0128205  |
# | micro av. recall    | 0.438596 | 0.00246305 |
# | macro av. recall    | 0.5      | 0.00241546 |
# | micro av. f1        | 0.242131 | 0.00447427 |
# | macro av. f1        | 0.143266 | 0.00406504 |
# | micro av. pr.       | 0.170528 | 0.144639   |
# | macro av. pr.       | 0.285159 | 0.132755   |
# | micro av. auc       | 0.500568 | 0.394715   |
# | macro av. auc       | 0.554929 | 0.33861    |
# | coverage error      | 0.581104 | 0.504181   |
# | ranking loss        | 0.199833 | 0.164716   |
#
# label index list [0, 2, 4, 6]
# Task: 2, s index: 4, e index: 6
# The test shape is (1196, 6).
# |                     |        0 |          1 |        2 |
# |:--------------------|---------:|-----------:|---------:|
# | hamming loss        | 0.523411 | 0.186037   | 0.612876 |
# | zero_one_loss       | 0.84699  | 0.353679   | 0.923913 |
# | one_error           | 0.199833 | 0.0183946  | 0.301839 |
# | micro av. jaccard   | 0.137741 | 0.00224215 | 0.224339 |
# | macro av. jaccard   | 0.083612 | 0.00204082 | 0.233151 |
# | micro av. precision | 0.167224 | 0.0243902  | 0.225892 |
# | macro av. precision | 0.083612 | 0.0128205  | 0.235679 |
# | micro av. recall    | 0.438596 | 0.00246305 | 0.970252 |
# | macro av. recall    | 0.5      | 0.00241546 | 0.9675   |
# | micro av. f1        | 0.242131 | 0.00447427 | 0.366465 |
# | macro av. f1        | 0.143266 | 0.00406504 | 0.376906 |
# | micro av. pr.       | 0.170528 | 0.144639   | 0.249005 |
# | macro av. pr.       | 0.285159 | 0.132755   | 0.311115 |
# | micro av. auc       | 0.500568 | 0.394715   | 0.658699 |
# | macro av. auc       | 0.554929 | 0.33861    | 0.685127 |
# | coverage error      | 0.581104 | 0.504181   | 0.502508 |
# | ranking loss        | 0.199833 | 0.164716   | 0.137124 |
#
# Individual Task Results
# |                     |        0 |          1 |        2 |
# |:--------------------|---------:|-----------:|---------:|
# | hamming loss        | 0.523411 | 0.186037   | 0.612876 |
# | zero_one_loss       | 0.84699  | 0.353679   | 0.923913 |
# | one_error           | 0.199833 | 0.0183946  | 0.301839 |
# | micro av. jaccard   | 0.137741 | 0.00224215 | 0.224339 |
# | macro av. jaccard   | 0.083612 | 0.00204082 | 0.233151 |
# | micro av. precision | 0.167224 | 0.0243902  | 0.225892 |
# | macro av. precision | 0.083612 | 0.0128205  | 0.235679 |
# | micro av. recall    | 0.438596 | 0.00246305 | 0.970252 |
# | macro av. recall    | 0.5      | 0.00241546 | 0.9675   |
# | micro av. f1        | 0.242131 | 0.00447427 | 0.366465 |
# | macro av. f1        | 0.143266 | 0.00406504 | 0.376906 |
# | micro av. pr.       | 0.170528 | 0.144639   | 0.249005 |
# | macro av. pr.       | 0.285159 | 0.132755   | 0.311115 |
# | micro av. auc       | 0.500568 | 0.394715   | 0.658699 |
# | macro av. auc       | 0.554929 | 0.33861    | 0.685127 |
# | coverage error      | 0.581104 | 0.504181   | 0.502508 |
# | ranking loss        | 0.199833 | 0.164716   | 0.137124 |
#
# ======================== Final Result ========================
# output shape =  (1196, 6)
# ground truth shape =  (1196, 6)
# Evaluation mode is incremental
# label index list [0, 2, 4, 6]
# Task: 0, s index: 0, e index: 2
# The test shape is (1196, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |
# |:--------------------|---------:|
# | hamming loss        | 0.523411 |
# | zero_one_loss       | 0.84699  |
# | one_error           | 0.199833 |
# | micro av. jaccard   | 0.137741 |
# | macro av. jaccard   | 0.083612 |
# | micro av. precision | 0.167224 |
# | macro av. precision | 0.083612 |
# | micro av. recall    | 0.438596 |
# | macro av. recall    | 0.5      |
# | micro av. f1        | 0.242131 |
# | macro av. f1        | 0.143266 |
# | micro av. pr.       | 0.170528 |
# | macro av. pr.       | 0.285159 |
# | micro av. auc       | 0.500568 |
# | macro av. auc       | 0.554929 |
# | coverage error      | 0.581104 |
# | ranking loss        | 0.199833 |
#
# label index list [0, 2, 4, 6]
# Task: 1, s index: 0, e index: 4
# The test shape is (1196, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |         1 |
# |:--------------------|---------:|----------:|
# | hamming loss        | 0.523411 | 0.354724  |
# | zero_one_loss       | 0.84699  | 0.854515  |
# | one_error           | 0.199833 | 0         |
# | micro av. jaccard   | 0.137741 | 0.105901  |
# | macro av. jaccard   | 0.083612 | 0.0428264 |
# | micro av. precision | 0.167224 | 0.16249   |
# | macro av. precision | 0.083612 | 0.0482163 |
# | micro av. recall    | 0.438596 | 0.233179  |
# | macro av. recall    | 0.5      | 0.251208  |
# | micro av. f1        | 0.242131 | 0.19152   |
# | macro av. f1        | 0.143266 | 0.0736658 |
# | micro av. pr.       | 0.170528 | 0.155938  |
# | macro av. pr.       | 0.285159 | 0.208957  |
# | micro av. auc       | 0.500568 | 0.454451  |
# | macro av. auc       | 0.554929 | 0.44677   |
# | coverage error      | 0.581104 | 1.84699   |
# | ranking loss        | 0.199833 | 0.37291   |
#
# label index list [0, 2, 4, 6]
# Task: 2, s index: 0, e index: 6
# The test shape is (1196, 6).
# /home/airl-gpu4/anaconda3/envs/DL_gpu/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# |                     |        0 |         1 |        2 |
# |:--------------------|---------:|----------:|---------:|
# | hamming loss        | 0.523411 | 0.354724  | 0.440775 |
# | zero_one_loss       | 0.84699  | 0.854515  | 0.999164 |
# | one_error           | 0.199833 | 0         | 0        |
# | micro av. jaccard   | 0.137741 | 0.105901  | 0.164995 |
# | macro av. jaccard   | 0.083612 | 0.0428264 | 0.106268 |
# | micro av. precision | 0.167224 | 0.16249   | 0.200706 |
# | macro av. precision | 0.083612 | 0.0482163 | 0.110704 |
# | micro av. recall    | 0.438596 | 0.233179  | 0.481139 |
# | macro av. recall    | 0.5      | 0.251208  | 0.489972 |
# | micro av. f1        | 0.242131 | 0.19152   | 0.283254 |
# | macro av. f1        | 0.143266 | 0.0736658 | 0.174746 |
# | micro av. pr.       | 0.170528 | 0.155938  | 0.174624 |
# | macro av. pr.       | 0.285159 | 0.208957  | 0.24301  |
# | micro av. auc       | 0.500568 | 0.454451  | 0.496907 |
# | macro av. auc       | 0.554929 | 0.44677   | 0.526222 |
# | coverage error      | 0.581104 | 1.84699   | 3.65886  |
# | ranking loss        | 0.199833 | 0.37291   | 0.501819 |
#
# Overall Task Results
# |                     |        0 |         1 |        2 |
# |:--------------------|---------:|----------:|---------:|
# | hamming loss        | 0.523411 | 0.354724  | 0.440775 |
# | zero_one_loss       | 0.84699  | 0.854515  | 0.999164 |
# | one_error           | 0.199833 | 0         | 0        |
# | micro av. jaccard   | 0.137741 | 0.105901  | 0.164995 |
# | macro av. jaccard   | 0.083612 | 0.0428264 | 0.106268 |
# | micro av. precision | 0.167224 | 0.16249   | 0.200706 |
# | macro av. precision | 0.083612 | 0.0482163 | 0.110704 |
# | micro av. recall    | 0.438596 | 0.233179  | 0.481139 |
# | macro av. recall    | 0.5      | 0.251208  | 0.489972 |
# | micro av. f1        | 0.242131 | 0.19152   | 0.283254 |
# | macro av. f1        | 0.143266 | 0.0736658 | 0.174746 |
# | micro av. pr.       | 0.170528 | 0.155938  | 0.174624 |
# | macro av. pr.       | 0.285159 | 0.208957  | 0.24301  |
# | micro av. auc       | 0.500568 | 0.454451  | 0.496907 |
# | macro av. auc       | 0.554929 | 0.44677   | 0.526222 |
# | coverage error      | 0.581104 | 1.84699   | 3.65886  |
# | ranking loss        | 0.199833 | 0.37291   | 0.501819 |
# 852.0054290294647 s.
